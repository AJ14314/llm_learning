# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import datetime as dt
import requests
import json
import os
from bs4 import BeautifulSoup
import time
import random
import concurrent.futures
from typing import List, Tuple, Dict, Any
import logging
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
from threading import Lock
import gc

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# Configure session with retries and connection pooling
session = requests.Session()
retries = Retry(total=5, backoff_factor=0.1, status_forcelist=[500, 502, 503, 504])
session.mount('http://', HTTPAdapter(max_retries=retries, pool_connections=100, pool_maxsize=100))
session.mount('https://', HTTPAdapter(max_retries=retries, pool_connections=100, pool_maxsize=100))

# Thread-safe lock for file writing
file_lock = Lock()

# %%
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# %%
def calculate_rsi(data, window=14):
    # Ensure the 'Close' column is correctly accessed
    if isinstance(data.columns, pd.MultiIndex):
        close_prices = data['Close'].iloc[:, 0]
    else:
        close_prices = data['Close']

    # Calculate price changes
    delta = close_prices.diff()

    # Separate gains (positive) and losses (negative)
    gains = delta.where(delta > 0, 0)
    losses = -delta.where(delta < 0, 0)

    # Initialize the averages
    avg_gains = [np.nan] * len(close_prices)
    avg_losses = [np.nan] * len(close_prices)

    # Calculate first averages after initial window
    first_avg_gain = gains[1:window+1].mean()
    first_avg_loss = losses[1:window+1].mean()
    avg_gains[window] = first_avg_gain
    avg_losses[window] = first_avg_loss

    # Calculate subsequent values using the Wilder's smoothing method
    for i in range(window+1, len(close_prices)):
        avg_gain = (avg_gains[i-1] * (window-1) + gains[i]) / window
        avg_loss = (avg_losses[i-1] * (window-1) + losses[i]) / window
        avg_gains[i] = avg_gain
        avg_losses[i] = avg_loss

    # Convert to Series with proper index
    avg_gains = pd.Series(avg_gains, index=close_prices.index)
    avg_losses = pd.Series(avg_losses, index=close_prices.index)

    # Calculate RS and RSI
    rs = avg_gains / avg_losses
    rsi = 100 - (100 / (1 + rs))

    return rsi

# %%
def get_stock_data(symbol, period='1y', end_date=None):
    """Fetch stock data with proper error handling and ensure unique data per stock

    Args:
        symbol (str): Stock symbol
        period (str): Data period to fetch (default='1y')
        end_date (str): End date in 'YYYY-MM-DD' format. If None, uses current date

    Returns:
        tuple: (DataFrame with stock data, actual_end_date)
    """
    try:
        time.sleep(1)  # Add delay to prevent rate limiting

        kwargs = {
            'tickers': f"{symbol}.NS",
            'period': period,
            'progress': False,
            'threads': False,
            'ignore_tz': True,
            'auto_adjust': True,
            'prepost': False,
            'repair': True
        }

        # Add end parameter if end_date is provided
        if end_date:
            kwargs['end'] = end_date
            # Calculate start date based on period
            if period == '1y':
                start_date = pd.to_datetime(end_date) - pd.DateOffset(years=1)
            elif period == '2y':
                start_date = pd.to_datetime(end_date) - pd.DateOffset(years=2)
            kwargs['start'] = start_date.strftime('%Y-%m-%d')

        # Download data
        data = yf.download(**kwargs)

        if data.empty:
            logger.warning(f"No data available for {symbol}")
            return pd.DataFrame(), None

        # Get the actual last date from the data
        actual_end_date = data.index[-1]

        # Handle multi-index columns if present
        if isinstance(data.columns, pd.MultiIndex):
            df = pd.DataFrame(index=data.index)
            column_map = {
                'Open': ('Open', symbol + '.NS'),
                'High': ('High', symbol + '.NS'),
                'Low': ('Low', symbol + '.NS'),
                'Close': ('Close', symbol + '.NS'),
                'Volume': ('Volume', symbol + '.NS')
            }
            for col, multi_idx in column_map.items():
                try:
                    if multi_idx in data.columns:
                        df[col] = data[multi_idx]
                    else:
                        df[col] = data[(multi_idx[0],)]
                except:
                    df[col] = data[multi_idx[0]]
        else:
            df = data.copy()

        # Verify data is valid
        if 'Close' in df.columns:
            latest_price = df['Close'].iloc[-1]
            logger.info(f"Verified unique data for {symbol}: Latest price = Rs.{latest_price:.2f}")
            if end_date:
                requested_date = pd.to_datetime(end_date).normalize()
                actual_date = actual_end_date.normalize()
                if actual_date != requested_date:
                    logger.info(f"Note: Last available date ({actual_date.strftime('%Y-%m-%d')}) differs from requested date ({requested_date.strftime('%Y-%m-%d')})")
        else:
            logger.error(f"Missing Close column for {symbol}")
            return pd.DataFrame(), None

        return df, actual_end_date

    except Exception as e:
        logger.error(f"Error fetching data for {symbol}: {e}")
        return pd.DataFrame(), None

# %%
def calculate_macd(data, fast=12, slow=26, signal=9):
    try:
        # Make sure we're working with a copy of the data to avoid warnings
        if isinstance(data.columns, pd.MultiIndex):
            close_series = data['Close'].iloc[:, 0].copy()
        else:
            close_series = data['Close'].copy()

        # Calculate EMAs
        ema_fast = close_series.ewm(span=fast, adjust=False).mean()
        ema_slow = close_series.ewm(span=slow, adjust=False).mean()

        # Calculate MACD components
        macd_line = ema_fast - ema_slow
        signal_line = macd_line.ewm(span=signal, adjust=False).mean()
        histogram = macd_line - signal_line

        return macd_line, signal_line, histogram
    except Exception as e:
        logger.error(f"Error calculating MACD: {e}")
        empty_series = pd.Series(dtype=float)
        return empty_series, empty_series, empty_series

# %%
def calculate_momentum(data, period=20):
    try:
        if isinstance(data.columns, pd.MultiIndex):
            close_series = data['Close'].iloc[:, 0]
        else:
            close_series = data['Close']

        momentum = close_series / close_series.shift(period) - 1
        return momentum * 100
    except Exception as e:
        logger.error(f"Error calculating momentum: {e}")
        return pd.Series(dtype=float)

# %%
def calculate_momentum_index(data, period=126):
    try:
        if isinstance(data.columns, pd.MultiIndex):
            close_series = data['Close'].iloc[:, 0]
        else:
            close_series = data['Close']

        returns = close_series.pct_change().dropna()
        momentum_std = returns.rolling(window=period).std() * np.sqrt(252)
        return momentum_std
    except Exception as e:
        logger.error(f"Error calculating momentum index: {e}")
        return pd.Series(dtype=float)

# %%
def get_fundamental_data(symbol: str) -> Dict[str, Any]:
    """Fetch fundamental data"""
    try:
        ticker = yf.Ticker(f"{symbol}.NS")
        info = ticker.info
        fundamental_data = {
            'P/E Ratio': info.get('trailingPE', 'N/A'),
            'Forward P/E': info.get('forwardPE', 'N/A'),
            'Market Cap': info.get('marketCap', 'N/A'),
            'EPS': info.get('trailingEps', 'N/A'),
            'Dividend Yield': info.get('dividendYield', 'N/A'),
            'Debt to Equity': info.get('debtToEquity', 'N/A'),
            'Return on Equity': info.get('returnOnEquity', 'N/A'),
            'Revenue Growth': info.get('revenueGrowth', 'N/A'),
            'Profit Margins': info.get('profitMargins', 'N/A'),
            'Beta': info.get('beta', 'N/A'),
            'Current Ratio': info.get('currentRatio', 'N/A'),
            'Book Value': info.get('bookValue', 'N/A'),
            '52-Week High': info.get('fiftyTwoWeekHigh', 'N/A'),
            '52-Week Low': info.get('fiftyTwoWeekLow', 'N/A'),
            'Target Price': info.get('targetMeanPrice', 'N/A')
        }
        return fundamental_data
    except Exception as e:
        logger.error(f"Error fetching fundamental data for {symbol}: {e}")
        return {}

# %%
def determine_strength(data, rsi, macd_line, signal_line):
    # Ensure data is not empty
    if isinstance(data, pd.DataFrame) and data.empty:
        return [], []

    # Handle multi-index columns if they exist
    if isinstance(data.columns, pd.MultiIndex):
        # Extract the first level columns if multi-index
        data_cols = {
            'Open': data['Open'].iloc[:, 0],
            'High': data['High'].iloc[:, 0],
            'Low': data['Low'].iloc[:, 0],
            'Close': data['Close'].iloc[:, 0],
            'Volume': data['Volume'].iloc[:, 0]
        }
        data_df = pd.DataFrame(data_cols, index=data.index)
    else:
        data_df = data

    current_price = data_df['Close'].iloc[-1]
    sma_50 = data_df['Close'].rolling(window=50).mean().iloc[-1]
    sma_200 = data_df['Close'].rolling(window=200).mean().iloc[-1]

    # Convert any Series to scalar values
    if isinstance(current_price, pd.Series):
        current_price = current_price.iloc[0]
    if isinstance(sma_50, pd.Series):
        sma_50 = sma_50.iloc[0]
    if isinstance(sma_200, pd.Series):
        sma_200 = sma_200.iloc[0]

    strengths = []
    weaknesses = []

    # RSI Analysis
    if not isinstance(rsi, pd.Series) or len(rsi) == 0:
        print("RSI data is empty")
    else:
        last_rsi = rsi.iloc[-1]
        if isinstance(last_rsi, pd.Series):
            last_rsi = last_rsi.item()
        if last_rsi > 70:
            weaknesses.append("RSI indicates overbought conditions")
        elif last_rsi < 30:
            strengths.append("RSI indicates oversold conditions (potential buying opportunity)")
        elif 40 <= last_rsi <= 60:
            strengths.append("RSI in neutral zone showing balance between buyers and sellers")
        elif 60 < last_rsi < 70:
            strengths.append("Strong RSI showing positive momentum")

    # MACD Analysis
    if (not isinstance(macd_line, pd.Series) or len(macd_line) == 0 or
        not isinstance(signal_line, pd.Series) or len(signal_line) == 0):
        print("MACD or signal line data is empty")
    else:
        macd_value = macd_line.iloc[-1]
        signal_value = signal_line.iloc[-1]
        if isinstance(macd_value, pd.Series):
            macd_value = macd_value.item()
        if isinstance(signal_value, pd.Series):
            signal_value = signal_value.item()
        if macd_value > signal_value:
            strengths.append("MACD line above signal line indicating bullish momentum")
        else:
            weaknesses.append("MACD line below signal line indicating bearish momentum")

    # Moving Average Analysis
    if pd.notna(sma_50) and pd.notna(current_price):
        if current_price > sma_50:
            strengths.append("Price above 50-day SMA showing short-term strength")
        else:
            weaknesses.append("Price below 50-day SMA showing short-term weakness")

    if pd.notna(sma_200) and pd.notna(current_price):
        if current_price > sma_200:
            strengths.append("Price above 200-day SMA suggesting long-term uptrend")
        else:
            weaknesses.append("Price below 200-day SMA suggesting long-term downtrend")

    # Golden/Death Cross
    if pd.notna(sma_50) and pd.notna(sma_200):
        if sma_50 > sma_200 and (sma_50 / sma_200 - 1) < 0.03:
            strengths.append("Recent golden cross or nearing golden cross (50-day SMA crossing above 200-day SMA)")
        elif sma_50 < sma_200 and (sma_200 / sma_50 - 1) < 0.03:
            weaknesses.append("Recent death cross or nearing death cross (50-day SMA crossing below 200-day SMA)")

    # Volume Analysis
    avg_volume = data_df['Volume'].mean()
    if isinstance(avg_volume, pd.Series):
        avg_volume = avg_volume.item()

    recent_volume = data_df['Volume'].iloc[-5:].mean()
    if isinstance(recent_volume, pd.Series):
        recent_volume = recent_volume.item()

    # Calculate price trend
    recent_price_mean = data_df['Close'].iloc[-5:].mean()
    if isinstance(recent_price_mean, pd.Series):
        recent_price_mean = recent_price_mean.item()

    price_trend_up = current_price > recent_price_mean

    if recent_volume > avg_volume * 1.2:
        if price_trend_up:
            strengths.append("Strong volume supporting upward price movement")
        else:
            weaknesses.append("High volume during price decline indicates selling pressure")
    elif recent_volume < avg_volume * 0.8:
        if price_trend_up:
            strengths.append("Price rising on low volume - potential weakness")
        else:
            weaknesses.append("Price declining on low volume - potential for reversal")

    # Price Movement
    if len(data_df['Close']) >= 22:
        latest_price = data_df['Close'].iloc[-1]
        price_22_days_ago = data_df['Close'].iloc[-22]

        if isinstance(latest_price, pd.Series):
            latest_price = latest_price.item()
        if isinstance(price_22_days_ago, pd.Series):
            price_22_days_ago = price_22_days_ago.item()

        monthly_return = (latest_price / price_22_days_ago - 1) * 100

        if monthly_return > 5:
            strengths.append(f"Strong monthly return of {monthly_return:.2f}%")
        elif monthly_return < -5:
            weaknesses.append(f"Weak monthly return of {monthly_return:.2f}%")

    # Volatility
    if len(data_df['Close']) >= 2:
        returns = data_df['Close'].pct_change().dropna()
        if len(returns) > 0:
            volatility = returns.std() * np.sqrt(252) * 100
            if isinstance(volatility, pd.Series):
                volatility = volatility.item()

            if volatility > 30:
                weaknesses.append(f"High volatility ({volatility:.2f}%) indicating increased risk")
            elif volatility < 15:
                strengths.append(f"Low volatility ({volatility:.2f}%) indicating stability")

    return strengths, weaknesses

# %%
def get_weekday(date):
    """Get weekday number (1=Monday to 7=Sunday)"""
    return date.isoweekday()

def get_next_friday(target_date):
    """Get the next Friday from a given date. If the date is Friday, return the same date."""
    weekday = get_weekday(target_date)
    if weekday == 5:  # If Friday
        return target_date

    days_until_friday = {
        1: 4,  # Monday -> +4 days
        2: 3,  # Tuesday -> +3 days
        3: 2,  # Wednesday -> +2 days
        4: 1,  # Thursday -> +1 day
        6: 6,  # Saturday -> +6 days
        7: 5   # Sunday -> +5 days
    }
    days_to_add = days_until_friday[weekday]
    return target_date + pd.Timedelta(days=days_to_add)

def get_next_thursday(target_date):
    """Get the next Thursday from a given date. If the date is Friday, return the previous day."""
    weekday = get_weekday(target_date)
    if weekday == 5:  # If Friday
        return target_date - pd.Timedelta(days=1)
    return get_next_friday(target_date) - pd.Timedelta(days=1)

def find_closest_trading_day(data, target_date):
    """Find the closest trading day in the data for a given target date"""
    target_friday = get_next_friday(target_date)
    target_thursday = get_next_thursday(target_date)

    # Convert index to datetime if it's not already and normalize to remove time component
    date_index = pd.to_datetime(data.index).normalize()

    # Normalize target dates to remove time component
    target_friday = pd.to_datetime(target_friday).normalize()
    target_thursday = pd.to_datetime(target_thursday).normalize()

    # Try to find exact matches first
    friday_match = date_index[date_index == target_friday]
    thursday_match = date_index[date_index == target_thursday]

    if not friday_match.empty:
        return friday_match[0]
    elif not thursday_match.empty:
        return thursday_match[0]

    # If no exact match, find the closest available date
    all_dates = date_index
    closest_date = min(all_dates, key=lambda x: abs(x - target_friday))

    return closest_date

def get_date_one_year_back(data, from_date=None):
    """Calculate the date from the given date (or last date in stock data) to 1 year back"""
    if from_date:
        last_date = pd.to_datetime(from_date).normalize()
    else:
        last_date = pd.to_datetime(data.index[-1]).normalize()
    target_date = last_date - pd.DateOffset(months=12)
    return find_closest_trading_day(data, target_date)

def get_date_six_months_back(data, from_date=None):
    """Calculate the date from the given date (or last date in stock data) to 6 months back"""
    if from_date:
        last_date = pd.to_datetime(from_date).normalize()
    else:
        last_date = pd.to_datetime(data.index[-1]).normalize()
    target_date = last_date - pd.DateOffset(months=6)
    return find_closest_trading_day(data, target_date)

def get_first_available_date(data):
    """Get the first date for which price data is available"""
    return pd.to_datetime(data.index[0]).normalize()

def get_prices_for_dates(data, end_date=None):
    """Get prices for specified date (or current date), 6 months back and 1 year back, and calculate price changes.

    Args:
        data (pd.DataFrame): Stock price data with 'Close' prices
        end_date (str): End date in 'YYYY-MM-DD' format. If None, uses last date in data

    Returns:
        dict: Dictionary containing price data and changes for different time periods
    """
    # Get the actual last date from data
    actual_last_date = pd.to_datetime(data.index[-1]).normalize()

    # If end_date is provided but different from actual_last_date, use actual_last_date
    if end_date:
        requested_date = pd.to_datetime(end_date).normalize()
        if requested_date != actual_last_date:
            logger.info(f"Using last available date {actual_last_date.strftime('%Y-%m-%d')} instead of requested date {requested_date.strftime('%Y-%m-%d')}")
            current_date = actual_last_date
        else:
            current_date = requested_date
    else:
        current_date = actual_last_date

    six_month_date = get_date_six_months_back(data, current_date)
    one_year_date = get_date_one_year_back(data, current_date)
    first_available_date = get_first_available_date(data)

    # Handle multi-index columns if they exist
    if isinstance(data.columns, pd.MultiIndex):
        close_prices = data['Close'].iloc[:, 0]
    else:
        close_prices = data['Close']

    # Get current price (should always be available since we're using actual last date)
    current_price = close_prices[current_date]

    # Get 6-month price if available, otherwise use first available date
    try:
        six_month_price = close_prices[six_month_date]
        six_month_actual_date = six_month_date
    except KeyError:
        six_month_price = close_prices[first_available_date]
        six_month_actual_date = first_available_date

    # Get 1-year price if available, otherwise use first available date
    try:
        one_year_price = close_prices[one_year_date]
        one_year_actual_date = one_year_date
    except KeyError:
        one_year_price = close_prices[first_available_date]
        one_year_actual_date = first_available_date

    # Calculate price changes
    twelve_month_change = (current_price / one_year_price - 1) if one_year_price != 0 else 0
    six_month_change = (current_price / six_month_price - 1) if six_month_price != 0 else 0

    # Create a dictionary with dates, prices and price changes
    price_data = {
        'Current': {
            'date': current_date.strftime('%Y-%m-%d'),
            'price': round(current_price, 2)
        },
        '6_months_back': {
            'date': six_month_actual_date.strftime('%Y-%m-%d'),
            'price': round(six_month_price, 2),
            'price_change_percent': round(six_month_change * 100, 2),
            'is_first_available': six_month_actual_date == first_available_date
        },
        '1_year_back': {
            'date': one_year_actual_date.strftime('%Y-%m-%d'),
            'price': round(one_year_price, 2),
            'price_change_percent': round(twelve_month_change * 100, 2),
            'is_first_available': one_year_actual_date == first_available_date
        }
    }

    return price_data

# %%
def calculate_log_returns(data, end_date=None):
    """Calculate logarithmic returns between consecutive trading days for the past year
    Returns the log returns as percentages along with the prices used in calculations.

    Args:
        data (pd.DataFrame): Stock price data with 'Close' prices
        end_date (str): End date in 'YYYY-MM-DD' format. If None, uses last date in data

    Returns:
        tuple: (log_returns, price_data)
    """
    # Get the dates for 1 year period
    if end_date:
        current_date = pd.to_datetime(end_date).normalize()
    else:
        current_date = pd.to_datetime(data.index[-1]).normalize()

    one_year_back_date = get_date_one_year_back(data, end_date)

    # Handle multi-index columns if they exist
    if isinstance(data.columns, pd.MultiIndex):
        close_prices = data['Close'].iloc[:, 0]
    else:
        close_prices = data['Close']

    # Get the slice of data between one year back and current date
    mask = (data.index >= one_year_back_date) & (data.index <= current_date)
    period_prices = close_prices[mask]

    # Create a DataFrame to store prices and calculations
    price_data = pd.DataFrame({
        'Current_Price': period_prices.astype(float),
        'Previous_Price': period_prices.shift(1).astype(float)
    })

    # Calculate price ratios first (current/previous)
    price_data['Price_Ratio'] = price_data['Current_Price'] / price_data['Previous_Price']

    # Calculate log returns exactly as Excel does: LN(current/previous)
    price_data['Log_Return_Percent'] = np.log(price_data['Price_Ratio']) * 100

    # Round to 3 decimal places after all calculations
    price_data['Log_Return_Percent'] = price_data['Log_Return_Percent'].round(3)

    # Round other columns to 2 decimal places
    for column in ['Current_Price', 'Previous_Price', 'Price_Ratio']:
        price_data[column] = price_data[column].round(2)

    # Drop the first row as it will have NaN values due to the shift operation
    price_data = price_data.dropna()

    # Create the log returns series
    log_returns = price_data['Log_Return_Percent']

    return log_returns, price_data

# %%
def calculate_log_stdev(data, end_date=None):
    """Calculate standard deviation using all log values from last 1 year till the specified date.
    Similar to Excel's STDEV(A:B) where A:B would be the range of log values.
    Returns the standard deviation divided by 100.

    Args:
        data (pd.DataFrame): Stock price data with 'Close' prices
        end_date (str): End date in 'YYYY-MM-DD' format. If None, uses last date in data

    Returns:
        tuple: (one_year_stdev, six_month_stdev) where values are divided by 100
    """
    # Get the dates
    if end_date:
        current_date = pd.to_datetime(end_date).normalize()
    else:
        current_date = pd.to_datetime(data.index[-1]).normalize()

    six_month_date = get_date_six_months_back(data, end_date)
    one_year_date = get_date_one_year_back(data, end_date)

    # Get log returns for the entire period
    log_returns, _ = calculate_log_returns(data, end_date)

    try:
        # Get all log values from one year ago to current date
        one_year_mask = (log_returns.index >= one_year_date) & (log_returns.index <= current_date)
        one_year_logs = log_returns[one_year_mask]
        # Calculate standard deviation using all values in the period and divide by 100
        one_year_stdev = np.std(one_year_logs) / 100
    except KeyError:
        one_year_stdev = None

    try:
        # Get all log values from six months ago to current date
        six_month_mask = (log_returns.index >= six_month_date) & (log_returns.index <= current_date)
        six_month_logs = log_returns[six_month_mask]
        # Calculate standard deviation using all values in the period and divide by 100
        six_month_stdev = np.std(six_month_logs) / 100
    except KeyError:
        six_month_stdev = None

    return one_year_stdev, six_month_stdev

# %%
def calculate_momentum_ratio(data, end_date=None):
    """Calculate momentum ratios for 1 year and 6 months periods.
    Momentum ratio = Price change percentage / (Standard deviation * 100)

    Args:
        data (pd.DataFrame): Stock price data with 'Close' prices
        end_date (str): End date in 'YYYY-MM-DD' format. If None, uses last date in data

    Returns:
        dict: Dictionary containing momentum ratios for both periods
    """
    # Get price changes
    prices_data = get_prices_for_dates(data, end_date)
    one_year_change = prices_data['1_year_back']['price_change_percent']
    six_month_change = prices_data['6_months_back']['price_change_percent']

    # Get standard deviations (already divided by 100 in calculate_log_stdev)
    one_year_stdev, six_month_stdev = calculate_log_stdev(data, end_date)

    # Calculate momentum ratios
    # Note: We multiply stdev by 100 to match the scale of price_change_percent
    one_year_momentum = one_year_change / (one_year_stdev * 100) if one_year_stdev else None
    six_month_momentum = six_month_change / (six_month_stdev * 100) if six_month_stdev else None

    result = {
        'momentum_ratios': {
            'one_year': round(one_year_momentum, 4) if one_year_momentum is not None else None,
            'six_month': round(six_month_momentum, 4) if six_month_momentum is not None else None
        },
        'components': {
            'one_year': {
                'price_change_percent': one_year_change,
                'standard_deviation': one_year_stdev * 100 if one_year_stdev else None
            },
            'six_month': {
                'price_change_percent': six_month_change,
                'standard_deviation': six_month_stdev * 100 if six_month_stdev else None
            }
        }
    }

    return result

# %%
def calculate_universe_stats(momentum_values):
    """Calculate standard deviation and mean for a list of momentum ratios.
    Similar to Excel's STDEV and AVERAGE functions.

    Args:
        momentum_values: List of momentum ratio values

    Returns:
        tuple: (standard_deviation, mean)
    """
    # Remove None values
    valid_values = [v for v in momentum_values if v is not None]

    if not valid_values:
        return None, None

    # Calculate standard deviation (similar to Excel's STDEV)
    stdev = np.std(valid_values, ddof=1)  # ddof=1 for sample standard deviation (like Excel)

    # Calculate mean (similar to Excel's AVERAGE)
    mean = np.mean(valid_values)

    return stdev, mean

# %%
def calculate_z_score(value, mean, stdev):
    """Calculate z-score for a value.

    Z-score = (value - mean) / standard_deviation

    Args:
        value: The value to calculate z-score for
        mean: Mean of the universe
        stdev: Standard deviation of the universe

    Returns:
        float: z-score or None if inputs are invalid
    """
    if value is None or mean is None or stdev is None or stdev == 0:
        return None

    return (value - mean) / stdev

# %%
def calculate_weighted_z_score(one_year_z_score, six_month_z_score, weights=None):
    """Calculate weighted z-score from 1-year and 6-month z-scores.

    Args:
        one_year_z_score: Z-score for 1-year momentum ratio
        six_month_z_score: Z-score for 6-month momentum ratio
        weights: Dictionary with weights for each period.
                Default is {'one_year': 0.5, 'six_month': 0.5}

    Returns:
        float: Weighted z-score or None if inputs are invalid
    """
    if one_year_z_score is None or six_month_z_score is None:
        return None

    # Use default weights if none provided
    if weights is None:
        weights = {'one_year': 0.5, 'six_month': 0.5}

    weighted_z_score = (
        one_year_z_score * weights['one_year'] +
        six_month_z_score * weights['six_month']
    )

    return weighted_z_score

# %%
def calculate_normalized_z_score(z_score):
    """Calculate normalized z-score using the formula: IF(z_score>0,(1+z_score),(1-z_score)^-1)

    Args:
        z_score: The z-score to normalize

    Returns:
        float: Normalized z-score or None if input is invalid
    """
    if z_score is None:
        return None

    return (1 + z_score) if z_score > 0 else (1 - z_score) ** -1

# %%
def calculate_rank(value, values_list):
    """Calculate the rank of a value within a list. Similar to Excel's RANK(number, ref, [order])

    Args:
        value: The number whose rank you want to find
        values_list: A list of numbers that defines the relative ranking

    Returns:
        int: The rank of the number (1 being the highest)
    """
    # Remove None values from the list
    valid_values = [v for v in values_list if v is not None]

    if value is None or not valid_values:
        return None

    # Sort values in descending order (mimicking Excel's RANK with order=0)
    sorted_values = sorted(set(valid_values), reverse=True)

    try:
        # Find the rank (adding 1 because index starts at 0)
        rank = sorted_values.index(value) + 1
        return rank
    except ValueError:
        return None

# %%
def analyze_stocks(stocks_df, output_dir="stock_analysis", max_workers=5, end_date=None):
    """Analyze a list of stocks and calculate momentum metrics for each.

    Args:
        stocks_df: List of tuples (company_name, symbol)
        output_dir: Directory to store analysis results
        max_workers: Maximum number of parallel workers
        end_date: End date for analysis in YYYY-MM-DD format
    """
    os.makedirs(output_dir, exist_ok=True)
    results = {}

    # Global rank data structure to store universe-wide statistics
    global rank_data
    rank_data = {
        'one_year': {'values': [], 'ranks': {}, 'universe_stats': {'stdev': None, 'mean': None}},
        'six_month': {'values': [], 'ranks': {}, 'universe_stats': {'stdev': None, 'mean': None}},
        'weighted_z_score': {'values': [], 'ranks': {}},
        'normalized_z_score': {'values': [], 'ranks': {}}
    }

    def process_stock(stock_tuple):
        company_name, symbol = stock_tuple
        logger.info(f"Processing {company_name} ({symbol})")

        try:
            # Get stock data with actual end date
            data, actual_end_date = get_stock_data(symbol, period='2y', end_date=end_date)
            if data.empty:
                logger.warning(f"No data available for {symbol}")
                return None

            # Use actual end date for all calculations
            actual_end_date_str = actual_end_date.strftime('%Y-%m-%d')

            # Calculate technical indicators
            rsi = calculate_rsi(data)
            macd_line, signal_line, histogram = calculate_macd(data)
            momentum_period20 = calculate_momentum(data, period=20)
            momentum_index = calculate_momentum_index(data)
            momentum_ratio = calculate_momentum_ratio(data, actual_end_date_str)

            # Get price data using actual end date
            prices = get_prices_for_dates(data, actual_end_date_str)

            # Determine strengths and weaknesses
            strengths, weaknesses = determine_strength(data, rsi, macd_line, signal_line)

            # Store the result with all necessary data
            result = {
                'company_name': company_name,
                'symbol': symbol,
                'actual_end_date': actual_end_date_str,
                'current_price': prices['Current']['price'],
                'price_data': prices,
                'technical_indicators': {
                    'rsi': rsi.iloc[-1] if not rsi.empty else None,
                    'macd': {
                        'macd_line': macd_line.iloc[-1] if not macd_line.empty else None,
                        'signal_line': signal_line.iloc[-1] if not signal_line.empty else None,
                        'histogram': histogram.iloc[-1] if not histogram.empty else None
                    },
                    'momentum': {
                        'momentum_20day': momentum_period20.iloc[-1] if not momentum_period20.empty else None,
                        'momentum_index': momentum_index.iloc[-1] if not momentum_index.empty else None,
                        'momentum_ratio': momentum_ratio
                    }
                },
                'analysis': {
                    'strengths': strengths,
                    'weaknesses': weaknesses
                },
                'data': data
            }

            # Store momentum values for universe calculations
            one_year_momentum = momentum_ratio['momentum_ratios']['one_year']
            six_month_momentum = momentum_ratio['momentum_ratios']['six_month']

            if one_year_momentum is not None:
                rank_data['one_year']['values'].append(one_year_momentum)
            if six_month_momentum is not None:
                rank_data['six_month']['values'].append(six_month_momentum)

            return result

        except Exception as e:
            logger.error(f"Error processing {symbol}: {e}")
            return None

    # Process stocks in parallel
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {executor.submit(process_stock, stock): stock for stock in stocks_df}

        for future in concurrent.futures.as_completed(futures):
            stock = futures[future]
            try:
                result = future.result()
                if result:
                    results[result['symbol']] = result
            except Exception as e:
                logger.error(f"Error processing {stock}: {e}")

    # Calculate universe statistics for both periods
    for period in ['one_year', 'six_month']:
        values = rank_data[period]['values']
        stdev, mean = calculate_universe_stats(values)
        rank_data[period]['universe_stats']['stdev'] = stdev
        rank_data[period]['universe_stats']['mean'] = mean

        # Calculate ranks and z-scores
        for symbol, result in results.items():
            momentum = result['technical_indicators']['momentum']['momentum_ratio']['momentum_ratios'][period]
            if momentum is not None:
                rank = calculate_rank(momentum, values)
                z_score = calculate_z_score(momentum, mean, stdev)
                rank_data[period]['ranks'][symbol] = rank

                # Update the result with rank and z-score information
                result['technical_indicators']['momentum']['momentum_ratio']['ranks'] = result['technical_indicators']['momentum']['momentum_ratio'].get('ranks', {})
                result['technical_indicators']['momentum']['momentum_ratio']['ranks'][period] = rank
                result['technical_indicators']['momentum']['momentum_ratio']['z_scores'] = result['technical_indicators']['momentum']['momentum_ratio'].get('z_scores', {})
                result['technical_indicators']['momentum']['momentum_ratio']['z_scores'][period] = z_score
                result['technical_indicators']['momentum']['momentum_ratio']['universe_stats'] = {
                    'stdev': stdev,
                    'mean': mean
                }

    # Calculate weighted z-score ranks and normalized z-scores
    weighted_z_scores = {}
    normalized_z_scores = {}
    for symbol, result in results.items():
        one_year_z_score = result['technical_indicators']['momentum']['momentum_ratio']['z_scores'].get('one_year')
        six_month_z_score = result['technical_indicators']['momentum']['momentum_ratio']['z_scores'].get('six_month')
        weighted_z_score = calculate_weighted_z_score(one_year_z_score, six_month_z_score)

        if weighted_z_score is not None:
            weighted_z_scores[symbol] = weighted_z_score
            rank_data['weighted_z_score']['values'].append(weighted_z_score)

            # Calculate normalized z-score
            normalized_z_score = calculate_normalized_z_score(weighted_z_score)
            if normalized_z_score is not None:
                normalized_z_scores[symbol] = normalized_z_score
                rank_data['normalized_z_score']['values'].append(normalized_z_score)

    # Calculate ranks for weighted z-scores
    sorted_weighted_z = sorted(rank_data['weighted_z_score']['values'], reverse=True)
    for symbol, weighted_z_score in weighted_z_scores.items():
        rank = sorted_weighted_z.index(weighted_z_score) + 1
        rank_data['weighted_z_score']['ranks'][symbol] = rank
        results[symbol]['technical_indicators']['momentum']['momentum_ratio']['weighted_z_score'] = {
            'score': weighted_z_score,
            'rank': rank,
            'total_stocks': len(results)
        }

    # Calculate ranks for normalized z-scores
    sorted_normalized_z = sorted(rank_data['normalized_z_score']['values'], reverse=True)
    for symbol, normalized_z_score in normalized_z_scores.items():
        rank = sorted_normalized_z.index(normalized_z_score) + 1
        rank_data['normalized_z_score']['ranks'][symbol] = rank
        results[symbol]['technical_indicators']['momentum']['momentum_ratio']['normalized_z_score'] = {
            'score': normalized_z_score,
            'rank': rank,
            'total_stocks': len(results)
        }

    # Generate markdown files
    for symbol, result in results.items():
        company_name = result['company_name']

        # Generate rank analysis markdown
        rank_analysis_md = generate_rank_analysis_markdown(
            result['data'],
            symbol,
            one_year_rank=rank_data['one_year']['ranks'].get(symbol),
            six_month_rank=rank_data['six_month']['ranks'].get(symbol),
            total_stocks=len(results)
        )

        # Create comprehensive markdown content
        md_content = f"# {company_name} ({symbol}) Analysis\n\n"

        # Add actual date used for analysis
        if end_date and result['actual_end_date'] != end_date:
            md_content += f"*Note: Analysis uses last available date {result['actual_end_date']} instead of requested date {end_date}*\n\n"

        # Current Price and Performance
        md_content += "## Current Price and Performance\n\n"
        md_content += f"Current Price: Rs.{result['price_data']['Current']['price']:.2f}\n"
        if '1_year_back' in result['price_data']:
            md_content += f"1-Year Change: {result['price_data']['1_year_back']['price_change_percent']:.2f}%\n"
        if '6_months_back' in result['price_data']:
            md_content += f"6-Month Change: {result['price_data']['6_months_back']['price_change_percent']:.2f}%\n\n"

        # Technical Indicators
        md_content += "## Technical Indicators\n\n"
        if result['technical_indicators']['rsi'] is not None:
            md_content += f"RSI (14-day): {float(result['technical_indicators']['rsi']):.2f}\n"
        if result['technical_indicators']['macd']['macd_line'] is not None:
            md_content += f"MACD Line: {float(result['technical_indicators']['macd']['macd_line']):.2f}\n"
            md_content += f"Signal Line: {float(result['technical_indicators']['macd']['signal_line']):.2f}\n"
            md_content += f"MACD Histogram: {float(result['technical_indicators']['macd']['histogram']):.2f}\n"

        # Momentum Rankings and Universe Statistics
        md_content += "\n## Momentum Rankings and Universe Statistics\n\n"

        # 1-Year Stats
        md_content += "### 1-Year Momentum\n"
        one_year_rank = rank_data['one_year']['ranks'].get(symbol)
        one_year_momentum = result['technical_indicators']['momentum']['momentum_ratio']['momentum_ratios']['one_year']
        one_year_z_score = result['technical_indicators']['momentum']['momentum_ratio']['z_scores'].get('one_year')

        if one_year_rank and one_year_momentum:
            md_content += f"- Rank: {one_year_rank} out of {len(results)}\n"
            md_content += f"- Momentum Ratio: {one_year_momentum:.4f}\n"
            md_content += f"- Universe Mean: {rank_data['one_year']['universe_stats']['mean']:.4f}\n"
            md_content += f"- Universe StDev: {rank_data['one_year']['universe_stats']['stdev']:.4f}\n"
            if one_year_z_score is not None:
                md_content += f"- Z-Score: {one_year_z_score:.4f}\n"

        # 6-Month Stats
        md_content += "\n### 6-Month Momentum\n"
        six_month_rank = rank_data['six_month']['ranks'].get(symbol)
        six_month_momentum = result['technical_indicators']['momentum']['momentum_ratio']['momentum_ratios']['six_month']
        six_month_z_score = result['technical_indicators']['momentum']['momentum_ratio']['z_scores'].get('six_month')

        if six_month_rank and six_month_momentum:
            md_content += f"- Rank: {six_month_rank} out of {len(results)}\n"
            md_content += f"- Momentum Ratio: {six_month_momentum:.4f}\n"
            md_content += f"- Universe Mean: {rank_data['six_month']['universe_stats']['mean']:.4f}\n"
            md_content += f"- Universe StDev: {rank_data['six_month']['universe_stats']['stdev']:.4f}\n"
            if six_month_z_score is not None:
                md_content += f"- Z-Score: {six_month_z_score:.4f}\n"

        # Add dedicated Rank and Z-Score section
        one_year_z_score = result['technical_indicators']['momentum']['momentum_ratio']['z_scores'].get('one_year')
        six_month_z_score = result['technical_indicators']['momentum']['momentum_ratio']['z_scores'].get('six_month')
        weighted_z_score_data = result['technical_indicators']['momentum']['momentum_ratio'].get('weighted_z_score', {})
        normalized_z_score_data = result['technical_indicators']['momentum']['momentum_ratio'].get('normalized_z_score', {})

        md_content += "\n## Rank and Z-Score Analysis\n\n"
        md_content += "### Z-Scores\n"
        if one_year_z_score is not None:
            md_content += f"- 1-Year Z-Score: {one_year_z_score:.4f}\n"
        if six_month_z_score is not None:
            md_content += f"- 6-Month Z-Score: {six_month_z_score:.4f}\n"
        if weighted_z_score_data.get('score') is not None:
            md_content += f"- Weighted Z-Score: {weighted_z_score_data['score']:.4f}\n"
            md_content += "  *(Calculated as: 1-Year Z-Score × 0.5 + 6-Month Z-Score × 0.5)*\n"
        if normalized_z_score_data.get('score') is not None:
            md_content += f"- Normalized Z-Score: {normalized_z_score_data['score']:.4f}\n"
            md_content += "  *(Calculated as: IF(weighted_z_score>0, (1+weighted_z_score), (1-weighted_z_score)^-1))*\n"

        md_content += "\n### Rankings\n"
        if one_year_rank:
            md_content += f"- 1-Year Momentum Rank: {one_year_rank} out of {len(results)}\n"
        if six_month_rank:
            md_content += f"- 6-Month Momentum Rank: {six_month_rank} out of {len(results)}\n"
        if weighted_z_score_data.get('rank') is not None:
            md_content += f"- Weighted Z-Score Rank: {weighted_z_score_data['rank']} out of {weighted_z_score_data['total_stocks']}\n"
        if normalized_z_score_data.get('rank') is not None:
            md_content += f"- Normalized Z-Score Rank: {normalized_z_score_data['rank']} out of {normalized_z_score_data['total_stocks']}\n"

        md_content += "\n### Universe Statistics\n"
        md_content += "**1-Year Momentum:**\n"
        md_content += f"- Mean: {rank_data['one_year']['universe_stats']['mean']:.4f}\n"
        md_content += f"- Standard Deviation: {rank_data['one_year']['universe_stats']['stdev']:.4f}\n\n"
        md_content += "**6-Month Momentum:**\n"
        md_content += f"- Mean: {rank_data['six_month']['universe_stats']['mean']:.4f}\n"
        md_content += f"- Standard Deviation: {rank_data['six_month']['universe_stats']['stdev']:.4f}\n"

        # Strengths and Weaknesses
        md_content += "\n## Analysis\n\n"
        md_content += "### Strengths\n"
        for strength in result['analysis']['strengths']:
            md_content += f"- {strength}\n"

        md_content += "\n### Weaknesses\n"
        for weakness in result['analysis']['weaknesses']:
            md_content += f"- {weakness}\n"

        # Add rank analysis content
        md_content += "\n" + rank_analysis_md

        # Save markdown file with all analysis
        analysis_file = os.path.join(output_dir, f"{symbol}.md")
        with file_lock:
            with open(analysis_file, 'w', encoding='utf-8') as f:
                f.write(md_content)

    return results

# %%
def generate_rank_analysis_markdown(stock_data, symbol, one_year_rank=None, six_month_rank=None, total_stocks=None):
    """Generate markdown documentation for RANK analysis calculations.

    This function creates detailed markdown explaining all calculations used in the analysis.
    """
    md_content = "## RANK Analysis\n\n"

    # Date Calculations Section
    md_content += "### Date Reference Points\n\n"
    current_date = stock_data.index[-1].strftime('%Y-%m-%d')
    one_year_back_date = get_date_one_year_back(stock_data)
    six_month_back_date = get_date_six_months_back(stock_data)

    md_content += f"- **Current Date:** {current_date}\n"
    md_content += f"- **1-Year Reference Date:** {one_year_back_date.strftime('%Y-%m-%d')}\n"
    md_content += f"- **6-Month Reference Date:** {six_month_back_date.strftime('%Y-%m-%d')}\n\n"

    # Price Changes Section
    md_content += "### Price Changes\n\n"
    current_price = stock_data['Close'].iloc[-1]
    year_start_price = stock_data.loc[one_year_back_date, 'Close']
    six_month_start_price = stock_data.loc[six_month_back_date, 'Close']

    year_change = (current_price / year_start_price - 1) * 100
    six_month_change = (current_price / six_month_start_price - 1) * 100

    md_content += f"**1-Year Price Change:**\n"
    md_content += f"- Start Price: ₹{year_start_price:.2f}\n"
    md_content += f"- Current Price: ₹{current_price:.2f}\n"
    md_content += f"- Change: {year_change:.2f}%\n\n"

    md_content += f"**6-Month Price Change:**\n"
    md_content += f"- Start Price: ₹{six_month_start_price:.2f}\n"
    md_content += f"- Current Price: ₹{current_price:.2f}\n"
    md_content += f"- Change: {six_month_change:.2f}%\n\n"

    # Log Returns Section
    md_content += "### Log Returns and Standard Deviation\n\n"
    log_returns, price_data = calculate_log_returns(stock_data)
    one_year_stdev, six_month_stdev = calculate_log_stdev(stock_data)

    md_content += "**Log Returns Calculation:**\n"
    md_content += "- Formula: `ln(current_price / previous_price) * 100`\n"
    md_content += f"- Recent Log Returns (last 5 days):\n"
    for date, row in price_data.tail().iterrows():
        md_content += f"  * {date.strftime('%Y-%m-%d')}: {row['Log_Return_Percent']:.3f}%\n"

    md_content += "\n**Standard Deviation:**\n"
    md_content += f"- 1-Year σ: {one_year_stdev*100:.3f}%\n"
    md_content += f"- 6-Month σ: {six_month_stdev*100:.3f}%\n\n"

    # Momentum Ratio Section
    md_content += "### Momentum Ratio\n\n"
    momentum_ratio = calculate_momentum_ratio(stock_data)

    md_content += "**Momentum Ratio Formula:** Price Change % / (Standard Deviation * 100)\n\n"

    md_content += "**1-Year Momentum Components:**\n"
    md_content += f"- Price Change: {momentum_ratio['components']['one_year']['price_change_percent']:.2f}%\n"
    md_content += f"- Standard Deviation: {momentum_ratio['components']['one_year']['standard_deviation']:.2f}%\n"
    md_content += f"- Momentum Ratio: {momentum_ratio['momentum_ratios']['one_year']:.4f}\n"
    if one_year_rank is not None and total_stocks is not None:
        md_content += f"- Rank: {one_year_rank} out of {total_stocks}\n\n"

    md_content += "**6-Month Momentum Components:**\n"
    md_content += f"- Price Change: {momentum_ratio['components']['six_month']['price_change_percent']:.2f}%\n"
    md_content += f"- Standard Deviation: {momentum_ratio['components']['six_month']['standard_deviation']:.2f}%\n"
    md_content += f"- Momentum Ratio: {momentum_ratio['momentum_ratios']['six_month']:.4f}\n"
    if six_month_rank is not None and total_stocks is not None:
        md_content += f"- Rank: {six_month_rank} out of {total_stocks}\n\n"

    return md_content

# %%
def parse_stock_list(stock_list_text):
    stocks = []
    lines = stock_list_text.strip().split('\n')

    for line in lines:
        if '\t' in line:
            parts = line.split('\t')
            if len(parts) >= 2:
                company_name = parts[0].strip()
                symbol = parts[1].strip()
                if company_name not in ['Company Name', ''] and symbol not in ['Symbol', '']:
                    stocks.append((company_name, symbol))

    return stocks

# %%
# Example usage:
stock_list_nifty = """Company Name	Symbol
Adani Enterprises Ltd.	ADANIENT
Adani Ports and Special Economic Zone Ltd.	ADANIPORTS
Apollo Hospitals Enterprise Ltd.	APOLLOHOSP
Asian Paints Ltd.	ASIANPAINT
Axis Bank Ltd.	AXISBANK
Bajaj Auto Ltd.	BAJAJ-AUTO
Bajaj Finance Ltd.	BAJFINANCE
Bajaj Finserv Ltd.	BAJAJFINSV
Bharat Electronics Ltd.	BEL
Bharti Airtel Ltd.	BHARTIARTL
Cipla Ltd.	CIPLA
Coal India Ltd.	COALINDIA
Dr. Reddy's Laboratories Ltd.	DRREDDY
Eicher Motors Ltd.	EICHERMOT
Grasim Industries Ltd.	GRASIM
HCL Technologies Ltd.	HCLTECH
HDFC Bank Ltd.	HDFCBANK
HDFC Life Insurance Company Ltd.	HDFCLIFE
Hero MotoCorp Ltd.	HEROMOTOCO
Hindalco Industries Ltd.	HINDALCO
Hindustan Unilever Ltd.	HINDUNILVR
ICICI Bank Ltd.	ICICIBANK
ITC Ltd.	ITC
IndusInd Bank Ltd.	INDUSINDBK
Infosys Ltd.	INFY
JSW Steel Ltd.	JSWSTEEL
Jio Financial Services Ltd.	JIOFIN
Kotak Mahindra Bank Ltd.	KOTAKBANK
Larsen & Toubro Ltd.	LT
Mahindra & Mahindra Ltd.	M&M
Maruti Suzuki India Ltd.	MARUTI
NTPC Ltd.	NTPC
Nestle India Ltd.	NESTLEIND
Oil & Natural Gas Corporation Ltd.	ONGC
Power Grid Corporation of India Ltd.	POWERGRID
Reliance Industries Ltd.	RELIANCE
SBI Life Insurance Company Ltd.	SBILIFE
Shriram Finance Ltd.	SHRIRAMFIN
State Bank of India	SBIN
Sun Pharmaceutical Industries Ltd.	SUNPHARMA
Tata Consultancy Services Ltd.	TCS
Tata Consumer Products Ltd.	TATACONSUM
Tata Motors Ltd.	TATAMOTORS
Tata Steel Ltd.	TATASTEEL
Tech Mahindra Ltd.	TECHM
Titan Company Ltd.	TITAN
Trent Ltd.	TRENT
UltraTech Cement Ltd.	ULTRACEMCO
Wipro Ltd.	WIPRO
Zomato Ltd.	ZOMATO"""

stocks_nifty = parse_stock_list(stock_list_nifty)
results = analyze_stocks(stocks_nifty, output_dir="stock_analysis/reports_v2/nifty_50", max_workers=10, end_date="2025-04-12")
# Out:
# 2025-04-13 16:39:55,705 - INFO - Processing Adani Enterprises Ltd. (ADANIENT)
# 2025-04-13 16:39:55,707 - INFO - Processing Adani Ports and Special Economic Zone Ltd. (ADANIPORTS)
# 2025-04-13 16:39:55,712 - INFO - Processing Apollo Hospitals Enterprise Ltd. (APOLLOHOSP)
# 2025-04-13 16:39:55,714 - INFO - Processing Asian Paints Ltd. (ASIANPAINT)
# 2025-04-13 16:39:55,718 - INFO - Processing Axis Bank Ltd. (AXISBANK)
# 2025-04-13 16:39:55,718 - INFO - Processing Bajaj Auto Ltd. (BAJAJ-AUTO)
# 2025-04-13 16:39:55,720 - INFO - Processing Bajaj Finance Ltd. (BAJFINANCE)
# 2025-04-13 16:39:55,722 - INFO - Processing Bajaj Finserv Ltd. (BAJAJFINSV)
# 2025-04-13 16:39:55,724 - INFO - Processing Bharat Electronics Ltd. (BEL)
# 2025-04-13 16:39:55,726 - INFO - Processing Bharti Airtel Ltd. (BHARTIARTL)
# 2025-04-13 16:39:57,103 - INFO - AXISBANK.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-07-06']
# 2025-04-13 16:39:57,135 - INFO - Verified unique data for ADANIPORTS: Latest price = Rs.1164.55
# 2025-04-13 16:39:57,151 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:39:57,184 - INFO - Verified unique data for ASIANPAINT: Latest price = Rs.2393.60
# 2025-04-13 16:39:57,184 - INFO - ADANIENT.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-07-06']
# 2025-04-13 16:39:57,198 - INFO - APOLLOHOSP.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-08-18']
# 2025-04-13 16:39:57,230 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:39:57,264 - INFO - Processing Cipla Ltd. (CIPLA)
# 2025-04-13 16:39:57,323 - INFO - Verified unique data for BAJAJFINSV: Latest price = Rs.1946.30
# 2025-04-13 16:39:57,403 - INFO - Verified unique data for BHARTIARTL: Latest price = Rs.1756.60
# 2025-04-13 16:39:57,409 - INFO - Verified unique data for BAJAJ-AUTO: Latest price = Rs.7768.85
# 2025-04-13 16:39:57,409 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:39:57,409 - INFO - Verified unique data for BEL: Latest price = Rs.285.00
# 2025-04-13 16:39:57,419 - INFO - Processing Coal India Ltd. (COALINDIA)
# 2025-04-13 16:39:57,419 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:39:57,435 - INFO - Verified unique data for AXISBANK: Latest price = Rs.1068.95
# 2025-04-13 16:39:57,435 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:39:57,466 - INFO - Verified unique data for ADANIENT: Latest price = Rs.2321.40
# 2025-04-13 16:39:57,466 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:39:57,482 - INFO - Verified unique data for BAJFINANCE: Latest price = Rs.8921.10
# 2025-04-13 16:39:57,482 - INFO - Processing Dr. Reddy's Laboratories Ltd. (DRREDDY)
# 2025-04-13 16:39:57,482 - INFO - Verified unique data for APOLLOHOSP: Latest price = Rs.6780.95
# 2025-04-13 16:39:57,514 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:39:57,523 - INFO - Processing Eicher Motors Ltd. (EICHERMOT)
# 2025-04-13 16:39:57,545 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:39:57,576 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:39:57,576 - INFO - Processing Grasim Industries Ltd. (GRASIM)
# 2025-04-13 16:39:57,592 - INFO - Processing HCL Technologies Ltd. (HCLTECH)
# 2025-04-13 16:39:57,592 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:39:57,640 - INFO - Processing HDFC Bank Ltd. (HDFCBANK)
# 2025-04-13 16:39:57,688 - INFO - Processing HDFC Life Insurance Company Ltd. (HDFCLIFE)
# 2025-04-13 16:39:57,688 - INFO - Processing Hero MotoCorp Ltd. (HEROMOTOCO)
# 2025-04-13 16:39:57,732 - INFO - Processing Hindalco Industries Ltd. (HINDALCO)
# 2025-04-13 16:39:58,580 - INFO - CIPLA.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-07-21']
# 2025-04-13 16:39:58,601 - INFO - Verified unique data for CIPLA: Latest price = Rs.1463.05
# 2025-04-13 16:39:58,604 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:39:58,639 - INFO - Processing Hindustan Unilever Ltd. (HINDUNILVR)
# 2025-04-13 16:39:58,842 - INFO - Verified unique data for COALINDIA: Latest price = Rs.392.10
# 2025-04-13 16:39:58,872 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:39:58,980 - INFO - Verified unique data for DRREDDY: Latest price = Rs.1109.50
# 2025-04-13 16:39:58,984 - INFO - Processing ICICI Bank Ltd. (ICICIBANK)
# 2025-04-13 16:39:59,041 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:39:59,053 - INFO - Verified unique data for EICHERMOT: Latest price = Rs.5350.90
# 2025-04-13 16:39:59,132 - INFO - Verified unique data for HDFCLIFE: Latest price = Rs.685.55
# 2025-04-13 16:39:59,140 - INFO - Verified unique data for GRASIM: Latest price = Rs.2651.25
# 2025-04-13 16:39:59,149 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:39:59,173 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:39:59,177 - INFO - Verified unique data for HCLTECH: Latest price = Rs.1390.55
# 2025-04-13 16:39:59,180 - INFO - Processing ITC Ltd. (ITC)
# 2025-04-13 16:39:59,183 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:39:59,207 - INFO - Verified unique data for HEROMOTOCO: Latest price = Rs.3666.00
# 2025-04-13 16:39:59,251 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:39:59,251 - INFO - Processing IndusInd Bank Ltd. (INDUSINDBK)
# 2025-04-13 16:39:59,264 - INFO - Processing Infosys Ltd. (INFY)
# 2025-04-13 16:39:59,287 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:39:59,293 - INFO - Verified unique data for HINDALCO: Latest price = Rs.600.30
# 2025-04-13 16:39:59,315 - INFO - Verified unique data for HDFCBANK: Latest price = Rs.1806.75
# 2025-04-13 16:39:59,328 - INFO - Processing JSW Steel Ltd. (JSWSTEEL)
# 2025-04-13 16:39:59,342 - INFO - Processing Jio Financial Services Ltd. (JIOFIN)
# 2025-04-13 16:39:59,368 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:39:59,377 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:39:59,380 - INFO - Processing Kotak Mahindra Bank Ltd. (KOTAKBANK)
# 2025-04-13 16:39:59,436 - INFO - Processing Larsen & Toubro Ltd. (LT)
# 2025-04-13 16:39:59,447 - INFO - Processing Mahindra & Mahindra Ltd. (M&M)
# 2025-04-13 16:39:59,880 - INFO - Verified unique data for HINDUNILVR: Latest price = Rs.2366.15
# 2025-04-13 16:39:59,881 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:39:59,912 - INFO - Processing Maruti Suzuki India Ltd. (MARUTI)
# 2025-04-13 16:40:00,236 - INFO - ICICIBANK.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-08-08']
# 2025-04-13 16:40:00,257 - INFO - Verified unique data for ICICIBANK: Latest price = Rs.1311.65
# 2025-04-13 16:40:00,258 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:00,296 - INFO - Processing NTPC Ltd. (NTPC)
# 2025-04-13 16:40:00,471 - INFO - Verified unique data for ITC: Latest price = Rs.421.55
# 2025-04-13 16:40:00,472 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:00,534 - INFO - Processing Nestle India Ltd. (NESTLEIND)
# 2025-04-13 16:40:00,607 - INFO - Verified unique data for INDUSINDBK: Latest price = Rs.689.50
# 2025-04-13 16:40:00,615 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:00,735 - INFO - Processing Oil & Natural Gas Corporation Ltd. (ONGC)
# 2025-04-13 16:40:00,741 - INFO - Verified unique data for INFY: Latest price = Rs.1409.45
# 2025-04-13 16:40:00,764 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:00,812 - INFO - Verified unique data for JSWSTEEL: Latest price = Rs.990.25
# 2025-04-13 16:40:00,816 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:00,879 - INFO - Processing Power Grid Corporation of India Ltd. (POWERGRID)
# 2025-04-13 16:40:00,909 - INFO - Verified unique data for KOTAKBANK: Latest price = Rs.2111.20
# 2025-04-13 16:40:00,911 - INFO - Processing Reliance Industries Ltd. (RELIANCE)
# 2025-04-13 16:40:00,917 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:00,926 - INFO - Verified unique data for LT: Latest price = Rs.3115.95
# 2025-04-13 16:40:00,929 - INFO - Verified unique data for M&M: Latest price = Rs.2580.35
# 2025-04-13 16:40:00,957 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:00,969 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:00,970 - INFO - Processing SBI Life Insurance Company Ltd. (SBILIFE)
# 2025-04-13 16:40:01,043 - INFO - Processing Shriram Finance Ltd. (SHRIRAMFIN)
# 2025-04-13 16:40:01,046 - INFO - Processing State Bank of India (SBIN)
# 2025-04-13 16:40:01,088 - INFO - Verified unique data for JIOFIN: Latest price = Rs.230.02
# 2025-04-13 16:40:01,089 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:01,143 - INFO - Processing Sun Pharmaceutical Industries Ltd. (SUNPHARMA)
# 2025-04-13 16:40:01,154 - INFO - Verified unique data for MARUTI: Latest price = Rs.11599.05
# 2025-04-13 16:40:01,155 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:01,186 - INFO - Processing Tata Consultancy Services Ltd. (TCS)
# 2025-04-13 16:40:01,471 - INFO - Verified unique data for NTPC: Latest price = Rs.360.10
# 2025-04-13 16:40:01,472 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:01,500 - INFO - Processing Tata Consumer Products Ltd. (TATACONSUM)
# 2025-04-13 16:40:01,790 - INFO - Verified unique data for NESTLEIND: Latest price = Rs.2361.40
# 2025-04-13 16:40:01,791 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:01,820 - INFO - Processing Tata Motors Ltd. (TATAMOTORS)
# 2025-04-13 16:40:02,007 - INFO - Verified unique data for ONGC: Latest price = Rs.230.37
# 2025-04-13 16:40:02,008 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:02,043 - INFO - Processing Tata Steel Ltd. (TATASTEEL)
# 2025-04-13 16:40:02,122 - INFO - Verified unique data for POWERGRID: Latest price = Rs.304.10
# 2025-04-13 16:40:02,123 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:02,178 - INFO - Processing Tech Mahindra Ltd. (TECHM)
# 2025-04-13 16:40:02,239 - INFO - Verified unique data for RELIANCE: Latest price = Rs.1218.95
# 2025-04-13 16:40:02,248 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:02,341 - INFO - Verified unique data for SBILIFE: Latest price = Rs.1521.90
# 2025-04-13 16:40:02,359 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:02,360 - INFO - Processing Titan Company Ltd. (TITAN)
# 2025-04-13 16:40:02,364 - INFO - Verified unique data for SBIN: Latest price = Rs.753.85
# 2025-04-13 16:40:02,424 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:02,435 - INFO - Processing Trent Ltd. (TRENT)
# 2025-04-13 16:40:02,457 - INFO - Verified unique data for SHRIRAMFIN: Latest price = Rs.638.80
# 2025-04-13 16:40:02,505 - INFO - Verified unique data for SUNPHARMA: Latest price = Rs.1687.55
# 2025-04-13 16:40:02,516 - INFO - Processing UltraTech Cement Ltd. (ULTRACEMCO)
# 2025-04-13 16:40:02,520 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:02,524 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:02,536 - INFO - Verified unique data for TCS: Latest price = Rs.3231.50
# 2025-04-13 16:40:02,589 - INFO - Processing Wipro Ltd. (WIPRO)
# 2025-04-13 16:40:02,590 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:02,600 - INFO - Processing Zomato Ltd. (ZOMATO)
# 2025-04-13 16:40:02,726 - INFO - Verified unique data for TATACONSUM: Latest price = Rs.1097.90
# 2025-04-13 16:40:02,727 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:03,147 - INFO - Verified unique data for TATAMOTORS: Latest price = Rs.595.05
# 2025-04-13 16:40:03,148 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:03,269 - INFO - Verified unique data for TATASTEEL: Latest price = Rs.133.42
# 2025-04-13 16:40:03,270 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:03,503 - INFO - Verified unique data for TECHM: Latest price = Rs.1282.25
# 2025-04-13 16:40:03,504 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:03,621 - INFO - TITAN.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-06-26']
# 2025-04-13 16:40:03,643 - INFO - Verified unique data for TITAN: Latest price = Rs.3234.90
# 2025-04-13 16:40:03,644 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:03,705 - INFO - Verified unique data for TRENT: Latest price = Rs.4780.55
# 2025-04-13 16:40:03,706 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:03,811 - INFO - Verified unique data for ULTRACEMCO: Latest price = Rs.11502.65
# 2025-04-13 16:40:03,812 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:03,858 - INFO - Verified unique data for ZOMATO: Latest price = Rs.211.39
# 2025-04-13 16:40:03,867 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:03,910 - INFO - Verified unique data for WIPRO: Latest price = Rs.239.75
# 2025-04-13 16:40:03,914 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)

# %%
stock_list_midcap = """Company Name	Symbol
360 ONE WAM Ltd.	360ONE
3M India Ltd.	3MINDIA
ACC Ltd.	ACC
AIA Engineering Ltd.	AIAENG
APL Apollo Tubes Ltd.	APLAPOLLO
AU Small Finance Bank Ltd.	AUBANK
Abbott India Ltd.	ABBOTINDIA
Adani Total Gas Ltd.	ATGL
Adani Wilmar Ltd.	AWL
Aditya Birla Capital Ltd.	ABCAPITAL
Aditya Birla Fashion and Retail Ltd.	ABFRL
Ajanta Pharmaceuticals Ltd.	AJANTPHARM
Alkem Laboratories Ltd.	ALKEM
Apar Industries Ltd.	APARINDS
Apollo Tyres Ltd.	APOLLOTYRE
Ashok Leyland Ltd.	ASHOKLEY
Astral Ltd.	ASTRAL
Aurobindo Pharma Ltd.	AUROPHARMA
BSE Ltd.	BSE
Balkrishna Industries Ltd.	BALKRISIND
Bandhan Bank Ltd.	BANDHANBNK
Bank of India	BANKINDIA
Bank of Maharashtra	MAHABANK
Berger Paints India Ltd.	BERGEPAINT
Bharat Dynamics Ltd.	BDL
Bharat Forge Ltd.	BHARATFORG
Bharat Heavy Electricals Ltd.	BHEL
Bharti Hexacom Ltd.	BHARTIHEXA
Biocon Ltd.	BIOCON
Blue Star Ltd.	BLUESTARCO
CRISIL Ltd.	CRISIL
Cochin Shipyard Ltd.	COCHINSHIP
Coforge Ltd.	COFORGE
Colgate Palmolive (India) Ltd.	COLPAL
Container Corporation of India Ltd.	CONCOR
Coromandel International Ltd.	COROMANDEL
Cummins India Ltd.	CUMMINSIND
Dalmia Bharat Ltd.	DALBHARAT
Deepak Nitrite Ltd.	DEEPAKNTR
Dixon Technologies (India) Ltd.	DIXON
Emami Ltd.	EMAMILTD
Endurance Technologies Ltd.	ENDURANCE
Escorts Kubota Ltd.	ESCORTS
Exide Industries Ltd.	EXIDEIND
FSN E-Commerce Ventures Ltd.	NYKAA
Federal Bank Ltd.	FEDERALBNK
Fortis Healthcare Ltd.	FORTIS
GE Vernova T&D India Ltd.	GVT&D
GMR Airports Ltd.	GMRAIRPORT
General Insurance Corporation of India	GICRE
Gland Pharma Ltd.	GLAND
Glaxosmithkline Pharmaceuticals Ltd.	GLAXO
Glenmark Pharmaceuticals Ltd.	GLENMARK
Global Health Ltd.	MEDANTA
Godrej Industries Ltd.	GODREJIND
Godrej Properties Ltd.	GODREJPROP
Gujarat Fluorochemicals Ltd.	FLUOROCHEM
Gujarat Gas Ltd.	GUJGASLTD
HDFC Asset Management Company Ltd.	HDFCAMC
Hindustan Petroleum Corporation Ltd.	HINDPETRO
Hindustan Zinc Ltd.	HINDZINC
Hitachi Energy India Ltd.	POWERINDIA
Honeywell Automation India Ltd.	HONAUT
Housing & Urban Development Corporation Ltd.	HUDCO
IDFC First Bank Ltd.	IDFCFIRSTB
IRB Infrastructure Developers Ltd.	IRB
Indian Bank	INDIANB
Indian Railway Catering And Tourism Corporation Ltd.	IRCTC
Indian Renewable Energy Development Agency Ltd.	IREDA
Indraprastha Gas Ltd.	IGL
Indus Towers Ltd.	INDUSTOWER
Ipca Laboratories Ltd.	IPCALAB
J.K. Cement Ltd.	JKCEMENT
JSW Infrastructure Ltd.	JSWINFRA
Jindal Stainless Ltd.	JSL
Jubilant Foodworks Ltd.	JUBLFOOD
K.P.R. Mill Ltd.	KPRMILL
KEI Industries Ltd.	KEI
KPIT Technologies Ltd.	KPITTECH
Kalyan Jewellers India Ltd.	KALYANKJIL
L&T Finance Ltd.	LTF
L&T Technology Services Ltd.	LTTS
LIC Housing Finance Ltd.	LICHSGFIN
Linde India Ltd.	LINDEINDIA
Lloyds Metals And Energy Ltd.	LLOYDSME
Lupin Ltd.	LUPIN
MRF Ltd.	MRF
Mahindra & Mahindra Financial Services Ltd.	M&MFIN
Mangalore Refinery & Petrochemicals Ltd.	MRPL
Mankind Pharma Ltd.	MANKIND
Marico Ltd.	MARICO
Max Financial Services Ltd.	MFSL
Max Healthcare Institute Ltd.	MAXHEALTH
Mazagoan Dock Shipbuilders Ltd.	MAZDOCK
Motherson Sumi Wiring India Ltd.	MSUMI
Motilal Oswal Financial Services Ltd.	MOTILALOFS
MphasiS Ltd.	MPHASIS
Muthoot Finance Ltd.	MUTHOOTFIN
NHPC Ltd.	NHPC
NLC India Ltd.	NLCINDIA
NMDC Ltd.	NMDC
NTPC Green Energy Ltd.	NTPCGREEN
National Aluminium Co. Ltd.	NATIONALUM
Nippon Life India Asset Management Ltd.	NAM-INDIA
Oberoi Realty Ltd.	OBEROIRLTY
Oil India Ltd.	OIL
Ola Electric Mobility Ltd.	OLAELEC
One 97 Communications Ltd.	PAYTM
Oracle Financial Services Software Ltd.	OFSS
PB Fintech Ltd.	POLICYBZR
PI Industries Ltd.	PIIND
Page Industries Ltd.	PAGEIND
Patanjali Foods Ltd.	PATANJALI
Persistent Systems Ltd.	PERSISTENT
Petronet LNG Ltd.	PETRONET
Phoenix Mills Ltd.	PHOENIXLTD
Polycab India Ltd.	POLYCAB
Premier Energies Ltd.	PREMIERENE
Prestige Estates Projects Ltd.	PRESTIGE
Rail Vikas Nigam Ltd.	RVNL
SBI Cards and Payment Services Ltd.	SBICARD
SJVN Ltd.	SJVN
SRF Ltd.	SRF
Schaeffler India Ltd.	SCHAEFFLER
Solar Industries India Ltd.	SOLARINDS
Sona BLW Precision Forgings Ltd.	SONACOMS
Star Health and Allied Insurance Company Ltd.	STARHEALTH
Steel Authority of India Ltd.	SAIL
Sun TV Network Ltd.	SUNTV
Sundaram Finance Ltd.	SUNDARMFIN
Supreme Industries Ltd.	SUPREMEIND
Suzlon Energy Ltd.	SUZLON
Syngene International Ltd.	SYNGENE
Tata Communications Ltd.	TATACOMM
Tata Elxsi Ltd.	TATAELXSI
Tata Investment Corporation Ltd.	TATAINVEST
Tata Technologies Ltd.	TATATECH
The New India Assurance Company Ltd.	NIACL
Thermax Ltd.	THERMAX
Torrent Power Ltd.	TORNTPOWER
Tube Investments of India Ltd.	TIINDIA
UNO Minda Ltd.	UNOMINDA
UPL Ltd.	UPL
Union Bank of India	UNIONBANK
United Breweries Ltd.	UBL
Vishal Mega Mart Ltd.	VMM
Vodafone Idea Ltd.	IDEA
Voltas Ltd.	VOLTAS
Waaree Energies Ltd.	WAAREEENER
Yes Bank Ltd.	YESBANK"""


stocks_midcap = parse_stock_list(stock_list_midcap)
results = analyze_stocks(stocks_midcap, output_dir="stock_analysis/reports_v2/midcap_150", max_workers=10, end_date="2025-04-12")
# Out:
# 2025-04-13 16:40:05,167 - INFO - Processing 360 ONE WAM Ltd. (360ONE)
# 2025-04-13 16:40:05,169 - INFO - Processing 3M India Ltd. (3MINDIA)
# 2025-04-13 16:40:05,170 - INFO - Processing ACC Ltd. (ACC)
# 2025-04-13 16:40:05,170 - INFO - Processing AIA Engineering Ltd. (AIAENG)
# 2025-04-13 16:40:05,172 - INFO - Processing APL Apollo Tubes Ltd. (APLAPOLLO)
# 2025-04-13 16:40:05,174 - INFO - Processing AU Small Finance Bank Ltd. (AUBANK)
# 2025-04-13 16:40:05,175 - INFO - Processing Abbott India Ltd. (ABBOTINDIA)
# 2025-04-13 16:40:05,177 - INFO - Processing Adani Total Gas Ltd. (ATGL)
# 2025-04-13 16:40:05,179 - INFO - Processing Adani Wilmar Ltd. (AWL)
# 2025-04-13 16:40:05,180 - INFO - Processing Aditya Birla Capital Ltd. (ABCAPITAL)
# 2025-04-13 16:40:06,396 - INFO - Verified unique data for AWL: Latest price = Rs.272.55
# 2025-04-13 16:40:06,406 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:06,609 - INFO - Verified unique data for AUBANK: Latest price = Rs.557.10
# 2025-04-13 16:40:06,635 - INFO - Processing Aditya Birla Fashion and Retail Ltd. (ABFRL)
# 2025-04-13 16:40:06,636 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:06,662 - INFO - Verified unique data for AIAENG: Latest price = Rs.3168.75
# 2025-04-13 16:40:06,673 - INFO - Verified unique data for ABCAPITAL: Latest price = Rs.185.33
# 2025-04-13 16:40:06,737 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:06,757 - INFO - Verified unique data for 360ONE: Latest price = Rs.870.20
# 2025-04-13 16:40:06,768 - INFO - Verified unique data for ACC: Latest price = Rs.2007.35
# 2025-04-13 16:40:06,774 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:06,783 - INFO - Processing Ajanta Pharmaceuticals Ltd. (AJANTPHARM)
# 2025-04-13 16:40:06,819 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:06,829 - INFO - Verified unique data for APLAPOLLO: Latest price = Rs.1517.35
# 2025-04-13 16:40:06,832 - INFO - Verified unique data for ABBOTINDIA: Latest price = Rs.29641.10
# 2025-04-13 16:40:06,836 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:06,859 - INFO - Processing Alkem Laboratories Ltd. (ALKEM)
# 2025-04-13 16:40:06,870 - INFO - Verified unique data for ATGL: Latest price = Rs.592.05
# 2025-04-13 16:40:06,898 - INFO - Processing Apar Industries Ltd. (APARINDS)
# 2025-04-13 16:40:06,901 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:06,911 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:06,912 - INFO - Processing Apollo Tyres Ltd. (APOLLOTYRE)
# 2025-04-13 16:40:06,937 - INFO - Verified unique data for 3MINDIA: Latest price = Rs.29006.30
# 2025-04-13 16:40:06,947 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:06,950 - INFO - Processing Ashok Leyland Ltd. (ASHOKLEY)
# 2025-04-13 16:40:07,002 - INFO - Processing Astral Ltd. (ASTRAL)
# 2025-04-13 16:40:07,012 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:07,014 - INFO - Processing Aurobindo Pharma Ltd. (AUROPHARMA)
# 2025-04-13 16:40:07,045 - INFO - Processing BSE Ltd. (BSE)
# 2025-04-13 16:40:07,077 - INFO - Processing Balkrishna Industries Ltd. (BALKRISIND)
# 2025-04-13 16:40:07,857 - INFO - Verified unique data for ABFRL: Latest price = Rs.254.00
# 2025-04-13 16:40:07,858 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:07,896 - INFO - Processing Bandhan Bank Ltd. (BANDHANBNK)
# 2025-04-13 16:40:08,065 - INFO - Verified unique data for AJANTPHARM: Latest price = Rs.2565.40
# 2025-04-13 16:40:08,066 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:08,135 - INFO - Processing Bank of India (BANKINDIA)
# 2025-04-13 16:40:08,149 - INFO - Verified unique data for ALKEM: Latest price = Rs.4887.45
# 2025-04-13 16:40:08,150 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:08,282 - INFO - Processing Bank of Maharashtra (MAHABANK)
# 2025-04-13 16:40:08,321 - INFO - Verified unique data for APARINDS: Latest price = Rs.5028.40
# 2025-04-13 16:40:08,337 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:08,342 - INFO - ASHOKLEY.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-07-06']
# 2025-04-13 16:40:08,465 - INFO - BSE.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-08-04']
# 2025-04-13 16:40:08,475 - INFO - Verified unique data for ASTRAL: Latest price = Rs.1248.90
# 2025-04-13 16:40:08,485 - INFO - Processing Berger Paints India Ltd. (BERGEPAINT)
# 2025-04-13 16:40:08,509 - INFO - Verified unique data for APOLLOTYRE: Latest price = Rs.427.75
# 2025-04-13 16:40:08,527 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:08,547 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:08,552 - INFO - Verified unique data for AUROPHARMA: Latest price = Rs.1082.45
# 2025-04-13 16:40:08,600 - INFO - Verified unique data for ASHOKLEY: Latest price = Rs.208.50
# 2025-04-13 16:40:08,608 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:08,624 - INFO - Verified unique data for BSE: Latest price = Rs.5644.75
# 2025-04-13 16:40:08,626 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:08,629 - INFO - Verified unique data for BALKRISIND: Latest price = Rs.2337.50
# 2025-04-13 16:40:08,630 - INFO - Processing Bharat Dynamics Ltd. (BDL)
# 2025-04-13 16:40:08,632 - INFO - Processing Bharat Forge Ltd. (BHARATFORG)
# 2025-04-13 16:40:08,661 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:08,664 - INFO - Processing Bharat Heavy Electricals Ltd. (BHEL)
# 2025-04-13 16:40:08,687 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:08,695 - INFO - Processing Bharti Hexacom Ltd. (BHARTIHEXA)
# 2025-04-13 16:40:08,728 - INFO - Processing Biocon Ltd. (BIOCON)
# 2025-04-13 16:40:08,759 - INFO - Processing Blue Star Ltd. (BLUESTARCO)
# 2025-04-13 16:40:09,042 - INFO - Verified unique data for BANDHANBNK: Latest price = Rs.149.68
# 2025-04-13 16:40:09,043 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:09,073 - INFO - Processing CRISIL Ltd. (CRISIL)
# 2025-04-13 16:40:09,310 - INFO - Verified unique data for BANKINDIA: Latest price = Rs.108.16
# 2025-04-13 16:40:09,313 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:09,346 - INFO - Processing Cochin Shipyard Ltd. (COCHINSHIP)
# 2025-04-13 16:40:09,530 - INFO - MAHABANK.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-06-02']
# 2025-04-13 16:40:09,553 - INFO - Verified unique data for MAHABANK: Latest price = Rs.45.66
# 2025-04-13 16:40:09,554 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:09,583 - INFO - Processing Coforge Ltd. (COFORGE)
# 2025-04-13 16:40:09,701 - INFO - Verified unique data for BERGEPAINT: Latest price = Rs.530.50
# 2025-04-13 16:40:09,705 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:09,739 - INFO - Processing Colgate Palmolive (India) Ltd. (COLPAL)
# 2025-04-13 16:40:09,849 - INFO - Verified unique data for BDL: Latest price = Rs.1325.10
# 2025-04-13 16:40:09,850 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:09,885 - INFO - Processing Container Corporation of India Ltd. (CONCOR)
# 2025-04-13 16:40:09,963 - INFO - Verified unique data for BHARTIHEXA: Latest price = Rs.1504.75
# 2025-04-13 16:40:09,998 - INFO - BIOCON.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-07-06']
# 2025-04-13 16:40:10,003 - INFO - Verified unique data for BHARATFORG: Latest price = Rs.1002.15
# 2025-04-13 16:40:10,005 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:10,048 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:10,075 - INFO - Verified unique data for BHEL: Latest price = Rs.212.97
# 2025-04-13 16:40:10,124 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:10,130 - INFO - Verified unique data for BIOCON: Latest price = Rs.316.55
# 2025-04-13 16:40:10,134 - INFO - Processing Coromandel International Ltd. (COROMANDEL)
# 2025-04-13 16:40:10,148 - INFO - Verified unique data for BLUESTARCO: Latest price = Rs.1967.20
# 2025-04-13 16:40:10,172 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:10,174 - INFO - Processing Cummins India Ltd. (CUMMINSIND)
# 2025-04-13 16:40:10,190 - INFO - Processing Dalmia Bharat Ltd. (DALBHARAT)
# 2025-04-13 16:40:10,191 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:10,232 - INFO - Processing Deepak Nitrite Ltd. (DEEPAKNTR)
# 2025-04-13 16:40:10,263 - INFO - Processing Dixon Technologies (India) Ltd. (DIXON)
# 2025-04-13 16:40:10,363 - INFO - Verified unique data for CRISIL: Latest price = Rs.4215.85
# 2025-04-13 16:40:10,364 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:10,395 - INFO - Processing Emami Ltd. (EMAMILTD)
# 2025-04-13 16:40:10,536 - INFO - Verified unique data for COCHINSHIP: Latest price = Rs.1401.00
# 2025-04-13 16:40:10,537 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:10,568 - INFO - Processing Endurance Technologies Ltd. (ENDURANCE)
# 2025-04-13 16:40:10,768 - INFO - Verified unique data for COFORGE: Latest price = Rs.6316.65
# 2025-04-13 16:40:10,769 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:10,798 - INFO - Processing Escorts Kubota Ltd. (ESCORTS)
# 2025-04-13 16:40:10,903 - INFO - Verified unique data for COLPAL: Latest price = Rs.2491.65
# 2025-04-13 16:40:10,905 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:10,938 - INFO - Processing Exide Industries Ltd. (EXIDEIND)
# 2025-04-13 16:40:11,149 - INFO - Verified unique data for CONCOR: Latest price = Rs.684.80
# 2025-04-13 16:40:11,150 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:11,181 - INFO - Processing FSN E-Commerce Ventures Ltd. (NYKAA)
# 2025-04-13 16:40:11,336 - INFO - COROMANDEL.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-07-14']
# 2025-04-13 16:40:11,360 - INFO - Verified unique data for COROMANDEL: Latest price = Rs.2060.00
# 2025-04-13 16:40:11,369 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:11,436 - INFO - Processing Federal Bank Ltd. (FEDERALBNK)
# 2025-04-13 16:40:11,531 - INFO - Verified unique data for CUMMINSIND: Latest price = Rs.2814.95
# 2025-04-13 16:40:11,540 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:11,546 - INFO - Verified unique data for DEEPAKNTR: Latest price = Rs.1932.85
# 2025-04-13 16:40:11,584 - INFO - Verified unique data for DIXON: Latest price = Rs.14301.90
# 2025-04-13 16:40:11,585 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:11,595 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:11,596 - INFO - Processing Fortis Healthcare Ltd. (FORTIS)
# 2025-04-13 16:40:11,662 - INFO - Processing GE Vernova T&D India Ltd. (GVT&D)
# 2025-04-13 16:40:11,682 - INFO - Processing GMR Airports Ltd. (GMRAIRPORT)
# 2025-04-13 16:40:11,722 - INFO - Verified unique data for DALBHARAT: Latest price = Rs.1811.65
# 2025-04-13 16:40:11,723 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:11,816 - INFO - Processing General Insurance Corporation of India (GICRE)
# 2025-04-13 16:40:11,841 - INFO - Verified unique data for ENDURANCE: Latest price = Rs.1860.40
# 2025-04-13 16:40:11,843 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:11,855 - INFO - Verified unique data for EMAMILTD: Latest price = Rs.608.50
# 2025-04-13 16:40:11,878 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:11,908 - INFO - Processing Gland Pharma Ltd. (GLAND)
# 2025-04-13 16:40:11,919 - INFO - Processing Glaxosmithkline Pharmaceuticals Ltd. (GLAXO)
# 2025-04-13 16:40:12,038 - INFO - Verified unique data for ESCORTS: Latest price = Rs.3178.20
# 2025-04-13 16:40:12,039 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:12,068 - INFO - Processing Glenmark Pharmaceuticals Ltd. (GLENMARK)
# 2025-04-13 16:40:12,160 - INFO - Verified unique data for EXIDEIND: Latest price = Rs.369.30
# 2025-04-13 16:40:12,161 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:12,195 - INFO - Processing Global Health Ltd. (MEDANTA)
# 2025-04-13 16:40:12,366 - INFO - Verified unique data for NYKAA: Latest price = Rs.179.90
# 2025-04-13 16:40:12,367 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:12,396 - INFO - Processing Godrej Industries Ltd. (GODREJIND)
# 2025-04-13 16:40:12,622 - INFO - Verified unique data for FEDERALBNK: Latest price = Rs.190.44
# 2025-04-13 16:40:12,623 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:12,654 - INFO - Processing Godrej Properties Ltd. (GODREJPROP)
# 2025-04-13 16:40:12,872 - INFO - Verified unique data for GMRAIRPORT: Latest price = Rs.85.72
# 2025-04-13 16:40:12,874 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:12,911 - INFO - Verified unique data for GVT&D: Latest price = Rs.1771.10
# 2025-04-13 16:40:12,917 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:12,919 - INFO - Processing Gujarat Fluorochemicals Ltd. (FLUOROCHEM)
# 2025-04-13 16:40:13,000 - INFO - Processing Gujarat Gas Ltd. (GUJGASLTD)
# 2025-04-13 16:40:13,001 - INFO - Verified unique data for FORTIS: Latest price = Rs.649.55
# 2025-04-13 16:40:13,005 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:13,058 - INFO - Processing HDFC Asset Management Company Ltd. (HDFCAMC)
# 2025-04-13 16:40:13,071 - INFO - Verified unique data for GICRE: Latest price = Rs.397.35
# 2025-04-13 16:40:13,073 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:13,106 - INFO - Processing Hindustan Petroleum Corporation Ltd. (HINDPETRO)
# 2025-04-13 16:40:13,161 - INFO - Verified unique data for GLAXO: Latest price = Rs.2751.10
# 2025-04-13 16:40:13,166 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:13,195 - INFO - Verified unique data for GLAND: Latest price = Rs.1393.75
# 2025-04-13 16:40:13,204 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:13,212 - INFO - Processing Hindustan Zinc Ltd. (HINDZINC)
# 2025-04-13 16:40:13,246 - INFO - Processing Hitachi Energy India Ltd. (POWERINDIA)
# 2025-04-13 16:40:13,278 - INFO - Verified unique data for GLENMARK: Latest price = Rs.1378.10
# 2025-04-13 16:40:13,279 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:13,308 - INFO - Processing Honeywell Automation India Ltd. (HONAUT)
# 2025-04-13 16:40:13,330 - INFO - Verified unique data for MEDANTA: Latest price = Rs.1269.95
# 2025-04-13 16:40:13,331 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:13,360 - INFO - Processing Housing & Urban Development Corporation Ltd. (HUDCO)
# 2025-04-13 16:40:13,536 - INFO - Verified unique data for GODREJIND: Latest price = Rs.1136.70
# 2025-04-13 16:40:13,537 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:13,566 - INFO - Processing IDFC First Bank Ltd. (IDFCFIRSTB)
# 2025-04-13 16:40:13,800 - INFO - Verified unique data for GODREJPROP: Latest price = Rs.1948.40
# 2025-04-13 16:40:13,801 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:13,831 - INFO - Processing IRB Infrastructure Developers Ltd. (IRB)
# 2025-04-13 16:40:14,105 - INFO - Verified unique data for FLUOROCHEM: Latest price = Rs.3865.30
# 2025-04-13 16:40:14,106 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:14,142 - INFO - Processing Indian Bank (INDIANB)
# 2025-04-13 16:40:14,173 - INFO - Verified unique data for GUJGASLTD: Latest price = Rs.428.30
# 2025-04-13 16:40:14,174 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:14,204 - INFO - Processing Indian Railway Catering And Tourism Corporation Ltd. (IRCTC)
# 2025-04-13 16:40:14,296 - INFO - Verified unique data for HINDPETRO: Latest price = Rs.382.20
# 2025-04-13 16:40:14,297 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:14,346 - INFO - Processing Indian Renewable Energy Development Agency Ltd. (IREDA)
# 2025-04-13 16:40:14,369 - INFO - Verified unique data for HDFCAMC: Latest price = Rs.3987.25
# 2025-04-13 16:40:14,393 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:14,458 - INFO - Processing Indraprastha Gas Ltd. (IGL)
# 2025-04-13 16:40:14,459 - INFO - Verified unique data for HINDZINC: Latest price = Rs.411.05
# 2025-04-13 16:40:14,469 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:14,505 - INFO - Verified unique data for POWERINDIA: Latest price = Rs.11979.30
# 2025-04-13 16:40:14,513 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:14,513 - INFO - Processing Indus Towers Ltd. (INDUSTOWER)
# 2025-04-13 16:40:14,582 - INFO - Processing Ipca Laboratories Ltd. (IPCALAB)
# 2025-04-13 16:40:14,614 - INFO - Verified unique data for HUDCO: Latest price = Rs.215.81
# 2025-04-13 16:40:14,624 - INFO - Verified unique data for HONAUT: Latest price = Rs.34014.65
# 2025-04-13 16:40:14,624 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:14,625 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:14,680 - INFO - Processing J.K. Cement Ltd. (JKCEMENT)
# 2025-04-13 16:40:14,687 - INFO - Processing JSW Infrastructure Ltd. (JSWINFRA)
# 2025-04-13 16:40:14,729 - INFO - Verified unique data for IDFCFIRSTB: Latest price = Rs.59.92
# 2025-04-13 16:40:14,731 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:14,761 - INFO - Processing Jindal Stainless Ltd. (JSL)
# 2025-04-13 16:40:14,997 - INFO - Verified unique data for IRB: Latest price = Rs.45.01
# 2025-04-13 16:40:14,999 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:15,030 - INFO - Processing Jubilant Foodworks Ltd. (JUBLFOOD)
# 2025-04-13 16:40:15,363 - INFO - Verified unique data for INDIANB: Latest price = Rs.535.80
# 2025-04-13 16:40:15,365 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:15,426 - INFO - Processing K.P.R. Mill Ltd. (KPRMILL)
# 2025-04-13 16:40:15,437 - INFO - Verified unique data for IRCTC: Latest price = Rs.730.70
# 2025-04-13 16:40:15,438 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:15,468 - INFO - Processing KEI Industries Ltd. (KEI)
# 2025-04-13 16:40:15,489 - INFO - Verified unique data for IREDA: Latest price = Rs.154.20
# 2025-04-13 16:40:15,490 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:15,513 - INFO - Processing KPIT Technologies Ltd. (KPITTECH)
# 2025-04-13 16:40:15,664 - INFO - Verified unique data for IGL: Latest price = Rs.174.76
# 2025-04-13 16:40:15,665 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:15,698 - INFO - Processing Kalyan Jewellers India Ltd. (KALYANKJIL)
# 2025-04-13 16:40:15,839 - INFO - Verified unique data for INDUSTOWER: Latest price = Rs.373.65
# 2025-04-13 16:40:15,840 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:15,872 - INFO - Processing L&T Finance Ltd. (LTF)
# 2025-04-13 16:40:15,911 - INFO - Verified unique data for JKCEMENT: Latest price = Rs.4957.45
# 2025-04-13 16:40:15,912 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:15,962 - INFO - Processing L&T Technology Services Ltd. (LTTS)
# 2025-04-13 16:40:16,109 - INFO - Verified unique data for IPCALAB: Latest price = Rs.1330.95
# 2025-04-13 16:40:16,115 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:16,122 - INFO - Verified unique data for JSL: Latest price = Rs.542.05
# 2025-04-13 16:40:16,150 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:16,168 - INFO - Processing LIC Housing Finance Ltd. (LICHSGFIN)
# 2025-04-13 16:40:16,192 - INFO - Processing Linde India Ltd. (LINDEINDIA)
# 2025-04-13 16:40:16,275 - INFO - Verified unique data for JUBLFOOD: Latest price = Rs.685.30
# 2025-04-13 16:40:16,305 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:16,327 - INFO - Verified unique data for JSWINFRA: Latest price = Rs.296.10
# 2025-04-13 16:40:16,341 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:16,341 - INFO - Processing Lloyds Metals And Energy Ltd. (LLOYDSME)
# 2025-04-13 16:40:16,372 - INFO - Processing Lupin Ltd. (LUPIN)
# 2025-04-13 16:40:16,590 - INFO - Verified unique data for KPRMILL: Latest price = Rs.974.85
# 2025-04-13 16:40:16,591 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:16,620 - INFO - Processing MRF Ltd. (MRF)
# 2025-04-13 16:40:16,657 - INFO - Verified unique data for KEI: Latest price = Rs.2607.35
# 2025-04-13 16:40:16,659 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:16,688 - INFO - Processing Mahindra & Mahindra Financial Services Ltd. (M&MFIN)
# 2025-04-13 16:40:16,732 - INFO - Verified unique data for KPITTECH: Latest price = Rs.1118.95
# 2025-04-13 16:40:16,733 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:16,765 - INFO - Processing Mangalore Refinery & Petrochemicals Ltd. (MRPL)
# 2025-04-13 16:40:16,908 - INFO - Verified unique data for KALYANKJIL: Latest price = Rs.510.75
# 2025-04-13 16:40:16,909 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:16,942 - INFO - Processing Mankind Pharma Ltd. (MANKIND)
# 2025-04-13 16:40:17,024 - INFO - Verified unique data for LTF: Latest price = Rs.155.46
# 2025-04-13 16:40:17,025 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:17,057 - INFO - Processing Marico Ltd. (MARICO)
# 2025-04-13 16:40:17,171 - INFO - Verified unique data for LTTS: Latest price = Rs.4132.25
# 2025-04-13 16:40:17,172 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:17,208 - INFO - Processing Max Financial Services Ltd. (MFSL)
# 2025-04-13 16:40:17,450 - INFO - Verified unique data for LINDEINDIA: Latest price = Rs.5895.45
# 2025-04-13 16:40:17,452 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:17,485 - INFO - Verified unique data for LICHSGFIN: Latest price = Rs.559.65
# 2025-04-13 16:40:17,496 - INFO - Processing Max Healthcare Institute Ltd. (MAXHEALTH)
# 2025-04-13 16:40:17,497 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:17,528 - INFO - Processing Mazagoan Dock Shipbuilders Ltd. (MAZDOCK)
# 2025-04-13 16:40:17,608 - INFO - Verified unique data for LLOYDSME: Latest price = Rs.1197.35
# 2025-04-13 16:40:17,611 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:17,642 - INFO - Verified unique data for LUPIN: Latest price = Rs.1969.25
# 2025-04-13 16:40:17,646 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:17,676 - INFO - Processing Motherson Sumi Wiring India Ltd. (MSUMI)
# 2025-04-13 16:40:17,690 - INFO - Processing Motilal Oswal Financial Services Ltd. (MOTILALOFS)
# 2025-04-13 16:40:17,860 - INFO - Verified unique data for MRF: Latest price = Rs.117544.40
# 2025-04-13 16:40:17,861 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:17,906 - INFO - Processing MphasiS Ltd. (MPHASIS)
# 2025-04-13 16:40:17,943 - INFO - Verified unique data for M&MFIN: Latest price = Rs.263.10
# 2025-04-13 16:40:17,949 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:17,994 - INFO - Verified unique data for MRPL: Latest price = Rs.130.81
# 2025-04-13 16:40:17,996 - INFO - Processing Muthoot Finance Ltd. (MUTHOOTFIN)
# 2025-04-13 16:40:17,997 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:18,027 - INFO - Processing NHPC Ltd. (NHPC)
# 2025-04-13 16:40:18,072 - INFO - Verified unique data for MANKIND: Latest price = Rs.2350.50
# 2025-04-13 16:40:18,073 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:18,101 - INFO - Processing NLC India Ltd. (NLCINDIA)
# 2025-04-13 16:40:18,280 - INFO - Verified unique data for MARICO: Latest price = Rs.709.95
# 2025-04-13 16:40:18,281 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:18,316 - INFO - Processing NMDC Ltd. (NMDC)
# 2025-04-13 16:40:18,407 - INFO - Verified unique data for MFSL: Latest price = Rs.1163.30
# 2025-04-13 16:40:18,408 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:18,437 - INFO - Processing NTPC Green Energy Ltd. (NTPCGREEN)
# 2025-04-13 16:40:18,716 - INFO - Verified unique data for MAXHEALTH: Latest price = Rs.1089.30
# 2025-04-13 16:40:18,723 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:18,728 - INFO - Verified unique data for MAZDOCK: Latest price = Rs.2432.55
# 2025-04-13 16:40:18,751 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:18,761 - INFO - Processing National Aluminium Co. Ltd. (NATIONALUM)
# 2025-04-13 16:40:18,792 - INFO - Processing Nippon Life India Asset Management Ltd. (NAM-INDIA)
# 2025-04-13 16:40:18,909 - INFO - Verified unique data for MSUMI: Latest price = Rs.52.92
# 2025-04-13 16:40:18,927 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:18,968 - INFO - Processing Oberoi Realty Ltd. (OBEROIRLTY)
# 2025-04-13 16:40:18,971 - INFO - MOTILALOFS.NS: 1d: price-repair-split: Corrected: 2023-04-12 -> 2023-12-29
# 2025-04-13 16:40:18,984 - INFO - Verified unique data for MOTILALOFS: Latest price = Rs.606.20
# 2025-04-13 16:40:18,985 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:19,021 - INFO - Processing Oil India Ltd. (OIL)
# 2025-04-13 16:40:19,193 - INFO - Verified unique data for MPHASIS: Latest price = Rs.2160.55
# 2025-04-13 16:40:19,207 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:19,211 - INFO - Verified unique data for MUTHOOTFIN: Latest price = Rs.2017.00
# 2025-04-13 16:40:19,265 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:19,293 - INFO - Processing Ola Electric Mobility Ltd. (OLAELEC)
# 2025-04-13 16:40:19,320 - INFO - Verified unique data for NHPC: Latest price = Rs.84.20
# 2025-04-13 16:40:19,323 - INFO - Processing One 97 Communications Ltd. (PAYTM)
# 2025-04-13 16:40:19,335 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:19,399 - INFO - Verified unique data for NLCINDIA: Latest price = Rs.229.49
# 2025-04-13 16:40:19,400 - INFO - Processing Oracle Financial Services Software Ltd. (OFSS)
# 2025-04-13 16:40:19,401 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:19,431 - INFO - Processing PB Fintech Ltd. (POLICYBZR)
# 2025-04-13 16:40:19,560 - INFO - Verified unique data for NTPCGREEN: Latest price = Rs.95.79
# 2025-04-13 16:40:19,561 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:19,594 - INFO - Verified unique data for NMDC: Latest price = Rs.62.91
# 2025-04-13 16:40:19,594 - INFO - Processing PI Industries Ltd. (PIIND)
# 2025-04-13 16:40:19,595 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:19,625 - INFO - Processing Page Industries Ltd. (PAGEIND)
# 2025-04-13 16:40:20,024 - INFO - Verified unique data for NATIONALUM: Latest price = Rs.143.22
# 2025-04-13 16:40:20,030 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:20,066 - INFO - Verified unique data for NAM-INDIA: Latest price = Rs.551.10
# 2025-04-13 16:40:20,074 - INFO - Processing Patanjali Foods Ltd. (PATANJALI)
# 2025-04-13 16:40:20,075 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:20,105 - INFO - Processing Persistent Systems Ltd. (PERSISTENT)
# 2025-04-13 16:40:20,236 - INFO - Verified unique data for OIL: Latest price = Rs.358.90
# 2025-04-13 16:40:20,252 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:20,294 - INFO - Verified unique data for OBEROIRLTY: Latest price = Rs.1547.35
# 2025-04-13 16:40:20,296 - INFO - Processing Petronet LNG Ltd. (PETRONET)
# 2025-04-13 16:40:20,297 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:20,330 - INFO - Processing Phoenix Mills Ltd. (PHOENIXLTD)
# 2025-04-13 16:40:20,434 - INFO - Verified unique data for OLAELEC: Latest price = Rs.50.20
# 2025-04-13 16:40:20,437 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:20,460 - INFO - Processing Polycab India Ltd. (POLYCAB)
# 2025-04-13 16:40:20,482 - INFO - Verified unique data for PAYTM: Latest price = Rs.840.70
# 2025-04-13 16:40:20,483 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:20,512 - INFO - Processing Premier Energies Ltd. (PREMIERENE)
# 2025-04-13 16:40:20,591 - INFO - Verified unique data for OFSS: Latest price = Rs.7579.85
# 2025-04-13 16:40:20,592 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:20,623 - INFO - Verified unique data for POLICYBZR: Latest price = Rs.1533.15
# 2025-04-13 16:40:20,638 - INFO - Processing Prestige Estates Projects Ltd. (PRESTIGE)
# 2025-04-13 16:40:20,639 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:20,669 - INFO - Processing Rail Vikas Nigam Ltd. (RVNL)
# 2025-04-13 16:40:20,855 - INFO - PIIND.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-08-11']
# 2025-04-13 16:40:20,873 - INFO - Verified unique data for PAGEIND: Latest price = Rs.44481.40
# 2025-04-13 16:40:20,876 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:20,910 - INFO - Verified unique data for PIIND: Latest price = Rs.3607.45
# 2025-04-13 16:40:20,920 - INFO - Processing SBI Cards and Payment Services Ltd. (SBICARD)
# 2025-04-13 16:40:20,920 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:20,951 - INFO - Processing SJVN Ltd. (SJVN)
# 2025-04-13 16:40:21,306 - INFO - Verified unique data for PERSISTENT: Latest price = Rs.4544.60
# 2025-04-13 16:40:21,310 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:21,339 - INFO - Verified unique data for PATANJALI: Latest price = Rs.1886.35
# 2025-04-13 16:40:21,355 - INFO - Processing SRF Ltd. (SRF)
# 2025-04-13 16:40:21,356 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:21,386 - INFO - Processing Schaeffler India Ltd. (SCHAEFFLER)
# 2025-04-13 16:40:21,499 - INFO - Verified unique data for PHOENIXLTD: Latest price = Rs.1478.00
# 2025-04-13 16:40:21,500 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:21,563 - INFO - Processing Solar Industries India Ltd. (SOLARINDS)
# 2025-04-13 16:40:21,574 - INFO - Verified unique data for PETRONET: Latest price = Rs.284.90
# 2025-04-13 16:40:21,575 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:21,603 - INFO - Processing Sona BLW Precision Forgings Ltd. (SONACOMS)
# 2025-04-13 16:40:21,651 - INFO - Verified unique data for PREMIERENE: Latest price = Rs.892.95
# 2025-04-13 16:40:21,653 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:21,675 - INFO - Processing Star Health and Allied Insurance Company Ltd. (STARHEALTH)
# 2025-04-13 16:40:21,846 - INFO - Verified unique data for PRESTIGE: Latest price = Rs.1122.85
# 2025-04-13 16:40:21,863 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:21,925 - INFO - Processing Steel Authority of India Ltd. (SAIL)
# 2025-04-13 16:40:21,941 - INFO - Verified unique data for RVNL: Latest price = Rs.346.30
# 2025-04-13 16:40:21,958 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:22,005 - INFO - Verified unique data for POLYCAB: Latest price = Rs.5093.25
# 2025-04-13 16:40:22,015 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:22,018 - INFO - Processing Sun TV Network Ltd. (SUNTV)
# 2025-04-13 16:40:22,050 - INFO - Processing Sundaram Finance Ltd. (SUNDARMFIN)
# 2025-04-13 16:40:22,086 - INFO - Verified unique data for SBICARD: Latest price = Rs.852.00
# 2025-04-13 16:40:22,087 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:22,118 - INFO - Processing Supreme Industries Ltd. (SUPREMEIND)
# 2025-04-13 16:40:22,189 - INFO - Verified unique data for SJVN: Latest price = Rs.91.43
# 2025-04-13 16:40:22,190 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:22,221 - INFO - Processing Suzlon Energy Ltd. (SUZLON)
# 2025-04-13 16:40:22,633 - INFO - Verified unique data for SRF: Latest price = Rs.2947.35
# 2025-04-13 16:40:22,634 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:22,693 - INFO - Processing Syngene International Ltd. (SYNGENE)
# 2025-04-13 16:40:22,708 - INFO - Verified unique data for SCHAEFFLER: Latest price = Rs.3042.65
# 2025-04-13 16:40:22,709 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:22,741 - INFO - Processing Tata Communications Ltd. (TATACOMM)
# 2025-04-13 16:40:22,773 - INFO - SOLARINDS.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-06-08']
# 2025-04-13 16:40:22,813 - INFO - SONACOMS.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-06-28']
# 2025-04-13 16:40:22,833 - INFO - Verified unique data for SOLARINDS: Latest price = Rs.11317.05
# 2025-04-13 16:40:22,844 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:22,885 - INFO - Processing Tata Elxsi Ltd. (TATAELXSI)
# 2025-04-13 16:40:22,897 - INFO - Verified unique data for SONACOMS: Latest price = Rs.430.10
# 2025-04-13 16:40:22,908 - INFO - Verified unique data for STARHEALTH: Latest price = Rs.360.30
# 2025-04-13 16:40:22,909 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:22,910 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:22,969 - INFO - Processing Tata Investment Corporation Ltd. (TATAINVEST)
# 2025-04-13 16:40:22,977 - INFO - Processing Tata Technologies Ltd. (TATATECH)
# 2025-04-13 16:40:23,159 - INFO - Verified unique data for SAIL: Latest price = Rs.108.34
# 2025-04-13 16:40:23,160 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:23,190 - INFO - Processing The New India Assurance Company Ltd. (NIACL)
# 2025-04-13 16:40:23,269 - INFO - Verified unique data for SUNTV: Latest price = Rs.660.10
# 2025-04-13 16:40:23,270 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:23,299 - INFO - Processing Thermax Ltd. (THERMAX)
# 2025-04-13 16:40:23,346 - INFO - Verified unique data for SUPREMEIND: Latest price = Rs.3168.50
# 2025-04-13 16:40:23,349 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:23,391 - INFO - Processing Torrent Power Ltd. (TORNTPOWER)
# 2025-04-13 16:40:23,408 - INFO - Verified unique data for SUZLON: Latest price = Rs.53.00
# 2025-04-13 16:40:23,421 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:23,456 - INFO - Verified unique data for SUNDARMFIN: Latest price = Rs.4645.75
# 2025-04-13 16:40:23,463 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:23,466 - INFO - Processing Tube Investments of India Ltd. (TIINDIA)
# 2025-04-13 16:40:23,495 - INFO - Processing UNO Minda Ltd. (UNOMINDA)
# 2025-04-13 16:40:23,937 - INFO - Verified unique data for TATACOMM: Latest price = Rs.1564.25
# 2025-04-13 16:40:23,941 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:23,952 - INFO - Verified unique data for SYNGENE: Latest price = Rs.701.80
# 2025-04-13 16:40:23,970 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:24,004 - INFO - Processing UPL Ltd. (UPL)
# 2025-04-13 16:40:24,017 - INFO - Processing Union Bank of India (UNIONBANK)
# 2025-04-13 16:40:24,169 - INFO - Verified unique data for TATAELXSI: Latest price = Rs.4752.05
# 2025-04-13 16:40:24,169 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:24,218 - INFO - Processing United Breweries Ltd. (UBL)
# 2025-04-13 16:40:24,236 - INFO - Verified unique data for TATAINVEST: Latest price = Rs.6171.50
# 2025-04-13 16:40:24,237 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:24,265 - INFO - Processing Vishal Mega Mart Ltd. (VMM)
# 2025-04-13 16:40:24,474 - INFO - Verified unique data for NIACL: Latest price = Rs.156.28
# 2025-04-13 16:40:24,485 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:24,537 - INFO - Verified unique data for THERMAX: Latest price = Rs.3085.45
# 2025-04-13 16:40:24,538 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:24,539 - INFO - Processing Vodafone Idea Ltd. (IDEA)
# 2025-04-13 16:40:24,585 - INFO - Processing Voltas Ltd. (VOLTAS)
# 2025-04-13 16:40:24,622 - INFO - Verified unique data for TORNTPOWER: Latest price = Rs.1562.15
# 2025-04-13 16:40:24,624 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:24,668 - INFO - Processing Waaree Energies Ltd. (WAAREEENER)
# 2025-04-13 16:40:24,709 - INFO - Verified unique data for TATATECH: Latest price = Rs.632.05
# 2025-04-13 16:40:24,727 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:24,793 - INFO - Processing Yes Bank Ltd. (YESBANK)
# 2025-04-13 16:40:24,806 - INFO - Verified unique data for UNOMINDA: Latest price = Rs.824.15
# 2025-04-13 16:40:24,817 - INFO - Verified unique data for TIINDIA: Latest price = Rs.2509.70
# 2025-04-13 16:40:24,817 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:24,818 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:25,245 - INFO - Verified unique data for UPL: Latest price = Rs.638.85
# 2025-04-13 16:40:25,248 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:25,288 - INFO - Verified unique data for UNIONBANK: Latest price = Rs.117.83
# 2025-04-13 16:40:25,292 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:25,423 - INFO - Verified unique data for VMM: Latest price = Rs.104.51
# 2025-04-13 16:40:25,425 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:25,562 - INFO - Verified unique data for UBL: Latest price = Rs.2019.50
# 2025-04-13 16:40:25,563 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:25,728 - INFO - Verified unique data for IDEA: Latest price = Rs.7.17
# 2025-04-13 16:40:25,729 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:25,789 - INFO - Verified unique data for WAAREEENER: Latest price = Rs.2161.45
# 2025-04-13 16:40:25,791 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:25,860 - INFO - Verified unique data for VOLTAS: Latest price = Rs.1284.90
# 2025-04-13 16:40:25,861 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:25,962 - INFO - Verified unique data for YESBANK: Latest price = Rs.17.15
# 2025-04-13 16:40:25,963 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)

# %%
stock_list_smallcap = """Company Name	Symbol
ACME Solar Holdings Ltd.	ACMESOLAR
Aadhar Housing Finance Ltd.	AADHARHFC
Aarti Industries Ltd.	AARTIIND
Aavas Financiers Ltd.	AAVAS
Action Construction Equipment Ltd.	ACE
Aditya Birla Real Estate Ltd.	ABREL
Aditya Birla Sun Life AMC Ltd.	ABSLAMC
Aegis Logistics Ltd.	AEGISLOG
Afcons Infrastructure Ltd.	AFCONS
Affle (India) Ltd.	AFFLE
Akums Drugs and Pharmaceuticals Ltd.	AKUMS
Alembic Pharmaceuticals Ltd.	APLLTD
Alivus Life Sciences Ltd.	ALIVUS
Alkyl Amines Chemicals Ltd.	ALKYLAMINE
Alok Industries Ltd.	ALOKINDS
Amara Raja Energy & Mobility Ltd.	ARE&M
Amber Enterprises India Ltd.	AMBER
Anand Rathi Wealth Ltd.	ANANDRATHI
Anant Raj Ltd.	ANANTRAJ
Angel One Ltd.	ANGELONE
Aptus Value Housing Finance India Ltd.	APTUS
Asahi India Glass Ltd.	ASAHIINDIA
Aster DM Healthcare Ltd.	ASTERDM
AstraZenca Pharma India Ltd.	ASTRAZEN
Atul Ltd.	ATUL
Authum Investment & Infrastructure Ltd.	AIIL
BASF India Ltd.	BASF
BEML Ltd.	BEML
BLS International Services Ltd.	BLS
Balrampur Chini Mills Ltd.	BALRAMCHIN
Bata India Ltd.	BATAINDIA
Bayer Cropscience Ltd.	BAYERCROP
Bikaji Foods International Ltd.	BIKAJI
Birlasoft Ltd.	BSOFT
Blue Dart Express Ltd.	BLUEDART
Bombay Burmah Trading Corporation Ltd.	BBTC
Brainbees Solutions Ltd.	FIRSTCRY
Brigade Enterprises Ltd.	BRIGADE
C.E. Info Systems Ltd.	MAPMYINDIA
CCL Products (I) Ltd.	CCL
CESC Ltd.	CESC
Campus Activewear Ltd.	CAMPUS
Can Fin Homes Ltd.	CANFINHOME
Caplin Point Laboratories Ltd.	CAPLIPOINT
Capri Global Capital Ltd.	CGCL
Carborundum Universal Ltd.	CARBORUNIV
Castrol India Ltd.	CASTROLIND
Ceat Ltd.	CEATLTD
Central Bank of India	CENTRALBK
Central Depository Services (India) Ltd.	CDSL
Century Plyboards (India) Ltd.	CENTURYPLY
Cera Sanitaryware Ltd	CERA
Chalet Hotels Ltd.	CHALET
Chambal Fertilizers & Chemicals Ltd.	CHAMBLFERT
Chennai Petroleum Corporation Ltd.	CHENNPETRO
Cholamandalam Financial Holdings Ltd.	CHOLAHLDNG
City Union Bank Ltd.	CUB
Clean Science and Technology Ltd.	CLEAN
Computer Age Management Services Ltd.	CAMS
Concord Biotech Ltd.	CONCORDBIO
Craftsman Automation Ltd.	CRAFTSMAN
CreditAccess Grameen Ltd.	CREDITACC
Crompton Greaves Consumer Electricals Ltd.	CROMPTON
Cyient Ltd.	CYIENT
DCM Shriram Ltd.	DCMSHRIRAM
DOMS Industries Ltd.	DOMS
Data Patterns (India) Ltd.	DATAPATTNS
Deepak Fertilisers & Petrochemicals Corp. Ltd.	DEEPAKFERT
Delhivery Ltd.	DELHIVERY
Devyani International Ltd.	DEVYANI
Dr. Lal Path Labs Ltd.	LALPATHLAB
E.I.D. Parry (India) Ltd.	EIDPARRY
EIH Ltd.	EIHOTEL
Elecon Engineering Co. Ltd.	ELECON
Elgi Equipments Ltd.	ELGIEQUIP
Emcure Pharmaceuticals Ltd.	EMCURE
Engineers India Ltd.	ENGINERSIN
Eris Lifesciences Ltd.	ERIS
Fertilisers and Chemicals Travancore Ltd.	FACT
Finolex Cables Ltd.	FINCABLES
Finolex Industries Ltd.	FINPIPE
Firstsource Solutions Ltd.	FSL
Five-Star Business Finance Ltd.	FIVESTAR
Garden Reach Shipbuilders & Engineers Ltd.	GRSE
Gillette India Ltd.	GILLETTE
Go Digit General Insurance Ltd.	GODIGIT
Godawari Power & Ispat Ltd.	GPIL
Godfrey Phillips India Ltd.	GODFRYPHLP
Godrej Agrovet Ltd.	GODREJAGRO
Granules India Ltd.	GRANULES
Graphite India Ltd.	GRAPHITE
Gravita India Ltd.	GRAVITA
Great Eastern Shipping Co. Ltd.	GESHIP
Gujarat Mineral Development Corporation Ltd.	GMDCLTD
Gujarat Narmada Valley Fertilizers and Chemicals Ltd.	GNFC
Gujarat Pipavav Port Ltd.	GPPL
Gujarat State Petronet Ltd.	GSPL
H.E.G. Ltd.	HEG
HBL Engineering Ltd.	HBLENGINE
HFCL Ltd.	HFCL
Happiest Minds Technologies Ltd.	HAPPSTMNDS
Himadri Speciality Chemical Ltd.	HSCL
Hindustan Copper Ltd.	HINDCOPPER
Home First Finance Company India Ltd.	HOMEFIRST
Honasa Consumer Ltd.	HONASA
IDBI Bank Ltd.	IDBI
IFCI Ltd.	IFCI
IIFL Finance Ltd.	IIFL
INOX India Ltd.	INOXINDIA
IRCON International Ltd.	IRCON
ITI Ltd.	ITI
Indegene Ltd.	INDGN
India Cements Ltd.	INDIACEM
Indiamart Intermesh Ltd.	INDIAMART
Indian Energy Exchange Ltd.	IEX
Indian Overseas Bank	IOB
Inox Wind Ltd.	INOXWIND
Intellect Design Arena Ltd.	INTELLECT
International Gemmological Institute (India) Ltd.	IGIL
Inventurus Knowledge Solutions Ltd.	IKS
J.B. Chemicals & Pharmaceuticals Ltd.	JBCHEPHARM
JBM Auto Ltd.	JBMA
JK Tyre & Industries Ltd.	JKTYRE
JM Financial Ltd.	JMFINANCIL
JSW Holdings Ltd.	JSWHL
Jaiprakash Power Ventures Ltd.	JPPOWER
Jammu & Kashmir Bank Ltd.	J&KBANK
Jindal Saw Ltd.	JINDALSAW
Jubilant Ingrevia Ltd.	JUBLINGREA
Jubilant Pharmova Ltd.	JUBLPHARMA
Jupiter Wagons Ltd.	JWL
Justdial Ltd.	JUSTDIAL
Jyothy Labs Ltd.	JYOTHYLAB
Jyoti CNC Automation Ltd.	JYOTICNC
KNR Constructions Ltd.	KNRCON
Kajaria Ceramics Ltd.	KAJARIACER
Kalpataru Projects International Ltd.	KPIL
Kansai Nerolac Paints Ltd.	KANSAINER
Karur Vysya Bank Ltd.	KARURVYSYA
Kaynes Technology India Ltd.	KAYNES
Kec International Ltd.	KEC
Kfin Technologies Ltd.	KFINTECH
Kirloskar Brothers Ltd.	KIRLOSBROS
Kirloskar Oil Eng Ltd.	KIRLOSENG
Krishna Institute of Medical Sciences Ltd.	KIMS
LT Foods Ltd.	LTFOODS
Latent View Analytics Ltd.	LATENTVIEW
Laurus Labs Ltd.	LAURUSLABS
Lemon Tree Hotels Ltd.	LEMONTREE
MMTC Ltd.	MMTC
Mahanagar Gas Ltd.	MGL
Maharashtra Seamless Ltd.	MAHSEAMLES
Manappuram Finance Ltd.	MANAPPURAM
Mastek Ltd.	MASTEK
Metropolis Healthcare Ltd.	METROPOLIS
Minda Corporation Ltd.	MINDACORP
Multi Commodity Exchange of India Ltd.	MCX
NATCO Pharma Ltd.	NATCOPHARM
NBCC (India) Ltd.	NBCC
NCC Ltd.	NCC
NMDC Steel Ltd.	NSLNISP
Narayana Hrudayalaya Ltd.	NH
Nava Ltd.	NAVA
Navin Fluorine International Ltd.	NAVINFLUOR
Netweb Technologies India Ltd.	NETWEB
Network18 Media & Investments Ltd.	NETWORK18
Neuland Laboratories Ltd.	NEULANDLAB
Newgen Software Technologies Ltd.	NEWGEN
Niva Bupa Health Insurance Company Ltd.	NIVABUPA
Nuvama Wealth Management Ltd.	NUVAMA
Olectra Greentech Ltd.	OLECTRA
PCBL Chemical Ltd.	PCBL
PG Electroplast Ltd.	PGEL
PNB Housing Finance Ltd.	PNBHOUSING
PNC Infratech Ltd.	PNCINFRA
PTC Industries Ltd.	PTCIL
PVR INOX Ltd.	PVRINOX
Pfizer Ltd.	PFIZER
Piramal Enterprises Ltd.	PEL
Piramal Pharma Ltd.	PPLPHARMA
Poly Medicure Ltd.	POLYMED
Poonawalla Fincorp Ltd.	POONAWALLA
Praj Industries Ltd.	PRAJIND
Quess Corp Ltd.	QUESS
R R Kabel Ltd.	RRKABEL
RBL Bank Ltd.	RBLBANK
RHI MAGNESITA INDIA LTD.	RHIM
RITES Ltd.	RITES
Radico Khaitan Ltd	RADICO
Railtel Corporation Of India Ltd.	RAILTEL
Rainbow Childrens Medicare Ltd.	RAINBOW
Ramkrishna Forgings Ltd.	RKFORGE
Rashtriya Chemicals & Fertilizers Ltd.	RCF
RattanIndia Enterprises Ltd.	RTNINDIA
Raymond Lifestyle Ltd.	RAYMONDLSL
Raymond Ltd.	RAYMOND
Redington Ltd.	REDINGTON
Reliance Power Ltd.	RPOWER
Route Mobile Ltd.	ROUTE
SBFC Finance Ltd.	SBFC
SKF India Ltd.	SKFINDIA
Sagility India Ltd.	SAGILITY
Sai Life Sciences Ltd.	SAILIFE
Sammaan Capital Ltd.	SAMMAANCAP
Sapphire Foods India Ltd.	SAPPHIRE
Sarda Energy and Minerals Ltd.	SARDAEN
Saregama India Ltd	SAREGAMA
Schneider Electric Infrastructure Ltd.	SCHNEIDER
Shipping Corporation of India Ltd.	SCI
Shree Renuka Sugars Ltd.	RENUKA
Shyam Metalics and Energy Ltd.	SHYAMMETL
Signatureglobal (India) Ltd.	SIGNATURE
Sobha Ltd.	SOBHA
Sonata Software Ltd.	SONATSOFTW
Sterling and Wilson Renewable Energy Ltd.	SWSOLAR
Sumitomo Chemical India Ltd.	SUMICHEM
Suven Pharmaceuticals Ltd.	SUVENPHAR
Swan Energy Ltd.	SWANENERGY
Syrma SGS Technology Ltd.	SYRMA
TBO Tek Ltd.	TBOTEK
Tanla Platforms Ltd.	TANLA
Tata Chemicals Ltd.	TATACHEM
Tata Teleservices (Maharashtra) Ltd.	TTML
Techno Electric & Engineering Company Ltd.	TECHNOE
Tejas Networks Ltd.	TEJASNET
The Ramco Cements Ltd.	RAMCOCEM
Timken India Ltd.	TIMKEN
Titagarh Rail Systems Ltd.	TITAGARH
Transformers And Rectifiers (India) Ltd.	TARIL
Trident Ltd.	TRIDENT
Triveni Engineering & Industries Ltd.	TRIVENI
Triveni Turbine Ltd.	TRITURBINE
UCO Bank	UCOBANK
UTI Asset Management Company Ltd.	UTIAMC
Usha Martin Ltd.	USHAMART
V-Guard Industries Ltd.	VGUARD
Valor Estate Ltd.	DBREALTY
Vardhman Textiles Ltd.	VTL
Vedant Fashions Ltd.	MANYAVAR
Vijaya Diagnostic Centre Ltd.	VIJAYA
Welspun Corp Ltd.	WELCORP
Welspun Living Ltd.	WELSPUNLIV
Westlife Foodworld Ltd.	WESTLIFE
Whirlpool of India Ltd.	WHIRLPOOL
Wockhardt Ltd.	WOCKPHARMA
ZF Commercial Vehicle Control Systems India Ltd.	ZFCVINDIA
Zee Entertainment Enterprises Ltd.	ZEEL
Zen Technologies Ltd.	ZENTEC
Zensar Technolgies Ltd.	ZENSARTECH
eClerx Services Ltd.	ECLERX"""


stocks_smallcap = parse_stock_list(stock_list_smallcap)
results = analyze_stocks(stocks_smallcap, output_dir="stock_analysis/reports_v2/smallcap_250", max_workers=10, end_date="2025-04-12")
# Out:
# 2025-04-13 16:40:28,778 - INFO - Processing ACME Solar Holdings Ltd. (ACMESOLAR)
# 2025-04-13 16:40:28,779 - INFO - Processing Aadhar Housing Finance Ltd. (AADHARHFC)
# 2025-04-13 16:40:28,781 - INFO - Processing Aarti Industries Ltd. (AARTIIND)
# 2025-04-13 16:40:28,782 - INFO - Processing Aavas Financiers Ltd. (AAVAS)
# 2025-04-13 16:40:28,783 - INFO - Processing Action Construction Equipment Ltd. (ACE)
# 2025-04-13 16:40:28,784 - INFO - Processing Aditya Birla Real Estate Ltd. (ABREL)
# 2025-04-13 16:40:28,785 - INFO - Processing Aditya Birla Sun Life AMC Ltd. (ABSLAMC)
# 2025-04-13 16:40:28,787 - INFO - Processing Aegis Logistics Ltd. (AEGISLOG)
# 2025-04-13 16:40:28,788 - INFO - Processing Afcons Infrastructure Ltd. (AFCONS)
# 2025-04-13 16:40:28,790 - INFO - Processing Affle (India) Ltd. (AFFLE)
# 2025-04-13 16:40:29,895 - INFO - Verified unique data for ACMESOLAR: Latest price = Rs.197.09
# 2025-04-13 16:40:29,897 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:29,959 - INFO - Processing Akums Drugs and Pharmaceuticals Ltd. (AKUMS)
# 2025-04-13 16:40:30,073 - INFO - Verified unique data for AFCONS: Latest price = Rs.428.20
# 2025-04-13 16:40:30,120 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:30,145 - INFO - Verified unique data for AAVAS: Latest price = Rs.2028.15
# 2025-04-13 16:40:30,175 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:30,201 - INFO - Processing Alembic Pharmaceuticals Ltd. (APLLTD)
# 2025-04-13 16:40:30,201 - INFO - Verified unique data for AADHARHFC: Latest price = Rs.463.40
# 2025-04-13 16:40:30,249 - INFO - Verified unique data for AFFLE: Latest price = Rs.1501.55
# 2025-04-13 16:40:30,270 - INFO - Verified unique data for ABREL: Latest price = Rs.1786.40
# 2025-04-13 16:40:30,280 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:30,299 - INFO - Verified unique data for ABSLAMC: Latest price = Rs.625.05
# 2025-04-13 16:40:30,303 - INFO - Processing Alivus Life Sciences Ltd. (ALIVUS)
# 2025-04-13 16:40:30,322 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:30,339 - INFO - Verified unique data for ACE: Latest price = Rs.1230.75
# 2025-04-13 16:40:30,343 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:30,344 - INFO - Verified unique data for AARTIIND: Latest price = Rs.382.95
# 2025-04-13 16:40:30,349 - INFO - Verified unique data for AEGISLOG: Latest price = Rs.755.75
# 2025-04-13 16:40:30,371 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:30,379 - INFO - Processing Alkyl Amines Chemicals Ltd. (ALKYLAMINE)
# 2025-04-13 16:40:30,398 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:30,430 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:30,433 - INFO - Processing Alok Industries Ltd. (ALOKINDS)
# 2025-04-13 16:40:30,436 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:30,442 - INFO - Processing Amara Raja Energy & Mobility Ltd. (ARE&M)
# 2025-04-13 16:40:30,490 - INFO - Processing Amber Enterprises India Ltd. (AMBER)
# 2025-04-13 16:40:30,519 - INFO - Processing Anand Rathi Wealth Ltd. (ANANDRATHI)
# 2025-04-13 16:40:30,549 - INFO - Processing Anant Raj Ltd. (ANANTRAJ)
# 2025-04-13 16:40:30,563 - INFO - Processing Angel One Ltd. (ANGELONE)
# 2025-04-13 16:40:31,291 - INFO - Verified unique data for AKUMS: Latest price = Rs.433.80
# 2025-04-13 16:40:31,292 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:31,313 - INFO - Processing Aptus Value Housing Finance India Ltd. (APTUS)
# 2025-04-13 16:40:31,432 - INFO - Verified unique data for APLLTD: Latest price = Rs.846.40
# 2025-04-13 16:40:31,433 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:31,463 - INFO - Processing Asahi India Glass Ltd. (ASAHIINDIA)
# 2025-04-13 16:40:31,491 - INFO - Verified unique data for ALIVUS: Latest price = Rs.965.30
# 2025-04-13 16:40:31,492 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:31,509 - INFO - Processing Aster DM Healthcare Ltd. (ASTERDM)
# 2025-04-13 16:40:31,669 - INFO - Verified unique data for ALOKINDS: Latest price = Rs.15.62
# 2025-04-13 16:40:31,671 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:31,730 - INFO - Processing AstraZenca Pharma India Ltd. (ASTRAZEN)
# 2025-04-13 16:40:31,842 - INFO - Verified unique data for ALKYLAMINE: Latest price = Rs.1740.45
# 2025-04-13 16:40:31,862 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:31,904 - INFO - Verified unique data for AMBER: Latest price = Rs.6530.05
# 2025-04-13 16:40:31,926 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:31,941 - INFO - Verified unique data for ANANDRATHI: Latest price = Rs.1800.40
# 2025-04-13 16:40:31,966 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:31,969 - INFO - Processing Atul Ltd. (ATUL)
# 2025-04-13 16:40:32,011 - INFO - Processing Authum Investment & Infrastructure Ltd. (AIIL)
# 2025-04-13 16:40:32,011 - INFO - Verified unique data for ANANTRAJ: Latest price = Rs.439.20
# 2025-04-13 16:40:32,025 - INFO - Verified unique data for ANGELONE: Latest price = Rs.2265.00
# 2025-04-13 16:40:32,031 - INFO - Processing BASF India Ltd. (BASF)
# 2025-04-13 16:40:32,032 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:32,046 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:32,096 - INFO - Processing BEML Ltd. (BEML)
# 2025-04-13 16:40:32,133 - INFO - Processing BLS International Services Ltd. (BLS)
# 2025-04-13 16:40:32,180 - INFO - Verified unique data for ARE&M: Latest price = Rs.975.55
# 2025-04-13 16:40:32,181 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:32,209 - INFO - Processing Balrampur Chini Mills Ltd. (BALRAMCHIN)
# 2025-04-13 16:40:32,483 - INFO - Verified unique data for APTUS: Latest price = Rs.302.45
# 2025-04-13 16:40:32,484 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:32,514 - INFO - Processing Bata India Ltd. (BATAINDIA)
# 2025-04-13 16:40:32,712 - INFO - Verified unique data for ASTERDM: Latest price = Rs.500.30
# 2025-04-13 16:40:32,713 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:32,768 - INFO - Processing Bayer Cropscience Ltd. (BAYERCROP)
# 2025-04-13 16:40:32,780 - INFO - Verified unique data for ASAHIINDIA: Latest price = Rs.662.75
# 2025-04-13 16:40:32,780 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:32,809 - INFO - Processing Bikaji Foods International Ltd. (BIKAJI)
# 2025-04-13 16:40:32,976 - INFO - Verified unique data for ASTRAZEN: Latest price = Rs.8457.40
# 2025-04-13 16:40:32,977 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:33,005 - INFO - Processing Birlasoft Ltd. (BSOFT)
# 2025-04-13 16:40:33,258 - INFO - Verified unique data for BASF: Latest price = Rs.4486.05
# 2025-04-13 16:40:33,259 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:33,293 - INFO - Verified unique data for ATUL: Latest price = Rs.5727.35
# 2025-04-13 16:40:33,312 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:33,337 - INFO - Processing Blue Dart Express Ltd. (BLUEDART)
# 2025-04-13 16:40:33,415 - INFO - Processing Bombay Burmah Trading Corporation Ltd. (BBTC)
# 2025-04-13 16:40:33,432 - INFO - Verified unique data for AIIL: Latest price = Rs.1609.00
# 2025-04-13 16:40:33,442 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:33,509 - INFO - Processing Brainbees Solutions Ltd. (FIRSTCRY)
# 2025-04-13 16:40:33,521 - INFO - Verified unique data for BEML: Latest price = Rs.3034.75
# 2025-04-13 16:40:33,524 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:33,537 - INFO - Verified unique data for BALRAMCHIN: Latest price = Rs.529.90
# 2025-04-13 16:40:33,540 - INFO - Verified unique data for BLS: Latest price = Rs.359.10
# 2025-04-13 16:40:33,559 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:33,569 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:33,578 - INFO - Processing Brigade Enterprises Ltd. (BRIGADE)
# 2025-04-13 16:40:33,619 - INFO - Processing C.E. Info Systems Ltd. (MAPMYINDIA)
# 2025-04-13 16:40:33,629 - INFO - Processing CCL Products (I) Ltd. (CCL)
# 2025-04-13 16:40:33,682 - INFO - Verified unique data for BATAINDIA: Latest price = Rs.1241.85
# 2025-04-13 16:40:33,683 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:33,711 - INFO - Processing CESC Ltd. (CESC)
# 2025-04-13 16:40:33,920 - INFO - BAYERCROP.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-08-04']
# 2025-04-13 16:40:33,999 - INFO - Verified unique data for BIKAJI: Latest price = Rs.709.45
# 2025-04-13 16:40:34,000 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:34,032 - INFO - Processing Campus Activewear Ltd. (CAMPUS)
# 2025-04-13 16:40:34,076 - INFO - Verified unique data for BAYERCROP: Latest price = Rs.4826.90
# 2025-04-13 16:40:34,077 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:34,109 - INFO - Processing Can Fin Homes Ltd. (CANFINHOME)
# 2025-04-13 16:40:34,191 - INFO - Verified unique data for BSOFT: Latest price = Rs.359.75
# 2025-04-13 16:40:34,192 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:34,225 - INFO - Processing Caplin Point Laboratories Ltd. (CAPLIPOINT)
# 2025-04-13 16:40:34,538 - INFO - Verified unique data for BLUEDART: Latest price = Rs.6312.10
# 2025-04-13 16:40:34,539 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:34,568 - INFO - Processing Capri Global Capital Ltd. (CGCL)
# 2025-04-13 16:40:34,659 - INFO - Verified unique data for FIRSTCRY: Latest price = Rs.327.00
# 2025-04-13 16:40:34,660 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:34,680 - INFO - Verified unique data for BBTC: Latest price = Rs.1826.25
# 2025-04-13 16:40:34,695 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:34,698 - INFO - Processing Carborundum Universal Ltd. (CARBORUNIV)
# 2025-04-13 16:40:34,738 - INFO - Processing Castrol India Ltd. (CASTROLIND)
# 2025-04-13 16:40:34,778 - INFO - Verified unique data for MAPMYINDIA: Latest price = Rs.1723.25
# 2025-04-13 16:40:34,801 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:34,875 - INFO - Verified unique data for CCL: Latest price = Rs.599.10
# 2025-04-13 16:40:34,878 - INFO - Processing Ceat Ltd. (CEATLTD)
# 2025-04-13 16:40:34,879 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:34,893 - INFO - Verified unique data for BRIGADE: Latest price = Rs.934.60
# 2025-04-13 16:40:34,921 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:34,927 - INFO - Processing Central Bank of India (CENTRALBK)
# 2025-04-13 16:40:34,981 - INFO - Processing Central Depository Services (India) Ltd. (CDSL)
# 2025-04-13 16:40:34,993 - INFO - Verified unique data for CESC: Latest price = Rs.153.70
# 2025-04-13 16:40:34,994 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:35,023 - INFO - Processing Century Plyboards (India) Ltd. (CENTURYPLY)
# 2025-04-13 16:40:35,159 - INFO - Verified unique data for CAMPUS: Latest price = Rs.238.31
# 2025-04-13 16:40:35,160 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:35,189 - INFO - Processing Cera Sanitaryware Ltd (CERA)
# 2025-04-13 16:40:35,325 - INFO - Verified unique data for CANFINHOME: Latest price = Rs.652.00
# 2025-04-13 16:40:35,326 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:35,379 - INFO - Processing Chalet Hotels Ltd. (CHALET)
# 2025-04-13 16:40:35,394 - INFO - Verified unique data for CAPLIPOINT: Latest price = Rs.1869.40
# 2025-04-13 16:40:35,395 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:35,423 - INFO - Processing Chambal Fertilizers & Chemicals Ltd. (CHAMBLFERT)
# 2025-04-13 16:40:35,709 - INFO - CGCL.NS: 1d: price-repair-split: Corrected: 2023-04-12 -> 2023-12-29
# 2025-04-13 16:40:35,721 - INFO - Verified unique data for CGCL: Latest price = Rs.155.84
# 2025-04-13 16:40:35,722 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:35,757 - INFO - Processing Chennai Petroleum Corporation Ltd. (CHENNPETRO)
# 2025-04-13 16:40:35,925 - INFO - Verified unique data for CARBORUNIV: Latest price = Rs.955.35
# 2025-04-13 16:40:35,926 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:35,956 - INFO - Processing Cholamandalam Financial Holdings Ltd. (CHOLAHLDNG)
# 2025-04-13 16:40:35,999 - INFO - Verified unique data for CASTROLIND: Latest price = Rs.199.33
# 2025-04-13 16:40:36,000 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:36,038 - INFO - Processing City Union Bank Ltd. (CUB)
# 2025-04-13 16:40:36,087 - INFO - Verified unique data for CENTRALBK: Latest price = Rs.34.43
# 2025-04-13 16:40:36,088 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:36,117 - INFO - Processing Clean Science and Technology Ltd. (CLEAN)
# 2025-04-13 16:40:36,243 - INFO - Verified unique data for CEATLTD: Latest price = Rs.2832.50
# 2025-04-13 16:40:36,250 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:36,288 - INFO - Verified unique data for CENTURYPLY: Latest price = Rs.696.90
# 2025-04-13 16:40:36,297 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:36,298 - INFO - Processing Computer Age Management Services Ltd. (CAMS)
# 2025-04-13 16:40:36,334 - INFO - Verified unique data for CDSL: Latest price = Rs.1168.00
# 2025-04-13 16:40:36,342 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:36,344 - INFO - Processing Concord Biotech Ltd. (CONCORDBIO)
# 2025-04-13 16:40:36,374 - INFO - Processing Craftsman Automation Ltd. (CRAFTSMAN)
# 2025-04-13 16:40:36,440 - INFO - Verified unique data for CERA: Latest price = Rs.5393.50
# 2025-04-13 16:40:36,441 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:36,470 - INFO - Processing CreditAccess Grameen Ltd. (CREDITACC)
# 2025-04-13 16:40:36,510 - INFO - Verified unique data for CHALET: Latest price = Rs.819.80
# 2025-04-13 16:40:36,512 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:36,540 - INFO - Processing Crompton Greaves Consumer Electricals Ltd. (CROMPTON)
# 2025-04-13 16:40:36,644 - INFO - Verified unique data for CHAMBLFERT: Latest price = Rs.645.25
# 2025-04-13 16:40:36,645 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:36,673 - INFO - Processing Cyient Ltd. (CYIENT)
# 2025-04-13 16:40:37,000 - INFO - Verified unique data for CHENNPETRO: Latest price = Rs.616.20
# 2025-04-13 16:40:37,001 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:37,029 - INFO - Processing DCM Shriram Ltd. (DCMSHRIRAM)
# 2025-04-13 16:40:37,170 - INFO - Verified unique data for CHOLAHLDNG: Latest price = Rs.1780.40
# 2025-04-13 16:40:37,172 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:37,213 - INFO - Processing DOMS Industries Ltd. (DOMS)
# 2025-04-13 16:40:37,237 - INFO - Verified unique data for CUB: Latest price = Rs.166.97
# 2025-04-13 16:40:37,249 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:37,306 - INFO - Verified unique data for CLEAN: Latest price = Rs.1180.95
# 2025-04-13 16:40:37,309 - INFO - Processing Data Patterns (India) Ltd. (DATAPATTNS)
# 2025-04-13 16:40:37,309 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:37,340 - INFO - Processing Deepak Fertilisers & Petrochemicals Corp. Ltd. (DEEPAKFERT)
# 2025-04-13 16:40:37,506 - INFO - Verified unique data for CRAFTSMAN: Latest price = Rs.4364.15
# 2025-04-13 16:40:37,507 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:37,536 - INFO - Processing Delhivery Ltd. (DELHIVERY)
# 2025-04-13 16:40:37,608 - INFO - Verified unique data for CREDITACC: Latest price = Rs.1023.10
# 2025-04-13 16:40:37,609 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:37,651 - INFO - Processing Devyani International Ltd. (DEVYANI)
# 2025-04-13 16:40:37,722 - INFO - Verified unique data for CAMS: Latest price = Rs.3716.70
# 2025-04-13 16:40:37,734 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:37,741 - INFO - Verified unique data for CONCORDBIO: Latest price = Rs.1653.85
# 2025-04-13 16:40:37,744 - INFO - CROMPTON.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-07-07']
# 2025-04-13 16:40:37,772 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:37,775 - INFO - Processing Dr. Lal Path Labs Ltd. (LALPATHLAB)
# 2025-04-13 16:40:37,823 - INFO - Processing E.I.D. Parry (India) Ltd. (EIDPARRY)
# 2025-04-13 16:40:37,828 - INFO - Verified unique data for CROMPTON: Latest price = Rs.334.10
# 2025-04-13 16:40:37,829 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:37,893 - INFO - Processing EIH Ltd. (EIHOTEL)
# 2025-04-13 16:40:37,898 - INFO - Verified unique data for CYIENT: Latest price = Rs.1144.20
# 2025-04-13 16:40:37,899 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:37,928 - INFO - Processing Elecon Engineering Co. Ltd. (ELECON)
# 2025-04-13 16:40:38,182 - INFO - DCMSHRIRAM.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-07-17']
# 2025-04-13 16:40:38,201 - INFO - Verified unique data for DCMSHRIRAM: Latest price = Rs.1036.80
# 2025-04-13 16:40:38,202 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:38,235 - INFO - Processing Elgi Equipments Ltd. (ELGIEQUIP)
# 2025-04-13 16:40:38,357 - INFO - Verified unique data for DOMS: Latest price = Rs.2599.55
# 2025-04-13 16:40:38,358 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:38,381 - INFO - Processing Emcure Pharmaceuticals Ltd. (EMCURE)
# 2025-04-13 16:40:38,454 - INFO - Verified unique data for DATAPATTNS: Latest price = Rs.1681.95
# 2025-04-13 16:40:38,455 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:38,485 - INFO - Processing Engineers India Ltd. (ENGINERSIN)
# 2025-04-13 16:40:38,506 - INFO - DEEPAKFERT.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-08-24']
# 2025-04-13 16:40:38,525 - INFO - Verified unique data for DEEPAKFERT: Latest price = Rs.1206.45
# 2025-04-13 16:40:38,526 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:38,558 - INFO - Processing Eris Lifesciences Ltd. (ERIS)
# 2025-04-13 16:40:38,675 - INFO - Verified unique data for DELHIVERY: Latest price = Rs.246.95
# 2025-04-13 16:40:38,676 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:38,708 - INFO - Processing Fertilisers and Chemicals Travancore Ltd. (FACT)
# 2025-04-13 16:40:38,838 - INFO - Verified unique data for DEVYANI: Latest price = Rs.155.92
# 2025-04-13 16:40:38,841 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:38,871 - INFO - Processing Finolex Cables Ltd. (FINCABLES)
# 2025-04-13 16:40:38,972 - INFO - Verified unique data for LALPATHLAB: Latest price = Rs.2701.80
# 2025-04-13 16:40:38,974 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:39,025 - INFO - Processing Finolex Industries Ltd. (FINPIPE)
# 2025-04-13 16:40:39,036 - INFO - Verified unique data for EIDPARRY: Latest price = Rs.780.85
# 2025-04-13 16:40:39,037 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:39,066 - INFO - Processing Firstsource Solutions Ltd. (FSL)
# 2025-04-13 16:40:39,169 - INFO - Verified unique data for EIHOTEL: Latest price = Rs.361.35
# 2025-04-13 16:40:39,171 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:39,205 - INFO - Verified unique data for ELECON: Latest price = Rs.436.05
# 2025-04-13 16:40:39,212 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:39,213 - INFO - Processing Five-Star Business Finance Ltd. (FIVESTAR)
# 2025-04-13 16:40:39,244 - INFO - Processing Garden Reach Shipbuilders & Engineers Ltd. (GRSE)
# 2025-04-13 16:40:39,442 - INFO - ELGIEQUIP.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-07-28']
# 2025-04-13 16:40:39,460 - INFO - Verified unique data for ELGIEQUIP: Latest price = Rs.422.15
# 2025-04-13 16:40:39,461 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:39,500 - INFO - Processing Gillette India Ltd. (GILLETTE)
# 2025-04-13 16:40:39,669 - INFO - Verified unique data for EMCURE: Latest price = Rs.919.45
# 2025-04-13 16:40:39,671 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:39,734 - INFO - Processing Go Digit General Insurance Ltd. (GODIGIT)
# 2025-04-13 16:40:39,755 - INFO - Verified unique data for ERIS: Latest price = Rs.1384.80
# 2025-04-13 16:40:39,758 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:39,784 - INFO - Verified unique data for ENGINERSIN: Latest price = Rs.159.93
# 2025-04-13 16:40:39,789 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:39,815 - INFO - Processing Godawari Power & Ispat Ltd. (GPIL)
# 2025-04-13 16:40:39,829 - INFO - Processing Godfrey Phillips India Ltd. (GODFRYPHLP)
# 2025-04-13 16:40:39,959 - INFO - Verified unique data for FACT: Latest price = Rs.624.65
# 2025-04-13 16:40:39,959 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:39,988 - INFO - Processing Godrej Agrovet Ltd. (GODREJAGRO)
# 2025-04-13 16:40:40,051 - INFO - Verified unique data for FINCABLES: Latest price = Rs.875.60
# 2025-04-13 16:40:40,052 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:40,082 - INFO - Processing Granules India Ltd. (GRANULES)
# 2025-04-13 16:40:40,291 - INFO - Verified unique data for FINPIPE: Latest price = Rs.171.98
# 2025-04-13 16:40:40,292 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:40,302 - INFO - Verified unique data for FSL: Latest price = Rs.321.05
# 2025-04-13 16:40:40,324 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:40,332 - INFO - Processing Graphite India Ltd. (GRAPHITE)
# 2025-04-13 16:40:40,362 - INFO - Processing Gravita India Ltd. (GRAVITA)
# 2025-04-13 16:40:40,404 - INFO - Verified unique data for FIVESTAR: Latest price = Rs.717.40
# 2025-04-13 16:40:40,410 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:40,452 - INFO - Verified unique data for GRSE: Latest price = Rs.1615.10
# 2025-04-13 16:40:40,453 - INFO - Processing Great Eastern Shipping Co. Ltd. (GESHIP)
# 2025-04-13 16:40:40,454 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:40,483 - INFO - Processing Gujarat Mineral Development Corporation Ltd. (GMDCLTD)
# 2025-04-13 16:40:40,721 - INFO - Verified unique data for GILLETTE: Latest price = Rs.7938.70
# 2025-04-13 16:40:40,722 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:40,753 - INFO - Processing Gujarat Narmada Valley Fertilizers and Chemicals Ltd. (GNFC)
# 2025-04-13 16:40:40,863 - INFO - Verified unique data for GODIGIT: Latest price = Rs.281.05
# 2025-04-13 16:40:40,864 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:40,887 - INFO - Processing Gujarat Pipavav Port Ltd. (GPPL)
# 2025-04-13 16:40:41,020 - INFO - GPIL.NS: 1d: price-repair-split: Corrected: 2023-04-12 -> 2023-12-29
# 2025-04-13 16:40:41,030 - INFO - Verified unique data for GPIL: Latest price = Rs.187.80
# 2025-04-13 16:40:41,031 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:41,059 - INFO - Processing Gujarat State Petronet Ltd. (GSPL)
# 2025-04-13 16:40:41,112 - INFO - Verified unique data for GODFRYPHLP: Latest price = Rs.7037.10
# 2025-04-13 16:40:41,113 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:41,143 - INFO - Processing H.E.G. Ltd. (HEG)
# 2025-04-13 16:40:41,183 - INFO - GODREJAGRO.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-07-27']
# 2025-04-13 16:40:41,202 - INFO - Verified unique data for GODREJAGRO: Latest price = Rs.768.85
# 2025-04-13 16:40:41,203 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:41,232 - INFO - Processing HBL Engineering Ltd. (HBLENGINE)
# 2025-04-13 16:40:41,389 - INFO - Verified unique data for GRANULES: Latest price = Rs.451.30
# 2025-04-13 16:40:41,390 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:41,419 - INFO - Processing HFCL Ltd. (HFCL)
# 2025-04-13 16:40:41,526 - INFO - Verified unique data for GRAVITA: Latest price = Rs.1852.10
# 2025-04-13 16:40:41,527 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:41,585 - INFO - Processing Happiest Minds Technologies Ltd. (HAPPSTMNDS)
# 2025-04-13 16:40:41,589 - INFO - Verified unique data for GRAPHITE: Latest price = Rs.451.80
# 2025-04-13 16:40:41,590 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:41,630 - INFO - Processing Himadri Speciality Chemical Ltd. (HSCL)
# 2025-04-13 16:40:41,691 - INFO - Verified unique data for GESHIP: Latest price = Rs.862.95
# 2025-04-13 16:40:41,699 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:41,703 - INFO - Verified unique data for GMDCLTD: Latest price = Rs.276.05
# 2025-04-13 16:40:41,726 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:41,734 - INFO - Processing Hindustan Copper Ltd. (HINDCOPPER)
# 2025-04-13 16:40:41,767 - INFO - Processing Home First Finance Company India Ltd. (HOMEFIRST)
# 2025-04-13 16:40:41,939 - INFO - Verified unique data for GNFC: Latest price = Rs.480.80
# 2025-04-13 16:40:41,940 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:41,968 - INFO - Processing Honasa Consumer Ltd. (HONASA)
# 2025-04-13 16:40:42,092 - INFO - Verified unique data for GPPL: Latest price = Rs.138.76
# 2025-04-13 16:40:42,093 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:42,121 - INFO - Processing IDBI Bank Ltd. (IDBI)
# 2025-04-13 16:40:42,236 - INFO - Verified unique data for GSPL: Latest price = Rs.314.25
# 2025-04-13 16:40:42,237 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:42,269 - INFO - Processing IFCI Ltd. (IFCI)
# 2025-04-13 16:40:42,371 - INFO - Verified unique data for HBLENGINE: Latest price = Rs.500.95
# 2025-04-13 16:40:42,373 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:42,400 - INFO - Processing IIFL Finance Ltd. (IIFL)
# 2025-04-13 16:40:42,404 - INFO - Verified unique data for HEG: Latest price = Rs.453.00
# 2025-04-13 16:40:42,406 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:42,437 - INFO - Processing INOX India Ltd. (INOXINDIA)
# 2025-04-13 16:40:42,607 - INFO - Verified unique data for HFCL: Latest price = Rs.76.01
# 2025-04-13 16:40:42,608 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:42,636 - INFO - Processing IRCON International Ltd. (IRCON)
# 2025-04-13 16:40:42,816 - INFO - HAPPSTMNDS.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-07-07']
# 2025-04-13 16:40:42,837 - INFO - Verified unique data for HSCL: Latest price = Rs.436.80
# 2025-04-13 16:40:42,838 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:42,848 - INFO - Verified unique data for HAPPSTMNDS: Latest price = Rs.560.50
# 2025-04-13 16:40:42,867 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:42,881 - INFO - Processing ITI Ltd. (ITI)
# 2025-04-13 16:40:42,937 - INFO - Processing Indegene Ltd. (INDGN)
# 2025-04-13 16:40:42,966 - INFO - Verified unique data for HINDCOPPER: Latest price = Rs.199.65
# 2025-04-13 16:40:42,967 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:43,012 - INFO - Processing India Cements Ltd. (INDIACEM)
# 2025-04-13 16:40:43,013 - INFO - Verified unique data for HOMEFIRST: Latest price = Rs.1059.00
# 2025-04-13 16:40:43,014 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:43,043 - INFO - Processing Indiamart Intermesh Ltd. (INDIAMART)
# 2025-04-13 16:40:43,107 - INFO - Verified unique data for HONASA: Latest price = Rs.231.94
# 2025-04-13 16:40:43,108 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:43,138 - INFO - Processing Indian Energy Exchange Ltd. (IEX)
# 2025-04-13 16:40:43,299 - INFO - Verified unique data for IDBI: Latest price = Rs.79.49
# 2025-04-13 16:40:43,300 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:43,328 - INFO - Processing Indian Overseas Bank (IOB)
# 2025-04-13 16:40:43,431 - INFO - Verified unique data for IFCI: Latest price = Rs.40.55
# 2025-04-13 16:40:43,432 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:43,464 - INFO - Processing Inox Wind Ltd. (INOXWIND)
# 2025-04-13 16:40:43,601 - INFO - Verified unique data for INOXINDIA: Latest price = Rs.997.75
# 2025-04-13 16:40:43,603 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:43,636 - INFO - Processing Intellect Design Arena Ltd. (INTELLECT)
# 2025-04-13 16:40:43,640 - INFO - Verified unique data for IIFL: Latest price = Rs.323.75
# 2025-04-13 16:40:43,643 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:43,672 - INFO - Processing International Gemmological Institute (India) Ltd. (IGIL)
# 2025-04-13 16:40:43,782 - INFO - Verified unique data for IRCON: Latest price = Rs.149.60
# 2025-04-13 16:40:43,783 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:43,811 - INFO - Processing Inventurus Knowledge Solutions Ltd. (IKS)
# 2025-04-13 16:40:44,030 - INFO - Verified unique data for ITI: Latest price = Rs.252.07
# 2025-04-13 16:40:44,031 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:44,075 - INFO - Processing J.B. Chemicals & Pharmaceuticals Ltd. (JBCHEPHARM)
# 2025-04-13 16:40:44,085 - INFO - Verified unique data for INDGN: Latest price = Rs.571.30
# 2025-04-13 16:40:44,087 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:44,114 - INFO - Processing JBM Auto Ltd. (JBMA)
# 2025-04-13 16:40:44,206 - INFO - Verified unique data for INDIACEM: Latest price = Rs.280.65
# 2025-04-13 16:40:44,206 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:44,251 - INFO - Processing JK Tyre & Industries Ltd. (JKTYRE)
# 2025-04-13 16:40:44,277 - INFO - Verified unique data for INDIAMART: Latest price = Rs.2093.90
# 2025-04-13 16:40:44,278 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:44,307 - INFO - Processing JM Financial Ltd. (JMFINANCIL)
# 2025-04-13 16:40:44,356 - INFO - IEX.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-07-28']
# 2025-04-13 16:40:44,375 - INFO - Verified unique data for IEX: Latest price = Rs.179.03
# 2025-04-13 16:40:44,376 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:44,404 - INFO - Processing JSW Holdings Ltd. (JSWHL)
# 2025-04-13 16:40:44,495 - INFO - Verified unique data for IOB: Latest price = Rs.34.93
# 2025-04-13 16:40:44,496 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:44,525 - INFO - Processing Jaiprakash Power Ventures Ltd. (JPPOWER)
# 2025-04-13 16:40:44,596 - INFO - Verified unique data for INOXWIND: Latest price = Rs.151.59
# 2025-04-13 16:40:44,597 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:44,625 - INFO - Processing Jammu & Kashmir Bank Ltd. (J&KBANK)
# 2025-04-13 16:40:44,769 - INFO - Verified unique data for INTELLECT: Latest price = Rs.660.60
# 2025-04-13 16:40:44,770 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:44,827 - INFO - Verified unique data for IGIL: Latest price = Rs.337.30
# 2025-04-13 16:40:44,830 - INFO - Processing Jindal Saw Ltd. (JINDALSAW)
# 2025-04-13 16:40:44,831 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:44,849 - INFO - Processing Jubilant Ingrevia Ltd. (JUBLINGREA)
# 2025-04-13 16:40:44,944 - INFO - Verified unique data for IKS: Latest price = Rs.1341.45
# 2025-04-13 16:40:44,945 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:44,962 - INFO - Processing Jubilant Pharmova Ltd. (JUBLPHARMA)
# 2025-04-13 16:40:45,325 - INFO - Verified unique data for JBCHEPHARM: Latest price = Rs.1571.60
# 2025-04-13 16:40:45,328 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:45,370 - INFO - Verified unique data for JBMA: Latest price = Rs.618.15
# 2025-04-13 16:40:45,371 - INFO - Processing Jupiter Wagons Ltd. (JWL)
# 2025-04-13 16:40:45,372 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:45,415 - INFO - Processing Justdial Ltd. (JUSTDIAL)
# 2025-04-13 16:40:45,442 - INFO - Verified unique data for JKTYRE: Latest price = Rs.284.05
# 2025-04-13 16:40:45,442 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:45,471 - INFO - Processing Jyothy Labs Ltd. (JYOTHYLAB)
# 2025-04-13 16:40:45,512 - INFO - Verified unique data for JMFINANCIL: Latest price = Rs.95.32
# 2025-04-13 16:40:45,513 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:45,545 - INFO - Processing Jyoti CNC Automation Ltd. (JYOTICNC)
# 2025-04-13 16:40:45,589 - INFO - Verified unique data for JSWHL: Latest price = Rs.23401.70
# 2025-04-13 16:40:45,590 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:45,618 - INFO - Processing KNR Constructions Ltd. (KNRCON)
# 2025-04-13 16:40:45,652 - INFO - Verified unique data for JPPOWER: Latest price = Rs.14.51
# 2025-04-13 16:40:45,653 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:45,682 - INFO - Processing Kajaria Ceramics Ltd. (KAJARIACER)
# 2025-04-13 16:40:45,827 - INFO - J&KBANK.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-08-14']
# 2025-04-13 16:40:45,847 - INFO - Verified unique data for J&KBANK: Latest price = Rs.91.16
# 2025-04-13 16:40:45,848 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:45,882 - INFO - Processing Kalpataru Projects International Ltd. (KPIL)
# 2025-04-13 16:40:46,006 - INFO - Verified unique data for JINDALSAW: Latest price = Rs.247.10
# 2025-04-13 16:40:46,007 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:46,060 - INFO - Processing Kansai Nerolac Paints Ltd. (KANSAINER)
# 2025-04-13 16:40:46,074 - INFO - Verified unique data for JUBLINGREA: Latest price = Rs.634.30
# 2025-04-13 16:40:46,075 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:46,106 - INFO - Processing Karur Vysya Bank Ltd. (KARURVYSYA)
# 2025-04-13 16:40:46,182 - INFO - Verified unique data for JUBLPHARMA: Latest price = Rs.918.30
# 2025-04-13 16:40:46,184 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:46,217 - INFO - Processing Kaynes Technology India Ltd. (KAYNES)
# 2025-04-13 16:40:46,556 - INFO - Verified unique data for JUSTDIAL: Latest price = Rs.835.50
# 2025-04-13 16:40:46,559 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:46,589 - INFO - Processing Kec International Ltd. (KEC)
# 2025-04-13 16:40:46,697 - INFO - Verified unique data for JYOTHYLAB: Latest price = Rs.366.80
# 2025-04-13 16:40:46,713 - INFO - Verified unique data for JYOTICNC: Latest price = Rs.1011.30
# 2025-04-13 16:40:46,725 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:46,728 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:46,779 - INFO - Processing Kfin Technologies Ltd. (KFINTECH)
# 2025-04-13 16:40:46,796 - INFO - Verified unique data for JWL: Latest price = Rs.370.90
# 2025-04-13 16:40:46,800 - INFO - Processing Kirloskar Brothers Ltd. (KIRLOSBROS)
# 2025-04-13 16:40:46,801 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:46,857 - INFO - Processing Kirloskar Oil Eng Ltd. (KIRLOSENG)
# 2025-04-13 16:40:46,868 - INFO - Verified unique data for KNRCON: Latest price = Rs.227.62
# 2025-04-13 16:40:46,869 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:46,904 - INFO - Processing Krishna Institute of Medical Sciences Ltd. (KIMS)
# 2025-04-13 16:40:46,939 - INFO - Verified unique data for KAJARIACER: Latest price = Rs.801.20
# 2025-04-13 16:40:46,940 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:46,969 - INFO - Processing LT Foods Ltd. (LTFOODS)
# 2025-04-13 16:40:47,282 - INFO - Verified unique data for KANSAINER: Latest price = Rs.249.58
# 2025-04-13 16:40:47,284 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:47,328 - INFO - Processing Latent View Analytics Ltd. (LATENTVIEW)
# 2025-04-13 16:40:47,373 - INFO - Verified unique data for KARURVYSYA: Latest price = Rs.209.50
# 2025-04-13 16:40:47,377 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:47,433 - INFO - Processing Laurus Labs Ltd. (LAURUSLABS)
# 2025-04-13 16:40:47,446 - INFO - Verified unique data for KAYNES: Latest price = Rs.5091.15
# 2025-04-13 16:40:47,468 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:47,496 - INFO - Processing Lemon Tree Hotels Ltd. (LEMONTREE)
# 2025-04-13 16:40:47,613 - INFO - Verified unique data for KPIL: Latest price = Rs.896.30
# 2025-04-13 16:40:47,615 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:47,643 - INFO - Processing MMTC Ltd. (MMTC)
# 2025-04-13 16:40:47,859 - INFO - Verified unique data for KEC: Latest price = Rs.660.05
# 2025-04-13 16:40:47,860 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:47,892 - INFO - Processing Mahanagar Gas Ltd. (MGL)
# 2025-04-13 16:40:47,939 - INFO - Verified unique data for KFINTECH: Latest price = Rs.998.35
# 2025-04-13 16:40:47,940 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:47,968 - INFO - Processing Maharashtra Seamless Ltd. (MAHSEAMLES)
# 2025-04-13 16:40:48,025 - INFO - Verified unique data for KIRLOSBROS: Latest price = Rs.1625.55
# 2025-04-13 16:40:48,038 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:48,090 - INFO - Verified unique data for KIRLOSENG: Latest price = Rs.726.15
# 2025-04-13 16:40:48,103 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:48,111 - INFO - Processing Manappuram Finance Ltd. (MANAPPURAM)
# 2025-04-13 16:40:48,173 - INFO - Processing Mastek Ltd. (MASTEK)
# 2025-04-13 16:40:48,187 - INFO - LTFOODS.NS: 1d: div-adjust-repair-bad: Repaired too-small div-adjust: ['2024-11-06']
# 2025-04-13 16:40:48,188 - INFO - Verified unique data for KIMS: Latest price = Rs.616.75
# 2025-04-13 16:40:48,196 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:48,314 - INFO - Processing Metropolis Healthcare Ltd. (METROPOLIS)
# 2025-04-13 16:40:48,465 - INFO - Verified unique data for LATENTVIEW: Latest price = Rs.379.90
# 2025-04-13 16:40:48,466 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:48,499 - INFO - Processing Minda Corporation Ltd. (MINDACORP)
# 2025-04-13 16:40:48,617 - INFO - Verified unique data for LTFOODS: Latest price = Rs.354.35
# 2025-04-13 16:40:48,623 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:48,666 - INFO - Processing Multi Commodity Exchange of India Ltd. (MCX)
# 2025-04-13 16:40:48,677 - INFO - Verified unique data for LAURUSLABS: Latest price = Rs.605.85
# 2025-04-13 16:40:48,687 - INFO - Verified unique data for LEMONTREE: Latest price = Rs.139.75
# 2025-04-13 16:40:48,688 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:48,689 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:48,746 - INFO - Processing NATCO Pharma Ltd. (NATCOPHARM)
# 2025-04-13 16:40:48,749 - INFO - Processing NBCC (India) Ltd. (NBCC)
# 2025-04-13 16:40:48,794 - INFO - Verified unique data for MMTC: Latest price = Rs.50.36
# 2025-04-13 16:40:48,795 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:48,823 - INFO - Processing NCC Ltd. (NCC)
# 2025-04-13 16:40:49,091 - INFO - Verified unique data for MGL: Latest price = Rs.1277.50
# 2025-04-13 16:40:49,092 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:49,121 - INFO - Processing NMDC Steel Ltd. (NSLNISP)
# 2025-04-13 16:40:49,187 - INFO - Verified unique data for MAHSEAMLES: Latest price = Rs.663.90
# 2025-04-13 16:40:49,189 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:49,220 - INFO - Processing Narayana Hrudayalaya Ltd. (NH)
# 2025-04-13 16:40:49,412 - INFO - Verified unique data for MANAPPURAM: Latest price = Rs.225.94
# 2025-04-13 16:40:49,418 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:49,450 - INFO - Verified unique data for MASTEK: Latest price = Rs.2196.20
# 2025-04-13 16:40:49,460 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:49,461 - INFO - Processing Nava Ltd. (NAVA)
# 2025-04-13 16:40:49,502 - INFO - Processing Navin Fluorine International Ltd. (NAVINFLUOR)
# 2025-04-13 16:40:49,523 - INFO - Verified unique data for METROPOLIS: Latest price = Rs.1601.60
# 2025-04-13 16:40:49,524 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:49,552 - INFO - Processing Netweb Technologies India Ltd. (NETWEB)
# 2025-04-13 16:40:49,663 - INFO - Verified unique data for MINDACORP: Latest price = Rs.494.50
# 2025-04-13 16:40:49,665 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:49,707 - INFO - Processing Network18 Media & Investments Ltd. (NETWORK18)
# 2025-04-13 16:40:49,905 - INFO - Verified unique data for MCX: Latest price = Rs.5441.45
# 2025-04-13 16:40:49,906 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:49,960 - INFO - Processing Neuland Laboratories Ltd. (NEULANDLAB)
# 2025-04-13 16:40:50,011 - INFO - Verified unique data for NBCC: Latest price = Rs.89.10
# 2025-04-13 16:40:50,023 - INFO - Verified unique data for NATCOPHARM: Latest price = Rs.775.50
# 2025-04-13 16:40:50,033 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:50,042 - INFO - NCC.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-08-24']
# 2025-04-13 16:40:50,043 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:50,102 - INFO - Processing Newgen Software Technologies Ltd. (NEWGEN)
# 2025-04-13 16:40:50,112 - INFO - Processing Niva Bupa Health Insurance Company Ltd. (NIVABUPA)
# 2025-04-13 16:40:50,123 - INFO - Verified unique data for NCC: Latest price = Rs.209.97
# 2025-04-13 16:40:50,125 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:50,155 - INFO - Processing Nuvama Wealth Management Ltd. (NUVAMA)
# 2025-04-13 16:40:50,248 - INFO - Verified unique data for NSLNISP: Latest price = Rs.35.04
# 2025-04-13 16:40:50,249 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:50,277 - INFO - Processing Olectra Greentech Ltd. (OLECTRA)
# ...
# 2025-04-13 16:40:54,328 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:54,356 - INFO - Processing Sai Life Sciences Ltd. (SAILIFE)
# 2025-04-13 16:40:54,577 - INFO - Verified unique data for RTNINDIA: Latest price = Rs.40.85
# 2025-04-13 16:40:54,578 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:54,606 - INFO - Processing Sammaan Capital Ltd. (SAMMAANCAP)
# 2025-04-13 16:40:54,692 - INFO - Verified unique data for RAYMONDLSL: Latest price = Rs.1042.55
# 2025-04-13 16:40:54,693 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:54,721 - INFO - Processing Sapphire Foods India Ltd. (SAPPHIRE)
# 2025-04-13 16:40:54,908 - INFO - Verified unique data for RAYMOND: Latest price = Rs.1493.15
# 2025-04-13 16:40:54,909 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:54,941 - INFO - Processing Sarda Energy and Minerals Ltd. (SARDAEN)
# 2025-04-13 16:40:55,137 - INFO - REDINGTON.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-07-06']
# 2025-04-13 16:40:55,157 - INFO - Verified unique data for REDINGTON: Latest price = Rs.215.48
# 2025-04-13 16:40:55,160 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:55,210 - INFO - Verified unique data for RPOWER: Latest price = Rs.40.03
# 2025-04-13 16:40:55,213 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:55,215 - INFO - Processing Saregama India Ltd (SAREGAMA)
# 2025-04-13 16:40:55,244 - INFO - Processing Schneider Electric Infrastructure Ltd. (SCHNEIDER)
# 2025-04-13 16:40:55,353 - INFO - Verified unique data for ROUTE: Latest price = Rs.975.40
# 2025-04-13 16:40:55,354 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:55,386 - INFO - Processing Shipping Corporation of India Ltd. (SCI)
# 2025-04-13 16:40:55,437 - INFO - Verified unique data for SAGILITY: Latest price = Rs.39.87
# 2025-04-13 16:40:55,452 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:55,506 - INFO - Processing Shree Renuka Sugars Ltd. (RENUKA)
# 2025-04-13 16:40:55,526 - INFO - Verified unique data for SAILIFE: Latest price = Rs.669.50
# 2025-04-13 16:40:55,533 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:55,538 - INFO - Verified unique data for SKFINDIA: Latest price = Rs.3861.95
# 2025-04-13 16:40:55,553 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:55,559 - INFO - Processing Shyam Metalics and Energy Ltd. (SHYAMMETL)
# 2025-04-13 16:40:55,590 - INFO - Processing Signatureglobal (India) Ltd. (SIGNATURE)
# 2025-04-13 16:40:55,637 - INFO - Verified unique data for SBFC: Latest price = Rs.89.67
# 2025-04-13 16:40:55,638 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:55,663 - INFO - Processing Sobha Ltd. (SOBHA)
# 2025-04-13 16:40:55,784 - INFO - Verified unique data for SAMMAANCAP: Latest price = Rs.107.80
# 2025-04-13 16:40:55,785 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:55,813 - INFO - Processing Sonata Software Ltd. (SONATSOFTW)
# 2025-04-13 16:40:55,907 - INFO - Verified unique data for SAPPHIRE: Latest price = Rs.305.30
# 2025-04-13 16:40:55,908 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:55,936 - INFO - Processing Sterling and Wilson Renewable Energy Ltd. (SWSOLAR)
# 2025-04-13 16:40:56,101 - INFO - Verified unique data for SARDAEN: Latest price = Rs.467.65
# 2025-04-13 16:40:56,102 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:56,131 - INFO - Processing Sumitomo Chemical India Ltd. (SUMICHEM)
# 2025-04-13 16:40:56,409 - INFO - Verified unique data for SCHNEIDER: Latest price = Rs.594.30
# 2025-04-13 16:40:56,410 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:56,461 - INFO - Processing Suven Pharmaceuticals Ltd. (SUVENPHAR)
# 2025-04-13 16:40:56,472 - INFO - Verified unique data for SAREGAMA: Latest price = Rs.524.05
# 2025-04-13 16:40:56,473 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:56,501 - INFO - Processing Swan Energy Ltd. (SWANENERGY)
# 2025-04-13 16:40:56,594 - INFO - Verified unique data for SCI: Latest price = Rs.171.75
# 2025-04-13 16:40:56,597 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:56,626 - INFO - Processing Syrma SGS Technology Ltd. (SYRMA)
# 2025-04-13 16:40:56,654 - INFO - Verified unique data for RENUKA: Latest price = Rs.26.98
# 2025-04-13 16:40:56,655 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:56,687 - INFO - Processing TBO Tek Ltd. (TBOTEK)
# 2025-04-13 16:40:56,708 - INFO - Verified unique data for SIGNATURE: Latest price = Rs.1088.40
# 2025-04-13 16:40:56,709 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:56,734 - INFO - Processing Tanla Platforms Ltd. (TANLA)
# 2025-04-13 16:40:56,793 - INFO - Verified unique data for SHYAMMETL: Latest price = Rs.843.85
# 2025-04-13 16:40:56,794 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:56,825 - INFO - Processing Tata Chemicals Ltd. (TATACHEM)
# 2025-04-13 16:40:56,858 - INFO - Verified unique data for SOBHA: Latest price = Rs.1127.15
# 2025-04-13 16:40:56,859 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:56,887 - INFO - Processing Tata Teleservices (Maharashtra) Ltd. (TTML)
# 2025-04-13 16:40:57,053 - INFO - Verified unique data for SONATSOFTW: Latest price = Rs.315.55
# 2025-04-13 16:40:57,054 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:57,095 - INFO - Processing Techno Electric & Engineering Company Ltd. (TECHNOE)
# 2025-04-13 16:40:57,106 - INFO - Verified unique data for SWSOLAR: Latest price = Rs.250.85
# 2025-04-13 16:40:57,107 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:57,137 - INFO - Processing Tejas Networks Ltd. (TEJASNET)
# 2025-04-13 16:40:57,264 - INFO - SUMICHEM.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-07-21']
# 2025-04-13 16:40:57,282 - INFO - Verified unique data for SUMICHEM: Latest price = Rs.565.25
# 2025-04-13 16:40:57,283 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:57,312 - INFO - Processing The Ramco Cements Ltd. (RAMCOCEM)
# 2025-04-13 16:40:57,646 - INFO - Verified unique data for SUVENPHAR: Latest price = Rs.1149.60
# 2025-04-13 16:40:57,647 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:57,678 - INFO - Processing Timken India Ltd. (TIMKEN)
# 2025-04-13 16:40:57,724 - INFO - Verified unique data for SWANENERGY: Latest price = Rs.396.95
# 2025-04-13 16:40:57,725 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:57,758 - INFO - Processing Titagarh Rail Systems Ltd. (TITAGARH)
# 2025-04-13 16:40:57,789 - INFO - Verified unique data for SYRMA: Latest price = Rs.479.80
# 2025-04-13 16:40:57,790 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:57,823 - INFO - Processing Transformers And Rectifiers (India) Ltd. (TARIL)
# 2025-04-13 16:40:57,843 - INFO - Verified unique data for TBOTEK: Latest price = Rs.1073.90
# 2025-04-13 16:40:57,844 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:57,867 - INFO - Processing Trident Ltd. (TRIDENT)
# 2025-04-13 16:40:57,920 - INFO - Verified unique data for TANLA: Latest price = Rs.483.90
# 2025-04-13 16:40:57,921 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:57,949 - INFO - Processing Triveni Engineering & Industries Ltd. (TRIVENI)
# 2025-04-13 16:40:57,981 - INFO - Verified unique data for TATACHEM: Latest price = Rs.832.25
# 2025-04-13 16:40:57,982 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:58,020 - INFO - Processing Triveni Turbine Ltd. (TRITURBINE)
# 2025-04-13 16:40:58,033 - INFO - Verified unique data for TTML: Latest price = Rs.56.63
# 2025-04-13 16:40:58,034 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:58,062 - INFO - Processing UCO Bank (UCOBANK)
# 2025-04-13 16:40:58,249 - INFO - Verified unique data for TECHNOE: Latest price = Rs.987.95
# 2025-04-13 16:40:58,250 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:58,294 - INFO - Processing UTI Asset Management Company Ltd. (UTIAMC)
# 2025-04-13 16:40:58,304 - INFO - Verified unique data for TEJASNET: Latest price = Rs.837.80
# 2025-04-13 16:40:58,304 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:58,336 - INFO - Processing Usha Martin Ltd. (USHAMART)
# 2025-04-13 16:40:58,540 - INFO - RAMCOCEM.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-08-02']
# 2025-04-13 16:40:58,557 - INFO - Verified unique data for RAMCOCEM: Latest price = Rs.936.85
# 2025-04-13 16:40:58,558 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:58,588 - INFO - Processing V-Guard Industries Ltd. (VGUARD)
# 2025-04-13 16:40:58,844 - INFO - Verified unique data for TIMKEN: Latest price = Rs.2474.60
# 2025-04-13 16:40:58,845 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:58,876 - INFO - Processing Valor Estate Ltd. (DBREALTY)
# 2025-04-13 16:40:58,980 - INFO - Verified unique data for TARIL: Latest price = Rs.544.60
# 2025-04-13 16:40:58,990 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:59,033 - INFO - Verified unique data for TITAGARH: Latest price = Rs.746.95
# 2025-04-13 16:40:59,035 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:59,037 - INFO - Processing Vardhman Textiles Ltd. (VTL)
# 2025-04-13 16:40:59,084 - INFO - Processing Vedant Fashions Ltd. (MANYAVAR)
# 2025-04-13 16:40:59,124 - INFO - Verified unique data for TRIDENT: Latest price = Rs.26.08
# 2025-04-13 16:40:59,128 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:59,170 - INFO - Verified unique data for TRIVENI: Latest price = Rs.379.90
# 2025-04-13 16:40:59,172 - INFO - Processing Vijaya Diagnostic Centre Ltd. (VIJAYA)
# 2025-04-13 16:40:59,173 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:59,205 - INFO - Processing Welspun Corp Ltd. (WELCORP)
# 2025-04-13 16:40:59,238 - INFO - Verified unique data for TRITURBINE: Latest price = Rs.495.80
# 2025-04-13 16:40:59,239 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:59,269 - INFO - Processing Welspun Living Ltd. (WELSPUNLIV)
# 2025-04-13 16:40:59,301 - INFO - Verified unique data for UCOBANK: Latest price = Rs.28.94
# 2025-04-13 16:40:59,302 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:59,332 - INFO - Processing Westlife Foodworld Ltd. (WESTLIFE)
# 2025-04-13 16:40:59,526 - INFO - Verified unique data for USHAMART: Latest price = Rs.306.10
# 2025-04-13 16:40:59,529 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:59,558 - INFO - Verified unique data for UTIAMC: Latest price = Rs.998.15
# 2025-04-13 16:40:59,568 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:59,569 - INFO - Processing Whirlpool of India Ltd. (WHIRLPOOL)
# 2025-04-13 16:40:59,601 - INFO - Processing Wockhardt Ltd. (WOCKPHARMA)
# 2025-04-13 16:40:59,758 - INFO - Verified unique data for VGUARD: Latest price = Rs.361.90
# 2025-04-13 16:40:59,759 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:40:59,788 - INFO - Processing ZF Commercial Vehicle Control Systems India Ltd. (ZFCVINDIA)
# 2025-04-13 16:41:00,052 - INFO - Verified unique data for DBREALTY: Latest price = Rs.174.48
# 2025-04-13 16:41:00,053 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:00,084 - INFO - Processing Zee Entertainment Enterprises Ltd. (ZEEL)
# 2025-04-13 16:41:00,259 - INFO - Verified unique data for MANYAVAR: Latest price = Rs.802.45
# 2025-04-13 16:41:00,267 - INFO - Verified unique data for VTL: Latest price = Rs.461.10
# 2025-04-13 16:41:00,268 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:00,269 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:00,331 - INFO - Processing Zen Technologies Ltd. (ZENTEC)
# 2025-04-13 16:41:00,333 - INFO - Processing Zensar Technolgies Ltd. (ZENSARTECH)
# 2025-04-13 16:41:00,368 - INFO - Verified unique data for VIJAYA: Latest price = Rs.965.40
# 2025-04-13 16:41:00,369 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:00,398 - INFO - Processing eClerx Services Ltd. (ECLERX)
# 2025-04-13 16:41:00,429 - INFO - Verified unique data for WELCORP: Latest price = Rs.758.50
# 2025-04-13 16:41:00,430 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:00,510 - INFO - Verified unique data for WESTLIFE: Latest price = Rs.708.45
# 2025-04-13 16:41:00,514 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:00,551 - INFO - Verified unique data for WELSPUNLIV: Latest price = Rs.123.85
# 2025-04-13 16:41:00,553 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:00,760 - INFO - Verified unique data for WOCKPHARMA: Latest price = Rs.1319.15
# 2025-04-13 16:41:00,761 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:00,999 - INFO - Verified unique data for WHIRLPOOL: Latest price = Rs.1106.55
# 2025-04-13 16:41:01,009 - INFO - Verified unique data for ZFCVINDIA: Latest price = Rs.12449.20
# 2025-04-13 16:41:01,010 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:01,011 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:01,289 - INFO - Verified unique data for ZEEL: Latest price = Rs.103.85
# 2025-04-13 16:41:01,291 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:01,475 - INFO - Verified unique data for ZENTEC: Latest price = Rs.1462.00
# 2025-04-13 16:41:01,476 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:01,560 - INFO - Verified unique data for ECLERX: Latest price = Rs.2402.20
# 2025-04-13 16:41:01,575 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:01,617 - INFO - Verified unique data for ZENSARTECH: Latest price = Rs.633.45
# 2025-04-13 16:41:01,619 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)

# %%
stock_list_microcap = """Company Name	Symbol
AGI Greenpac Ltd.	AGI
ASK Automotive Ltd.	ASKAUTOLTD
Aarti Drugs Ltd.	AARTIDRUGS
Aarti Pharmalabs Ltd.	AARTIPHARM
Aditya Vision Ltd.	AVL
Advanced Enzyme Tech Ltd.	ADVENZYMES
Aether Industries Ltd.	AETHER
Ahluwalia Contracts (India) Ltd.	AHLUCONT
Akzo Nobel India Ltd.	AKZOINDIA
Allcargo Logistics Ltd.	ALLCARGO
Allied Blenders and Distillers Ltd.	ABDL
Ami Organics Ltd.	AMIORG
Apeejay Surrendra Park Hotels Ltd.	PARKHOTELS
Archean Chemical Industries Ltd.	ACI
Arvind Fashions Ltd.	ARVINDFASN
Arvind Ltd.	ARVIND
Ashoka Buildcon Ltd.	ASHOKA
Astra Microwave Products Ltd.	ASTRAMICRO
Aurionpro Solution Ltd.	AURIONPRO
Avalon Technologies Ltd.	AVALON
Avanti Feeds Ltd.	AVANTIFEED
Awfis Space Solutions Ltd.	AWFIS
Azad Engineering Ltd.	AZAD
Bajaj Hindusthan Sugar Ltd.	BAJAJHIND
Balaji Amines Ltd.	BALAMINES
Balu Forge Industries Ltd.	BALUFORGE
Banco Products (India) Ltd.	BANCOINDIA
Bansal Wire Industries Ltd.	BANSALWIRE
Bhansali Engineering Polymers Ltd.	BEPL
Bharat Bijlee Ltd.	BBL
Birla Corporation Ltd.	BIRLACORPN
Blue Jet Healthcare Ltd.	BLUEJET
Bombay Dyeing & Manufacturing Co. Ltd.	BOMDYEING
Borosil Ltd.	BOROLTD
Borosil Renewables Ltd.	BORORENEW
CIE Automotive India Ltd.	CIEINDIA
CMS Info Systems Ltd.	CMSINFO
CSB Bank Ltd.	CSBBANK
Cartrade Tech Ltd.	CARTRADE
Ceigall India Ltd.	CEIGALL
Cello World Ltd.	CELLO
Chemplast Sanmar Ltd.	CHEMPLASTS
Choice International Ltd.	CHOICEIN
Cigniti Technologies Ltd.	CIGNITITEC
Cyient DLM Ltd.	CYIENTDLM
DCB Bank Ltd.	DCBBANK
DCX Systems Ltd.	DCXINDIA
Datamatics Global Services Ltd.	DATAMATICS
Dhani Services Ltd.	DHANI
Dilip Buildcon Ltd.	DBL
Dishman Carbogen Amcis Ltd.	DCAL
Dodla Dairy Ltd.	DODLA
Dynamatic Technologies Ltd.	DYNAMATECH
EPL Ltd.	EPL
Easy Trip Planners Ltd.	EASEMYTRIP
Edelweiss Financial Services Ltd.	EDELWEISS
Electronics Mart India Ltd.	EMIL
Electrosteel Castings Ltd.	ELECTCAST
Embassy Developments Ltd.	EMBDL
Entero Healthcare Solutions Ltd.	ENTERO
Enviro Infra Engineers Ltd.	EIEL
Epigral Ltd.	EPIGRAL
Equitas Small Finance Bank Ltd.	EQUITASBNK
Ethos Ltd.	ETHOSLTD
Eureka Forbes Ltd.	EUREKAFORB
FDC Ltd.	FDC
Fiem Industries Ltd	FIEMIND
Fine Organic Industries Ltd.	FINEORG
Fineotex Chemical Ltd.	FCL
Force Motors Ltd.	FORCEMOT
G R Infraprojects Ltd.	GRINFRA
GHCL Ltd.	GHCL
GMM Pfaudler Ltd.	GMMPFAUDLR
GMR Power and Urban Infra Ltd.	GMRP&UI
Gabriel India Ltd.	GABRIEL
Ganesh Housing Corporation Ltd.	GANESHHOUC
Ganesha Ecosphere Ltd.	GANECOS
Garware Hi-Tech Films Ltd.	GRWRHITECH
Garware Technical Fibres Ltd.	GARFIBRES
Gateway Distriparks Ltd.	GATEWAY
Gokaldas Exports Ltd.	GOKEX
Gopal Snacks Ltd.	GOPAL
Greaves Cotton Ltd.	GREAVESCOT
Greenpanel Industries Ltd.	GREENPANEL
Greenply Industries Ltd.	GREENPLY
Gujarat Ambuja Exports Ltd.	GAEL
Gujarat State Fertilizers & Chemicals Ltd.	GSFC
Gulf Oil Lubricants India Ltd.	GULFOILLUB
H.G. Infra Engineering Ltd.	HGINFRA
Hathway Cable & Datacom Ltd.	HATHWAY
Healthcare Global Enterprises Ltd.	HCG
HeidelbergCement India Ltd.	HEIDELBERG
Hemisphere Properties India Ltd.	HEMIPROP
Heritage Foods Ltd.	HERITGFOOD
Hikal Ltd.	HIKAL
Hindustan Construction Co. Ltd.	HCC
IFB Industries Ltd.	IFBIND
IIFL Capital Services Ltd.	IIFLCAPS
ITD Cementation India Ltd.	ITDCEM
Imagicaaworld Entertainment Ltd.	IMAGICAA
India Glycols Ltd.	INDIAGLYCO
India Shelter Finance Corporation Ltd.	INDIASHLTR
Indian Metals & Ferro Alloys Ltd.	IMFA
Indigo Paints Ltd.	INDIGOPNTS
Indo Count Industries Ltd.	ICIL
Infibeam Avenues Ltd.	INFIBEAM
Ingersoll Rand (India) Ltd.	INGERRAND
Innova Captab Ltd.	INNOVACAP
Inox Green Energy Services Ltd.	INOXGREEN
Ion Exchange (India) Ltd.	IONEXCHANG
Isgec Heavy Engineering Ltd.	ISGEC
J.Kumar Infraprojects Ltd.	JKIL
JK Lakshmi Cement Ltd.	JKLAKSHMI
JK Paper Ltd.	JKPAPER
JTL Industries Ltd.	JTLIND
Jai Balaji Industries Ltd.	JAIBALAJI
Jai Corp Ltd.	JAICORPLTD
Jain Irrigation Systems Ltd.	JISLJALEQS
Jamna Auto Industries Ltd.	JAMNAAUTO
Jana Small Finance Bank Ltd.	JSFB
Jindal Worldwide Ltd.	JINDWORLD
Johnson Controls - Hitachi Air Conditioning India Ltd.	JCHAC
KPI Green Energy Ltd.	KPIGREEN
KRBL Ltd.	KRBL
KSB Ltd.	KSB
Kalyani Steels Ltd.	KSL
Karnataka Bank Ltd.	KTKBANK
Kaveri Seed Company Ltd.	KSCL
Kirloskar Pneumatic Company Ltd.	KIRLPNU
LMW Ltd.	LMW
Laxmi Organic Industries Ltd.	LXCHEM
Le Travenues Technology Ltd.	IXIGO
Lloyds Engineering Works Ltd.	LLOYDSENGG
Lloyds Enterprises Ltd.	LLOYDSENT
Lux Industries Ltd.	LUXIND
MOIL Ltd.	MOIL
MSTC Ltd.	MSTCLTD
MTAR Technologies Ltd.	MTARTECH
Maharashtra Scooters Ltd.	MAHSCOOTER
Mahindra Lifespace Developers Ltd.	MAHLIFE
Man Infraconstruction Ltd.	MANINFRA
Marksans Pharma Ltd.	MARKSANS
Max Estates Ltd.	MAXESTATES
Medplus Health Services Ltd.	MEDPLUS
Mishra Dhatu Nigam Ltd.	MIDHANI
Mrs. Bectors Food Specialities Ltd.	BECTORFOOD
NEOGEN CHEMICALS LTD.	NEOGEN
NESCO Ltd.	NESCO
NOCIL Ltd.	NOCIL
National Fertilizers Ltd.	NFL
Nazara Technologies Ltd.	NAZARA
Nuvoco Vistas Corporation Ltd.	NUVOCO
Optiemus Infracom Ltd.	OPTIEMUS
Orchid Pharma Ltd.	ORCHPHARMA
Orient Cement Ltd.	ORIENTCEM
Orissa Min Dev Co Ltd.	ORISSAMINE
P N Gadgil Jewellers Ltd.	PNGJL
PC Jeweller Ltd.	PCJEWELLER
PTC India Ltd.	PTC
Paisalo Digital Ltd.	PAISALO
Paradeep Phosphates Ltd.	PARADEEP
Paras Defence and Space Technologies Ltd.	PARAS
Patel Engineering Ltd.	PATELENG
Pearl Global Industries Ltd.	PGIL
Polyplex Corporation Ltd.	POLYPLEX
Power Mech Projects Ltd.	POWERMECH
Pricol Ltd.	PRICOLLTD
Prince Pipes and Fittings Ltd.	PRINCEPIPE
Prism Johnson Ltd.	PRSMJOHNSN
Prudent Corporate Advisory Services Ltd.	PRUDENT
Rain Industries Ltd	RAIN
Rajesh Exports Ltd.	RAJESHEXPO
Rallis India Ltd.	RALLIS
Rategain Travel Technologies Ltd.	RATEGAIN
RattanIndia Power Ltd.	RTNPOWER
Redtape Ltd.	REDTAPE
Refex Industries Ltd.	REFEX
Reliance Infrastructure Ltd.	RELINFRA
Religare Enterprises Ltd.	RELIGARE
Responsive Industries Ltd.	RESPONIND
Restaurant Brands Asia Ltd.	RBA
Rossari Biotech Ltd.	ROSSARI
Safari Industries (India) Ltd.	SAFARI
Samhi Hotels Ltd.	SAMHI
Sanofi Consumer Healthcare India Ltd.	SANOFICONR
Sanofi India Ltd.	SANOFI
Sansera Engineering Ltd.	SANSERA
Senco Gold Ltd.	SENCO
Sequent Scientific Ltd.	SEQUENT
Shaily Engineering Plastics Ltd.	SHAILY
Shakti Pumps (India) Ltd.	SHAKTIPUMP
Sharda Cropchem Ltd.	SHARDACROP
Share India Securities Ltd.	SHAREINDIA
Sheela Foam Ltd.	SFL
Shilpa Medicare Ltd.	SHILPAMED
Shivalik Bimetal Controls Ltd.	SBCL
Shoppers Stop Ltd.	SHOPERSTOP
Shriram Pistons & Rings Ltd.	SHRIPISTON
Skipper Ltd.	SKIPPER
South Indian Bank Ltd.	SOUTHBANK
Spandana Sphoorty Financial Ltd.	SPANDANA
Star Cement Ltd.	STARCEMENT
Sterlite Technologies Ltd.	STLTECH
Strides Pharma Science Ltd.	STAR
Stylam Industries Ltd.	STYLAMIND
Subros Ltd.	SUBROS
Sudarshan Chemical Industries Ltd.	SUDARSCHEM
Sula Vineyards Ltd.	SULA
Sun Pharma Advanced Research Company Ltd.	SPARC
Sunflag Iron & Steel Company Ltd.	SUNFLAG
Sunteck Realty Ltd.	SUNTECK
Suprajit Engineering Ltd.	SUPRAJIT
Supriya Lifescience Ltd.	SUPRIYA
Surya Roshni Ltd.	SURYAROSNI
Symphony Ltd.	SYMPHONY
TARC Ltd.	TARC
TD Power Systems Ltd.	TDPOWERSYS
TVS Supply Chain Solutions Ltd.	TVSSCS
Teamlease Services Ltd.	TEAMLEASE
Technocraft Industries (India) Ltd.	TIIL
Tega Industries Ltd.	TEGA
Texmaco Rail & Eng. Ltd.	TEXRAIL
Thangamayil Jewellery Ltd.	THANGAMAYL
The Anup Engineering Ltd.	ANUP
Thirumalai Chemicals Ltd.	TIRUMALCHM
Thomas Cook (India) Ltd.	THOMASCOOK
Tilaknagar Industries Ltd.	TI
Time Technoplast Ltd.	TIMETECHNO
Tips Music Ltd.	TIPSMUSIC
Transrail Lighting Ltd.	TRANSRAILL
Ujjivan Small Finance Bank Ltd.	UJJIVANSFB
Unimech Aerospace and Manufacturing Ltd.	UNIMECH
V-Mart Retail Ltd.	VMART
V.I.P. Industries Ltd.	VIPIND
VST Industries Ltd.	VSTIND
Va Tech Wabag Ltd.	WABAG
Vaibhav Global Ltd.	VAIBHAVGBL
Varroc Engineering Ltd.	VARROC
Ventive Hospitality Ltd.	VENTIVE
Venus Pipes & Tubes Ltd.	VENUSPIPES
Vesuvius India Ltd.	VESUVIUS
Voltamp Transformers Ltd	VOLTAMP
Websol Energy System Ltd.	WEBELSOLAR
Welspun Enterprises Ltd.	WELENT
Wonderla Holidays Ltd.	WONDERLA
Yatharth Hospital & Trauma Care Services Ltd.	YATHARTH
Zaggle Prepaid Ocean Services Ltd.	ZAGGLE
Zinka Logistics Solutions Ltd.	BLACKBUCK
Zydus Wellness Ltd.	ZYDUSWELL
eMudhra Ltd.	EMUDHRA"""


stocks_microcap = parse_stock_list(stock_list_microcap)
results = analyze_stocks(stocks_microcap, output_dir="stock_analysis/reports_v2/microcap_250", max_workers=10, end_date="2025-04-12")
# Out:
# 2025-04-13 16:41:05,859 - INFO - Processing AGI Greenpac Ltd. (AGI)
# 2025-04-13 16:41:05,860 - INFO - Processing ASK Automotive Ltd. (ASKAUTOLTD)
# 2025-04-13 16:41:05,862 - INFO - Processing Aarti Drugs Ltd. (AARTIDRUGS)
# 2025-04-13 16:41:05,863 - INFO - Processing Aarti Pharmalabs Ltd. (AARTIPHARM)
# 2025-04-13 16:41:05,866 - INFO - Processing Aditya Vision Ltd. (AVL)
# 2025-04-13 16:41:05,867 - INFO - Processing Advanced Enzyme Tech Ltd. (ADVENZYMES)
# 2025-04-13 16:41:05,870 - INFO - Processing Aether Industries Ltd. (AETHER)
# 2025-04-13 16:41:05,870 - INFO - Processing Ahluwalia Contracts (India) Ltd. (AHLUCONT)
# 2025-04-13 16:41:05,872 - INFO - Processing Akzo Nobel India Ltd. (AKZOINDIA)
# 2025-04-13 16:41:05,874 - INFO - Processing Allcargo Logistics Ltd. (ALLCARGO)
# 2025-04-13 16:41:07,037 - INFO - Verified unique data for AVL: Latest price = Rs.427.85
# 2025-04-13 16:41:07,056 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:07,117 - INFO - Processing Allied Blenders and Distillers Ltd. (ABDL)
# 2025-04-13 16:41:07,271 - INFO - Verified unique data for AETHER: Latest price = Rs.824.95
# 2025-04-13 16:41:07,288 - INFO - Verified unique data for ADVENZYMES: Latest price = Rs.276.45
# 2025-04-13 16:41:07,289 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:07,308 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:07,347 - INFO - Verified unique data for AARTIPHARM: Latest price = Rs.679.40
# 2025-04-13 16:41:07,386 - INFO - Verified unique data for ALLCARGO: Latest price = Rs.27.72
# 2025-04-13 16:41:07,391 - INFO - Verified unique data for AKZOINDIA: Latest price = Rs.3510.45
# 2025-04-13 16:41:07,418 - INFO - Verified unique data for AHLUCONT: Latest price = Rs.862.55
# 2025-04-13 16:41:07,443 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:07,456 - INFO - Verified unique data for AARTIDRUGS: Latest price = Rs.329.15
# 2025-04-13 16:41:07,460 - INFO - Processing Ami Organics Ltd. (AMIORG)
# 2025-04-13 16:41:07,466 - INFO - Verified unique data for AGI: Latest price = Rs.768.55
# 2025-04-13 16:41:07,470 - INFO - Processing Apeejay Surrendra Park Hotels Ltd. (PARKHOTELS)
# 2025-04-13 16:41:07,472 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:07,475 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:07,476 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:07,494 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:07,505 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:07,515 - INFO - Processing Archean Chemical Industries Ltd. (ACI)
# 2025-04-13 16:41:07,586 - INFO - Processing Arvind Fashions Ltd. (ARVINDFASN)
# 2025-04-13 16:41:07,621 - INFO - Processing Arvind Ltd. (ARVIND)
# 2025-04-13 16:41:07,663 - INFO - Processing Ashoka Buildcon Ltd. (ASHOKA)
# 2025-04-13 16:41:07,673 - INFO - Processing Astra Microwave Products Ltd. (ASTRAMICRO)
# 2025-04-13 16:41:07,674 - INFO - Processing Aurionpro Solution Ltd. (AURIONPRO)
# 2025-04-13 16:41:07,715 - INFO - Verified unique data for ASKAUTOLTD: Latest price = Rs.407.60
# 2025-04-13 16:41:07,716 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:07,745 - INFO - Processing Avalon Technologies Ltd. (AVALON)
# 2025-04-13 16:41:08,260 - INFO - Verified unique data for ABDL: Latest price = Rs.319.05
# 2025-04-13 16:41:08,261 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:08,282 - INFO - Processing Avanti Feeds Ltd. (AVANTIFEED)
# 2025-04-13 16:41:08,658 - INFO - Verified unique data for AMIORG: Latest price = Rs.2256.65
# 2025-04-13 16:41:08,666 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:08,671 - INFO - Verified unique data for PARKHOTELS: Latest price = Rs.139.78
# 2025-04-13 16:41:08,695 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:08,734 - INFO - Processing Awfis Space Solutions Ltd. (AWFIS)
# 2025-04-13 16:41:08,747 - INFO - Processing Azad Engineering Ltd. (AZAD)
# 2025-04-13 16:41:08,863 - INFO - Verified unique data for ARVINDFASN: Latest price = Rs.382.00
# 2025-04-13 16:41:08,866 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:08,917 - INFO - Processing Bajaj Hindusthan Sugar Ltd. (BAJAJHIND)
# 2025-04-13 16:41:08,954 - INFO - ACI.NS: 1d: div-adjust-repair-bad: Removing phantom div(s): ['2023-07-21']
# 2025-04-13 16:41:09,010 - INFO - Verified unique data for ASHOKA: Latest price = Rs.186.49
# 2025-04-13 16:41:09,044 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:09,111 - INFO - Verified unique data for ARVIND: Latest price = Rs.333.10
# 2025-04-13 16:41:09,118 - INFO - Verified unique data for AVALON: Latest price = Rs.812.30
# 2025-04-13 16:41:09,118 - INFO - Processing Balaji Amines Ltd. (BALAMINES)
# 2025-04-13 16:41:09,122 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:09,130 - INFO - Verified unique data for ASTRAMICRO: Latest price = Rs.723.00
# 2025-04-13 16:41:09,135 - INFO - Verified unique data for ACI: Latest price = Rs.601.10
# 2025-04-13 16:41:09,140 - INFO - Verified unique data for AURIONPRO: Latest price = Rs.1556.80
# 2025-04-13 16:41:09,141 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:09,167 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:09,173 - INFO - Processing Balu Forge Industries Ltd. (BALUFORGE)
# 2025-04-13 16:41:09,173 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:09,174 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:09,233 - INFO - Processing Banco Products (India) Ltd. (BANCOINDIA)
# 2025-04-13 16:41:09,250 - INFO - Processing Bansal Wire Industries Ltd. (BANSALWIRE)
# 2025-04-13 16:41:09,282 - INFO - Processing Bhansali Engineering Polymers Ltd. (BEPL)
# 2025-04-13 16:41:09,298 - INFO - Processing Bharat Bijlee Ltd. (BBL)
# 2025-04-13 16:41:09,452 - INFO - Verified unique data for AVANTIFEED: Latest price = Rs.799.65
# 2025-04-13 16:41:09,454 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:09,482 - INFO - Processing Birla Corporation Ltd. (BIRLACORPN)
# 2025-04-13 16:41:09,869 - INFO - Verified unique data for AWFIS: Latest price = Rs.634.35
# 2025-04-13 16:41:09,873 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:09,893 - INFO - Verified unique data for AZAD: Latest price = Rs.1337.25
# 2025-04-13 16:41:09,903 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:09,909 - INFO - Processing Blue Jet Healthcare Ltd. (BLUEJET)
# 2025-04-13 16:41:09,936 - INFO - Processing Bombay Dyeing & Manufacturing Co. Ltd. (BOMDYEING)
# 2025-04-13 16:41:10,065 - INFO - Verified unique data for BAJAJHIND: Latest price = Rs.18.22
# 2025-04-13 16:41:10,066 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:10,094 - INFO - Processing Borosil Ltd. (BOROLTD)
# 2025-04-13 16:41:10,283 - INFO - Verified unique data for BALAMINES: Latest price = Rs.1205.35
# 2025-04-13 16:41:10,287 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:10,327 - INFO - Processing Borosil Renewables Ltd. (BORORENEW)
# 2025-04-13 16:41:10,355 - INFO - Verified unique data for BALUFORGE: Latest price = Rs.627.75
# 2025-04-13 16:41:10,356 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:10,380 - INFO - Processing CIE Automotive India Ltd. (CIEINDIA)
# 2025-04-13 16:41:10,492 - INFO - Verified unique data for BANCOINDIA: Latest price = Rs.335.85
# 2025-04-13 16:41:10,509 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:10,584 - INFO - Processing CMS Info Systems Ltd. (CMSINFO)
# 2025-04-13 16:41:10,635 - INFO - Verified unique data for BBL: Latest price = Rs.2881.20
# 2025-04-13 16:41:10,648 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:10,689 - INFO - Verified unique data for BANSALWIRE: Latest price = Rs.349.75
# 2025-04-13 16:41:10,707 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:10,715 - INFO - Verified unique data for BEPL: Latest price = Rs.106.64
# 2025-04-13 16:41:10,747 - INFO - Processing CSB Bank Ltd. (CSBBANK)
# 2025-04-13 16:41:10,749 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:10,760 - INFO - Processing Cartrade Tech Ltd. (CARTRADE)
# 2025-04-13 16:41:10,796 - INFO - Processing Ceigall India Ltd. (CEIGALL)
# 2025-04-13 16:41:10,808 - INFO - Verified unique data for BIRLACORPN: Latest price = Rs.1109.95
# 2025-04-13 16:41:10,809 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:10,837 - INFO - Processing Cello World Ltd. (CELLO)
# 2025-04-13 16:41:11,055 - INFO - Verified unique data for BLUEJET: Latest price = Rs.683.55
# 2025-04-13 16:41:11,056 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:11,080 - INFO - Processing Chemplast Sanmar Ltd. (CHEMPLASTS)
# 2025-04-13 16:41:11,157 - INFO - Verified unique data for BOMDYEING: Latest price = Rs.126.91
# 2025-04-13 16:41:11,158 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:11,187 - INFO - Processing Choice International Ltd. (CHOICEIN)
# 2025-04-13 16:41:11,214 - INFO - Verified unique data for BOROLTD: Latest price = Rs.326.65
# 2025-04-13 16:41:11,215 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:11,243 - INFO - Processing Cigniti Technologies Ltd. (CIGNITITEC)
# 2025-04-13 16:41:11,519 - INFO - Verified unique data for CIEINDIA: Latest price = Rs.400.80
# 2025-04-13 16:41:11,520 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:11,548 - INFO - Processing Cyient DLM Ltd. (CYIENTDLM)
# 2025-04-13 16:41:11,612 - INFO - Verified unique data for BORORENEW: Latest price = Rs.478.65
# 2025-04-13 16:41:11,613 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:11,643 - INFO - Processing DCB Bank Ltd. (DCBBANK)
# 2025-04-13 16:41:11,832 - INFO - Verified unique data for CMSINFO: Latest price = Rs.453.35
# 2025-04-13 16:41:11,833 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:11,865 - INFO - Processing DCX Systems Ltd. (DCXINDIA)
# 2025-04-13 16:41:11,887 - INFO - Verified unique data for CSBBANK: Latest price = Rs.323.00
# 2025-04-13 16:41:11,888 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:11,917 - INFO - Processing Datamatics Global Services Ltd. (DATAMATICS)
# 2025-04-13 16:41:11,996 - INFO - Verified unique data for CARTRADE: Latest price = Rs.1538.10
# 2025-04-13 16:41:11,999 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:12,038 - INFO - Processing Dhani Services Ltd. (DHANI)
# 2025-04-13 16:41:12,041 - INFO - Verified unique data for CELLO: Latest price = Rs.523.75
# 2025-04-13 16:41:12,042 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:12,080 - INFO - Processing Dilip Buildcon Ltd. (DBL)
# 2025-04-13 16:41:12,145 - INFO - Verified unique data for CEIGALL: Latest price = Rs.254.60
# 2025-04-13 16:41:12,146 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:12,167 - INFO - Processing Dishman Carbogen Amcis Ltd. (DCAL)
# 2025-04-13 16:41:12,212 - INFO - Verified unique data for CHEMPLASTS: Latest price = Rs.432.70
# 2025-04-13 16:41:12,213 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:12,241 - INFO - Processing Dodla Dairy Ltd. (DODLA)
# 2025-04-13 16:41:12,321 - INFO - Verified unique data for CHOICEIN: Latest price = Rs.515.60
# 2025-04-13 16:41:12,322 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:12,351 - INFO - Processing Dynamatic Technologies Ltd. (DYNAMATECH)
# 2025-04-13 16:41:12,383 - INFO - Verified unique data for CIGNITITEC: Latest price = Rs.1172.35
# 2025-04-13 16:41:12,384 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:12,412 - INFO - Processing EPL Ltd. (EPL)
# 2025-04-13 16:41:12,665 - INFO - Verified unique data for CYIENTDLM: Latest price = Rs.445.30
# 2025-04-13 16:41:12,666 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:12,693 - INFO - Processing Easy Trip Planners Ltd. (EASEMYTRIP)
# 2025-04-13 16:41:12,832 - INFO - Verified unique data for DCBBANK: Latest price = Rs.117.91
# 2025-04-13 16:41:12,833 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:12,872 - INFO - Processing Edelweiss Financial Services Ltd. (EDELWEISS)
# 2025-04-13 16:41:12,999 - INFO - Verified unique data for DCXINDIA: Latest price = Rs.229.38
# 2025-04-13 16:41:13,000 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:13,029 - INFO - Processing Electronics Mart India Ltd. (EMIL)
# 2025-04-13 16:41:13,087 - INFO - Verified unique data for DATAMATICS: Latest price = Rs.570.45
# 2025-04-13 16:41:13,088 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:13,121 - INFO - Processing Electrosteel Castings Ltd. (ELECTCAST)
# 2025-04-13 16:41:13,261 - INFO - Verified unique data for DHANI: Latest price = Rs.54.00
# 2025-04-13 16:41:13,264 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:13,300 - INFO - Verified unique data for DBL: Latest price = Rs.442.65
# 2025-04-13 16:41:13,313 - INFO - Processing Embassy Developments Ltd. (EMBDL)
# 2025-04-13 16:41:13,316 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:13,331 - INFO - Verified unique data for DCAL: Latest price = Rs.203.95
# 2025-04-13 16:41:13,358 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:13,378 - INFO - Processing Entero Healthcare Solutions Ltd. (ENTERO)
# 2025-04-13 16:41:13,396 - INFO - Processing Enviro Infra Engineers Ltd. (EIEL)
# 2025-04-13 16:41:13,455 - INFO - Verified unique data for DODLA: Latest price = Rs.1185.80
# 2025-04-13 16:41:13,456 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:13,485 - INFO - Processing Epigral Ltd. (EPIGRAL)
# 2025-04-13 16:41:13,613 - INFO - Verified unique data for EPL: Latest price = Rs.184.60
# 2025-04-13 16:41:13,616 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:13,646 - INFO - Verified unique data for DYNAMATECH: Latest price = Rs.6275.50
# 2025-04-13 16:41:13,655 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:13,657 - INFO - Processing Equitas Small Finance Bank Ltd. (EQUITASBNK)
# 2025-04-13 16:41:13,687 - INFO - Processing Ethos Ltd. (ETHOSLTD)
# 2025-04-13 16:41:13,848 - INFO - Verified unique data for EASEMYTRIP: Latest price = Rs.13.08
# 2025-04-13 16:41:13,849 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:13,880 - INFO - Processing Eureka Forbes Ltd. (EUREKAFORB)
# 2025-04-13 16:41:14,097 - INFO - Verified unique data for EDELWEISS: Latest price = Rs.79.06
# 2025-04-13 16:41:14,098 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:14,129 - INFO - Processing FDC Ltd. (FDC)
# 2025-04-13 16:41:14,158 - INFO - Verified unique data for EMIL: Latest price = Rs.119.56
# 2025-04-13 16:41:14,159 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:14,188 - INFO - Processing Fiem Industries Ltd (FIEMIND)
# 2025-04-13 16:41:14,351 - INFO - Verified unique data for ELECTCAST: Latest price = Rs.94.87
# 2025-04-13 16:41:14,352 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:14,381 - INFO - Processing Fine Organic Industries Ltd. (FINEORG)
# 2025-04-13 16:41:14,495 - INFO - Verified unique data for ENTERO: Latest price = Rs.1160.55
# 2025-04-13 16:41:14,498 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:14,520 - INFO - Processing Fineotex Chemical Ltd. (FCL)
# 2025-04-13 16:41:14,616 - INFO - Verified unique data for EMBDL: Latest price = Rs.100.39
# 2025-04-13 16:41:14,617 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:14,653 - INFO - Verified unique data for EIEL: Latest price = Rs.205.41
# 2025-04-13 16:41:14,669 - INFO - Processing Force Motors Ltd. (FORCEMOT)
# 2025-04-13 16:41:14,671 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:14,723 - INFO - Processing G R Infraprojects Ltd. (GRINFRA)
# 2025-04-13 16:41:14,913 - INFO - Verified unique data for ETHOSLTD: Latest price = Rs.2548.10
# 2025-04-13 16:41:14,932 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:14,976 - INFO - Processing GHCL Ltd. (GHCL)
# 2025-04-13 16:41:14,988 - INFO - Verified unique data for EQUITASBNK: Latest price = Rs.57.65
# 2025-04-13 16:41:14,989 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:15,032 - INFO - Processing GMM Pfaudler Ltd. (GMMPFAUDLR)
# 2025-04-13 16:41:15,089 - INFO - Verified unique data for EPIGRAL: Latest price = Rs.1784.65
# 2025-04-13 16:41:15,090 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:15,118 - INFO - Processing GMR Power and Urban Infra Ltd. (GMRP&UI)
# 2025-04-13 16:41:15,157 - INFO - EUREKAFORB.NS: 1h: price-reconstruct: Too old (8 rows tagged)
# 2025-04-13 16:41:15,183 - INFO - Verified unique data for EUREKAFORB: Latest price = Rs.501.70
# 2025-04-13 16:41:15,184 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:15,207 - INFO - Processing Gabriel India Ltd. (GABRIEL)
# 2025-04-13 16:41:15,272 - INFO - Verified unique data for FDC: Latest price = Rs.421.50
# 2025-04-13 16:41:15,273 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:15,303 - INFO - Processing Ganesh Housing Corporation Ltd. (GANESHHOUC)
# 2025-04-13 16:41:15,426 - INFO - Verified unique data for FIEMIND: Latest price = Rs.1364.90
# 2025-04-13 16:41:15,427 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:15,455 - INFO - Processing Ganesha Ecosphere Ltd. (GANECOS)
# 2025-04-13 16:41:15,544 - INFO - Verified unique data for FINEORG: Latest price = Rs.4040.30
# 2025-04-13 16:41:15,545 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:15,573 - INFO - Processing Garware Hi-Tech Films Ltd. (GRWRHITECH)
# 2025-04-13 16:41:15,745 - INFO - Verified unique data for FCL: Latest price = Rs.227.57
# 2025-04-13 16:41:15,746 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:15,774 - INFO - Processing Garware Technical Fibres Ltd. (GARFIBRES)
# 2025-04-13 16:41:15,861 - INFO - Verified unique data for GRINFRA: Latest price = Rs.1073.10
# 2025-04-13 16:41:15,862 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:15,890 - INFO - Processing Gateway Distriparks Ltd. (GATEWAY)
# 2025-04-13 16:41:15,941 - INFO - Verified unique data for FORCEMOT: Latest price = Rs.8705.05
# 2025-04-13 16:41:15,942 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:15,971 - INFO - Processing Gokaldas Exports Ltd. (GOKEX)
# 2025-04-13 16:41:16,189 - INFO - Verified unique data for GMMPFAUDLR: Latest price = Rs.1062.55
# 2025-04-13 16:41:16,190 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:16,221 - INFO - Processing Gopal Snacks Ltd. (GOPAL)
# 2025-04-13 16:41:16,250 - INFO - Verified unique data for GMRP&UI: Latest price = Rs.116.76
# 2025-04-13 16:41:16,250 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:16,280 - INFO - Processing Greaves Cotton Ltd. (GREAVESCOT)
# 2025-04-13 16:41:16,403 - INFO - Verified unique data for GHCL: Latest price = Rs.593.00
# 2025-04-13 16:41:16,404 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:16,483 - INFO - Processing Greenpanel Industries Ltd. (GREENPANEL)
# 2025-04-13 16:41:16,498 - INFO - Verified unique data for GABRIEL: Latest price = Rs.532.00
# 2025-04-13 16:41:16,501 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:16,530 - INFO - Verified unique data for GANESHHOUC: Latest price = Rs.1018.85
# 2025-04-13 16:41:16,540 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:16,542 - INFO - Processing Greenply Industries Ltd. (GREENPLY)
# 2025-04-13 16:41:16,571 - INFO - Processing Gujarat Ambuja Exports Ltd. (GAEL)
# 2025-04-13 16:41:16,626 - INFO - Verified unique data for GANECOS: Latest price = Rs.1550.55
# 2025-04-13 16:41:16,627 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:16,655 - INFO - Processing Gujarat State Fertilizers & Chemicals Ltd. (GSFC)
# 2025-04-13 16:41:16,768 - INFO - Verified unique data for GRWRHITECH: Latest price = Rs.2649.75
# 2025-04-13 16:41:16,769 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:16,799 - INFO - Processing Gulf Oil Lubricants India Ltd. (GULFOILLUB)
# 2025-04-13 16:41:16,932 - INFO - Verified unique data for GARFIBRES: Latest price = Rs.843.95
# 2025-04-13 16:41:16,933 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:16,961 - INFO - Processing H.G. Infra Engineering Ltd. (HGINFRA)
# 2025-04-13 16:41:17,078 - INFO - Verified unique data for GATEWAY: Latest price = Rs.61.41
# 2025-04-13 16:41:17,079 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:17,108 - INFO - Processing Hathway Cable & Datacom Ltd. (HATHWAY)
# 2025-04-13 16:41:17,140 - INFO - Verified unique data for GOKEX: Latest price = Rs.783.45
# 2025-04-13 16:41:17,142 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:17,170 - INFO - Processing Healthcare Global Enterprises Ltd. (HCG)
# 2025-04-13 16:41:17,347 - INFO - Verified unique data for GOPAL: Latest price = Rs.278.20
# 2025-04-13 16:41:17,348 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:17,368 - INFO - Processing HeidelbergCement India Ltd. (HEIDELBERG)
# 2025-04-13 16:41:17,447 - INFO - Verified unique data for GREAVESCOT: Latest price = Rs.182.70
# 2025-04-13 16:41:17,448 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:17,476 - INFO - Processing Hemisphere Properties India Ltd. (HEMIPROP)
# 2025-04-13 16:41:17,669 - INFO - Verified unique data for GREENPANEL: Latest price = Rs.227.65
# 2025-04-13 16:41:17,670 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:17,699 - INFO - Processing Heritage Foods Ltd. (HERITGFOOD)
# 2025-04-13 16:41:17,750 - INFO - Verified unique data for GAEL: Latest price = Rs.115.81
# 2025-04-13 16:41:17,751 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:17,805 - INFO - Processing Hikal Ltd. (HIKAL)
# 2025-04-13 16:41:17,817 - INFO - Verified unique data for GREENPLY: Latest price = Rs.286.45
# 2025-04-13 16:41:17,818 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:17,846 - INFO - Processing Hindustan Construction Co. Ltd. (HCC)
# 2025-04-13 16:41:18,011 - INFO - Verified unique data for GSFC: Latest price = Rs.175.62
# 2025-04-13 16:41:18,013 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:18,042 - INFO - Verified unique data for GULFOILLUB: Latest price = Rs.1131.55
# 2025-04-13 16:41:18,052 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:18,054 - INFO - Processing IFB Industries Ltd. (IFBIND)
# 2025-04-13 16:41:18,083 - INFO - Processing IIFL Capital Services Ltd. (IIFLCAPS)
# 2025-04-13 16:41:18,119 - INFO - Verified unique data for HGINFRA: Latest price = Rs.1052.85
# 2025-04-13 16:41:18,121 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:18,150 - INFO - Processing ITD Cementation India Ltd. (ITDCEM)
# 2025-04-13 16:41:18,248 - INFO - Verified unique data for HATHWAY: Latest price = Rs.13.04
# 2025-04-13 16:41:18,249 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:18,281 - INFO - Processing Imagicaaworld Entertainment Ltd. (IMAGICAA)
# 2025-04-13 16:41:18,301 - INFO - Verified unique data for HCG: Latest price = Rs.533.90
# 2025-04-13 16:41:18,302 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:18,330 - INFO - Processing India Glycols Ltd. (INDIAGLYCO)
# 2025-04-13 16:41:18,575 - INFO - Verified unique data for HEIDELBERG: Latest price = Rs.194.91
# 2025-04-13 16:41:18,576 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:18,616 - INFO - Processing India Shelter Finance Corporation Ltd. (INDIASHLTR)
# 2025-04-13 16:41:18,627 - INFO - Verified unique data for HEMIPROP: Latest price = Rs.123.47
# 2025-04-13 16:41:18,628 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:18,657 - INFO - Processing Indian Metals & Ferro Alloys Ltd. (IMFA)
# 2025-04-13 16:41:18,878 - INFO - Verified unique data for HERITGFOOD: Latest price = Rs.403.15
# 2025-04-13 16:41:18,879 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:18,907 - INFO - Processing Indigo Paints Ltd. (INDIGOPNTS)
# 2025-04-13 16:41:18,998 - INFO - Verified unique data for HIKAL: Latest price = Rs.418.85
# 2025-04-13 16:41:19,001 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:19,012 - INFO - Verified unique data for HCC: Latest price = Rs.25.18
# 2025-04-13 16:41:19,038 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:19,058 - INFO - Processing Indo Count Industries Ltd. (ICIL)
# 2025-04-13 16:41:19,071 - INFO - Processing Infibeam Avenues Ltd. (INFIBEAM)
# 2025-04-13 16:41:19,249 - INFO - Verified unique data for IFBIND: Latest price = Rs.1289.95
# 2025-04-13 16:41:19,250 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:19,278 - INFO - Processing Ingersoll Rand (India) Ltd. (INGERRAND)
# 2025-04-13 16:41:19,321 - INFO - Verified unique data for IIFLCAPS: Latest price = Rs.206.54
# 2025-04-13 16:41:19,322 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:19,341 - INFO - Processing Innova Captab Ltd. (INNOVACAP)
# 2025-04-13 16:41:19,375 - INFO - Verified unique data for ITDCEM: Latest price = Rs.524.90
# 2025-04-13 16:41:19,376 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:19,414 - INFO - Processing Inox Green Energy Services Ltd. (INOXGREEN)
# 2025-04-13 16:41:19,429 - INFO - Verified unique data for IMAGICAA: Latest price = Rs.65.44
# 2025-04-13 16:41:19,430 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:19,458 - INFO - Processing Ion Exchange (India) Ltd. (IONEXCHANG)
# 2025-04-13 16:41:19,492 - INFO - Verified unique data for INDIAGLYCO: Latest price = Rs.1269.05
# 2025-04-13 16:41:19,493 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:19,521 - INFO - Processing Isgec Heavy Engineering Ltd. (ISGEC)
# 2025-04-13 16:41:19,732 - INFO - Verified unique data for INDIASHLTR: Latest price = Rs.850.90
# 2025-04-13 16:41:19,733 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:19,757 - INFO - Processing J.Kumar Infraprojects Ltd. (JKIL)
# 2025-04-13 16:41:19,874 - INFO - Verified unique data for IMFA: Latest price = Rs.594.70
# 2025-04-13 16:41:19,875 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:19,903 - INFO - Processing JK Lakshmi Cement Ltd. (JKLAKSHMI)
# 2025-04-13 16:41:20,035 - INFO - Verified unique data for INDIGOPNTS: Latest price = Rs.985.70
# 2025-04-13 16:41:20,035 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:20,064 - INFO - Processing JK Paper Ltd. (JKPAPER)
# 2025-04-13 16:41:20,215 - INFO - Verified unique data for INFIBEAM: Latest price = Rs.16.25
# 2025-04-13 16:41:20,216 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:20,265 - INFO - Processing JTL Industries Ltd. (JTLIND)
# 2025-04-13 16:41:20,278 - INFO - Verified unique data for ICIL: Latest price = Rs.280.15
# 2025-04-13 16:41:20,279 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:20,311 - INFO - Processing Jai Balaji Industries Ltd. (JAIBALAJI)
# 2025-04-13 16:41:20,479 - INFO - Verified unique data for INGERRAND: Latest price = Rs.3502.55
# 2025-04-13 16:41:20,482 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:20,523 - INFO - Verified unique data for INNOVACAP: Latest price = Rs.875.70
# 2025-04-13 16:41:20,524 - INFO - Processing Jai Corp Ltd. (JAICORPLTD)
# 2025-04-13 16:41:20,525 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:20,569 - INFO - Processing Jain Irrigation Systems Ltd. (JISLJALEQS)
# 2025-04-13 16:41:20,580 - INFO - Verified unique data for INOXGREEN: Latest price = Rs.119.19
# 2025-04-13 16:41:20,581 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:20,634 - INFO - Processing Jamna Auto Industries Ltd. (JAMNAAUTO)
# 2025-04-13 16:41:20,660 - INFO - Verified unique data for IONEXCHANG: Latest price = Rs.483.15
# 2025-04-13 16:41:20,672 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:20,711 - INFO - Processing Jana Small Finance Bank Ltd. (JSFB)
# 2025-04-13 16:41:20,715 - INFO - Verified unique data for ISGEC: Latest price = Rs.1033.20
# 2025-04-13 16:41:20,716 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:20,744 - INFO - Processing Jindal Worldwide Ltd. (JINDWORLD)
# 2025-04-13 16:41:20,968 - INFO - Verified unique data for JKIL: Latest price = Rs.693.35
# 2025-04-13 16:41:20,969 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:20,997 - INFO - Processing Johnson Controls - Hitachi Air Conditioning India Ltd. (JCHAC)
# 2025-04-13 16:41:21,115 - INFO - Verified unique data for JKLAKSHMI: Latest price = Rs.788.95
# 2025-04-13 16:41:21,115 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:21,144 - INFO - Processing KPI Green Energy Ltd. (KPIGREEN)
# 2025-04-13 16:41:21,233 - INFO - Verified unique data for JKPAPER: Latest price = Rs.320.60
# 2025-04-13 16:41:21,234 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:21,261 - INFO - Processing KRBL Ltd. (KRBL)
# 2025-04-13 16:41:21,414 - INFO - Verified unique data for JTLIND: Latest price = Rs.74.63
# 2025-04-13 16:41:21,415 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:21,443 - INFO - Processing KSB Ltd. (KSB)
# 2025-04-13 16:41:21,499 - INFO - Verified unique data for JAIBALAJI: Latest price = Rs.131.30
# 2025-04-13 16:41:21,500 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:21,527 - INFO - Processing Kalyani Steels Ltd. (KSL)
# 2025-04-13 16:41:21,693 - INFO - Verified unique data for JAICORPLTD: Latest price = Rs.84.21
# 2025-04-13 16:41:21,693 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:21,729 - INFO - Processing Karnataka Bank Ltd. (KTKBANK)
# 2025-04-13 16:41:21,750 - INFO - Verified unique data for JISLJALEQS: Latest price = Rs.52.25
# 2025-04-13 16:41:21,752 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:21,782 - INFO - Processing Kaveri Seed Company Ltd. (KSCL)
# 2025-04-13 16:41:21,852 - INFO - Verified unique data for JAMNAAUTO: Latest price = Rs.72.16
# 2025-04-13 16:41:21,854 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:21,881 - INFO - Verified unique data for JSFB: Latest price = Rs.452.90
# 2025-04-13 16:41:21,893 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:21,899 - INFO - Processing Kirloskar Pneumatic Company Ltd. (KIRLPNU)
# 2025-04-13 16:41:21,950 - INFO - Processing LMW Ltd. (LMW)
# 2025-04-13 16:41:21,965 - INFO - Verified unique data for JINDWORLD: Latest price = Rs.67.53
# 2025-04-13 16:41:21,966 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:21,994 - INFO - Processing Laxmi Organic Industries Ltd. (LXCHEM)
# 2025-04-13 16:41:22,149 - INFO - Verified unique data for JCHAC: Latest price = Rs.1737.05
# 2025-04-13 16:41:22,151 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:22,181 - INFO - Processing Le Travenues Technology Ltd. (IXIGO)
# 2025-04-13 16:41:22,464 - INFO - Verified unique data for KPIGREEN: Latest price = Rs.410.15
# 2025-04-13 16:41:22,469 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:22,517 - INFO - Verified unique data for KRBL: Latest price = Rs.288.45
# 2025-04-13 16:41:22,519 - INFO - Processing Lloyds Engineering Works Ltd. (LLOYDSENGG)
# 2025-04-13 16:41:22,520 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:22,551 - INFO - Processing Lloyds Enterprises Ltd. (LLOYDSENT)
# 2025-04-13 16:41:22,668 - INFO - Verified unique data for KSB: Latest price = Rs.718.75
# 2025-04-13 16:41:22,669 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:22,697 - INFO - Processing Lux Industries Ltd. (LUXIND)
# 2025-04-13 16:41:22,744 - INFO - Verified unique data for KSL: Latest price = Rs.729.30
# 2025-04-13 16:41:22,745 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:22,775 - INFO - Processing MOIL Ltd. (MOIL)
# 2025-04-13 16:41:22,915 - INFO - Verified unique data for KTKBANK: Latest price = Rs.181.67
# 2025-04-13 16:41:22,916 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:22,947 - INFO - Processing MSTC Ltd. (MSTCLTD)
# 2025-04-13 16:41:22,987 - INFO - Verified unique data for KSCL: Latest price = Rs.1432.25
# 2025-04-13 16:41:22,988 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:23,020 - INFO - Processing MTAR Technologies Ltd. (MTARTECH)
# 2025-04-13 16:41:23,307 - INFO - Verified unique data for LXCHEM: Latest price = Rs.170.88
# 2025-04-13 16:41:23,313 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:23,315 - INFO - Verified unique data for LMW: Latest price = Rs.15283.35
# 2025-04-13 16:41:23,343 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:23,348 - INFO - Verified unique data for KIRLPNU: Latest price = Rs.1101.85
# 2025-04-13 16:41:23,370 - INFO - Processing Maharashtra Scooters Ltd. (MAHSCOOTER)
# 2025-04-13 16:41:23,384 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:23,396 - INFO - Processing Mahindra Lifespace Developers Ltd. (MAHLIFE)
# 2025-04-13 16:41:23,424 - INFO - Verified unique data for IXIGO: Latest price = Rs.141.27
# 2025-04-13 16:41:23,437 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:23,439 - INFO - Processing Man Infraconstruction Ltd. (MANINFRA)
# 2025-04-13 16:41:23,468 - INFO - Processing Marksans Pharma Ltd. (MARKSANS)
# 2025-04-13 16:41:23,668 - INFO - Verified unique data for LLOYDSENT: Latest price = Rs.52.02
# 2025-04-13 16:41:23,669 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:23,689 - INFO - Processing Max Estates Ltd. (MAXESTATES)
# 2025-04-13 16:41:23,880 - INFO - Verified unique data for LLOYDSENGG: Latest price = Rs.59.23
# 2025-04-13 16:41:23,883 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:23,930 - INFO - Processing Medplus Health Services Ltd. (MEDPLUS)
# 2025-04-13 16:41:23,955 - INFO - Verified unique data for LUXIND: Latest price = Rs.1352.75
# 2025-04-13 16:41:23,956 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:24,014 - INFO - Verified unique data for MOIL: Latest price = Rs.306.30
# 2025-04-13 16:41:24,014 - INFO - Processing Mishra Dhatu Nigam Ltd. (MIDHANI)
# 2025-04-13 16:41:24,015 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:24,048 - INFO - Processing Mrs. Bectors Food Specialities Ltd. (BECTORFOOD)
# 2025-04-13 16:41:24,202 - INFO - Verified unique data for MSTCLTD: Latest price = Rs.500.00
# 2025-04-13 16:41:24,213 - INFO - Verified unique data for MTARTECH: Latest price = Rs.1322.75
# 2025-04-13 16:41:24,214 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:24,214 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:24,289 - INFO - Processing NEOGEN CHEMICALS LTD. (NEOGEN)
# 2025-04-13 16:41:24,292 - INFO - Processing NESCO Ltd. (NESCO)
# 2025-04-13 16:41:24,569 - INFO - Verified unique data for MAHSCOOTER: Latest price = Rs.10448.30
# 2025-04-13 16:41:24,570 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:24,599 - INFO - Processing NOCIL Ltd. (NOCIL)
# 2025-04-13 16:41:24,681 - INFO - Verified unique data for MAHLIFE: Latest price = Rs.293.45
# 2025-04-13 16:41:24,684 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:24,728 - INFO - Verified unique data for MANINFRA: Latest price = Rs.144.80
# 2025-04-13 16:41:24,728 - INFO - Processing National Fertilizers Ltd. (NFL)
# 2025-04-13 16:41:24,729 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:24,761 - INFO - Processing Nazara Technologies Ltd. (NAZARA)
# 2025-04-13 16:41:24,792 - INFO - Verified unique data for MARKSANS: Latest price = Rs.205.58
# 2025-04-13 16:41:24,793 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:24,831 - INFO - Processing Nuvoco Vistas Corporation Ltd. (NUVOCO)
# 2025-04-13 16:41:25,066 - INFO - Verified unique data for MEDPLUS: Latest price = Rs.789.20
# 2025-04-13 16:41:25,069 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:25,103 - INFO - Processing Optiemus Infracom Ltd. (OPTIEMUS)
# 2025-04-13 16:41:25,138 - INFO - Verified unique data for MAXESTATES: Latest price = Rs.402.75
# 2025-04-13 16:41:25,139 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:25,168 - INFO - Processing Orchid Pharma Ltd. (ORCHPHARMA)
# 2025-04-13 16:41:25,253 - INFO - Verified unique data for BECTORFOOD: Latest price = Rs.1586.20
# 2025-04-13 16:41:25,254 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:25,284 - INFO - Processing Orient Cement Ltd. (ORIENTCEM)
# 2025-04-13 16:41:25,332 - INFO - Verified unique data for MIDHANI: Latest price = Rs.266.40
# 2025-04-13 16:41:25,333 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:25,361 - INFO - Processing Orissa Min Dev Co Ltd. (ORISSAMINE)
# 2025-04-13 16:41:25,431 - INFO - Verified unique data for NESCO: Latest price = Rs.950.70
# 2025-04-13 16:41:25,431 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:25,476 - INFO - Processing P N Gadgil Jewellers Ltd. (PNGJL)
# 2025-04-13 16:41:25,494 - INFO - Verified unique data for NEOGEN: Latest price = Rs.1558.55
# 2025-04-13 16:41:25,495 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:25,523 - INFO - Processing PC Jeweller Ltd. (PCJEWELLER)
# 2025-04-13 16:41:25,762 - INFO - Verified unique data for NOCIL: Latest price = Rs.180.36
# 2025-04-13 16:41:25,763 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:25,795 - INFO - Processing PTC India Ltd. (PTC)
# 2025-04-13 16:41:25,909 - INFO - Verified unique data for NAZARA: Latest price = Rs.961.05
# 2025-04-13 16:41:25,910 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:25,938 - INFO - Processing Paisalo Digital Ltd. (PAISALO)
# 2025-04-13 16:41:25,959 - INFO - Verified unique data for NUVOCO: Latest price = Rs.314.45
# 2025-04-13 16:41:25,960 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:25,989 - INFO - Processing Paradeep Phosphates Ltd. (PARADEEP)
# 2025-04-13 16:41:26,036 - INFO - Verified unique data for NFL: Latest price = Rs.78.28
# 2025-04-13 16:41:26,037 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:26,065 - INFO - Processing Paras Defence and Space Technologies Ltd. (PARAS)
# 2025-04-13 16:41:26,226 - INFO - Verified unique data for OPTIEMUS: Latest price = Rs.406.80
# 2025-04-13 16:41:26,227 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:26,255 - INFO - Processing Patel Engineering Ltd. (PATELENG)
# 2025-04-13 16:41:26,353 - INFO - Verified unique data for ORCHPHARMA: Latest price = Rs.719.70
# 2025-04-13 16:41:26,354 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:26,385 - INFO - Processing Pearl Global Industries Ltd. (PGIL)
# 2025-04-13 16:41:26,440 - INFO - Verified unique data for ORIENTCEM: Latest price = Rs.357.80
# 2025-04-13 16:41:26,441 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:26,470 - INFO - Processing Polyplex Corporation Ltd. (POLYPLEX)
# 2025-04-13 16:41:26,561 - INFO - Verified unique data for ORISSAMINE: Latest price = Rs.4693.95
# 2025-04-13 16:41:26,562 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:26,602 - INFO - Processing Power Mech Projects Ltd. (POWERMECH)
# 2025-04-13 16:41:26,705 - INFO - Verified unique data for PCJEWELLER: Latest price = Rs.13.60
# 2025-04-13 16:41:26,706 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:26,779 - INFO - Verified unique data for PNGJL: Latest price = Rs.532.55
# 2025-04-13 16:41:26,782 - INFO - Processing Pricol Ltd. (PRICOLLTD)
# 2025-04-13 16:41:26,782 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:26,815 - INFO - Processing Prince Pipes and Fittings Ltd. (PRINCEPIPE)
# 2025-04-13 16:41:27,021 - INFO - Verified unique data for PTC: Latest price = Rs.172.64
# 2025-04-13 16:41:27,022 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:27,050 - INFO - Processing Prism Johnson Ltd. (PRSMJOHNSN)
# 2025-04-13 16:41:27,112 - INFO - Verified unique data for PAISALO: Latest price = Rs.31.72
# 2025-04-13 16:41:27,113 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:27,142 - INFO - Processing Prudent Corporate Advisory Services Ltd. (PRUDENT)
# 2025-04-13 16:41:27,195 - INFO - Verified unique data for PARADEEP: Latest price = Rs.119.91
# 2025-04-13 16:41:27,196 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:27,224 - INFO - Processing Rain Industries Ltd (RAIN)
# 2025-04-13 16:41:27,245 - INFO - Verified unique data for PARAS: Latest price = Rs.973.25
# 2025-04-13 16:41:27,246 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:27,278 - INFO - Processing Rajesh Exports Ltd. (RAJESHEXPO)
# 2025-04-13 16:41:27,391 - INFO - Verified unique data for PATELENG: Latest price = Rs.39.87
# 2025-04-13 16:41:27,394 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:27,423 - INFO - Processing Rallis India Ltd. (RALLIS)
# 2025-04-13 16:41:27,561 - INFO - Verified unique data for PGIL: Latest price = Rs.1010.80
# 2025-04-13 16:41:27,562 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:27,590 - INFO - Processing Rategain Travel Technologies Ltd. (RATEGAIN)
# 2025-04-13 16:41:27,687 - INFO - Verified unique data for POLYPLEX: Latest price = Rs.1174.85
# 2025-04-13 16:41:27,688 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:27,716 - INFO - Processing RattanIndia Power Ltd. (RTNPOWER)
# 2025-04-13 16:41:27,810 - INFO - Verified unique data for POWERMECH: Latest price = Rs.2599.30
# 2025-04-13 16:41:27,811 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# ...
# 2025-04-13 16:41:31,004 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:31,033 - INFO - Processing Star Cement Ltd. (STARCEMENT)
# 2025-04-13 16:41:31,116 - INFO - Verified unique data for SFL: Latest price = Rs.657.55
# 2025-04-13 16:41:31,117 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:31,157 - INFO - Processing Sterlite Technologies Ltd. (STLTECH)
# 2025-04-13 16:41:31,197 - INFO - Verified unique data for SHAREINDIA: Latest price = Rs.157.48
# 2025-04-13 16:41:31,198 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:31,227 - INFO - Processing Strides Pharma Science Ltd. (STAR)
# 2025-04-13 16:41:31,353 - INFO - Verified unique data for SHILPAMED: Latest price = Rs.639.90
# 2025-04-13 16:41:31,353 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:31,381 - INFO - Processing Stylam Industries Ltd. (STYLAMIND)
# 2025-04-13 16:41:31,521 - INFO - Verified unique data for SBCL: Latest price = Rs.401.05
# 2025-04-13 16:41:31,522 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:31,551 - INFO - Processing Subros Ltd. (SUBROS)
# 2025-04-13 16:41:31,572 - INFO - Verified unique data for SHOPERSTOP: Latest price = Rs.495.20
# 2025-04-13 16:41:31,573 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:31,603 - INFO - Processing Sudarshan Chemical Industries Ltd. (SUDARSCHEM)
# 2025-04-13 16:41:31,803 - INFO - Verified unique data for SHRIPISTON: Latest price = Rs.1782.25
# 2025-04-13 16:41:31,806 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:31,815 - INFO - Verified unique data for SKIPPER: Latest price = Rs.426.20
# 2025-04-13 16:41:31,838 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:31,861 - INFO - Processing Sula Vineyards Ltd. (SULA)
# 2025-04-13 16:41:31,875 - INFO - Processing Sun Pharma Advanced Research Company Ltd. (SPARC)
# 2025-04-13 16:41:31,960 - INFO - Verified unique data for SOUTHBANK: Latest price = Rs.23.59
# 2025-04-13 16:41:31,961 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:31,990 - INFO - Processing Sunflag Iron & Steel Company Ltd. (SUNFLAG)
# 2025-04-13 16:41:32,164 - INFO - Verified unique data for SPANDANA: Latest price = Rs.240.20
# 2025-04-13 16:41:32,166 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:32,196 - INFO - Processing Sunteck Realty Ltd. (SUNTECK)
# 2025-04-13 16:41:32,217 - INFO - Verified unique data for STARCEMENT: Latest price = Rs.220.56
# 2025-04-13 16:41:32,218 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:32,250 - INFO - Processing Suprajit Engineering Ltd. (SUPRAJIT)
# 2025-04-13 16:41:32,396 - INFO - Verified unique data for STLTECH: Latest price = Rs.81.67
# 2025-04-13 16:41:32,409 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:32,445 - INFO - Verified unique data for STAR: Latest price = Rs.615.30
# 2025-04-13 16:41:32,451 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:32,452 - INFO - Processing Supriya Lifescience Ltd. (SUPRIYA)
# 2025-04-13 16:41:32,482 - INFO - Processing Surya Roshni Ltd. (SURYAROSNI)
# 2025-04-13 16:41:32,526 - INFO - Verified unique data for STYLAMIND: Latest price = Rs.1680.55
# 2025-04-13 16:41:32,526 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:32,555 - INFO - Processing Symphony Ltd. (SYMPHONY)
# 2025-04-13 16:41:32,770 - INFO - Verified unique data for SUDARSCHEM: Latest price = Rs.1009.95
# 2025-04-13 16:41:32,778 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:32,816 - INFO - Verified unique data for SUBROS: Latest price = Rs.570.30
# 2025-04-13 16:41:32,818 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:32,819 - INFO - Processing TARC Ltd. (TARC)
# 2025-04-13 16:41:32,849 - INFO - Processing TD Power Systems Ltd. (TDPOWERSYS)
# 2025-04-13 16:41:33,000 - INFO - Verified unique data for SULA: Latest price = Rs.275.50
# 2025-04-13 16:41:33,002 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:33,040 - INFO - Processing TVS Supply Chain Solutions Ltd. (TVSSCS)
# 2025-04-13 16:41:33,053 - INFO - Verified unique data for SPARC: Latest price = Rs.145.48
# 2025-04-13 16:41:33,054 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:33,083 - INFO - Processing Teamlease Services Ltd. (TEAMLEASE)
# 2025-04-13 16:41:33,141 - INFO - Verified unique data for SUNFLAG: Latest price = Rs.232.21
# 2025-04-13 16:41:33,142 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:33,171 - INFO - Processing Technocraft Industries (India) Ltd. (TIIL)
# 2025-04-13 16:41:33,341 - INFO - Verified unique data for SUNTECK: Latest price = Rs.373.50
# 2025-04-13 16:41:33,342 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:33,371 - INFO - Processing Tega Industries Ltd. (TEGA)
# 2025-04-13 16:41:33,415 - INFO - Verified unique data for SUPRAJIT: Latest price = Rs.381.80
# 2025-04-13 16:41:33,415 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:33,444 - INFO - Processing Texmaco Rail & Eng. Ltd. (TEXRAIL)
# 2025-04-13 16:41:33,614 - INFO - Verified unique data for SUPRIYA: Latest price = Rs.711.05
# 2025-04-13 16:41:33,616 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:33,668 - INFO - Processing Thangamayil Jewellery Ltd. (THANGAMAYL)
# 2025-04-13 16:41:33,687 - INFO - Verified unique data for SURYAROSNI: Latest price = Rs.247.48
# 2025-04-13 16:41:33,688 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:33,717 - INFO - Processing The Anup Engineering Ltd. (ANUP)
# 2025-04-13 16:41:33,785 - INFO - Verified unique data for SYMPHONY: Latest price = Rs.1135.75
# 2025-04-13 16:41:33,786 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:33,816 - INFO - Processing Thirumalai Chemicals Ltd. (TIRUMALCHM)
# 2025-04-13 16:41:34,012 - INFO - Verified unique data for TARC: Latest price = Rs.148.42
# 2025-04-13 16:41:34,012 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:34,054 - INFO - Processing Thomas Cook (India) Ltd. (THOMASCOOK)
# 2025-04-13 16:41:34,080 - INFO - Verified unique data for TDPOWERSYS: Latest price = Rs.408.75
# 2025-04-13 16:41:34,081 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:34,114 - INFO - Processing Tilaknagar Industries Ltd. (TI)
# 2025-04-13 16:41:34,277 - INFO - Verified unique data for TEAMLEASE: Latest price = Rs.1808.00
# 2025-04-13 16:41:34,278 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:34,310 - INFO - Processing Time Technoplast Ltd. (TIMETECHNO)
# 2025-04-13 16:41:34,429 - INFO - Verified unique data for TVSSCS: Latest price = Rs.110.21
# 2025-04-13 16:41:34,430 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:34,496 - INFO - Verified unique data for TIIL: Latest price = Rs.2304.20
# 2025-04-13 16:41:34,498 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:34,499 - INFO - Processing Tips Music Ltd. (TIPSMUSIC)
# 2025-04-13 16:41:34,554 - INFO - Processing Transrail Lighting Ltd. (TRANSRAILL)
# 2025-04-13 16:41:34,568 - INFO - Verified unique data for TEGA: Latest price = Rs.1449.60
# 2025-04-13 16:41:34,569 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:34,597 - INFO - Processing Ujjivan Small Finance Bank Ltd. (UJJIVANSFB)
# 2025-04-13 16:41:34,635 - INFO - Verified unique data for TEXRAIL: Latest price = Rs.134.30
# 2025-04-13 16:41:34,636 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:34,665 - INFO - Processing Unimech Aerospace and Manufacturing Ltd. (UNIMECH)
# 2025-04-13 16:41:34,893 - INFO - Verified unique data for ANUP: Latest price = Rs.3064.45
# 2025-04-13 16:41:34,895 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:34,928 - INFO - Verified unique data for THANGAMAYL: Latest price = Rs.2048.95
# 2025-04-13 16:41:34,937 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:34,940 - INFO - Processing V-Mart Retail Ltd. (VMART)
# 2025-04-13 16:41:34,969 - INFO - Processing V.I.P. Industries Ltd. (VIPIND)
# 2025-04-13 16:41:35,033 - INFO - Verified unique data for TIRUMALCHM: Latest price = Rs.261.54
# 2025-04-13 16:41:35,034 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:35,071 - INFO - Processing VST Industries Ltd. (VSTIND)
# 2025-04-13 16:41:35,213 - INFO - Verified unique data for THOMASCOOK: Latest price = Rs.131.31
# 2025-04-13 16:41:35,213 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:35,242 - INFO - Processing Va Tech Wabag Ltd. (WABAG)
# 2025-04-13 16:41:35,327 - INFO - Verified unique data for TI: Latest price = Rs.238.45
# 2025-04-13 16:41:35,329 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:35,360 - INFO - Processing Vaibhav Global Ltd. (VAIBHAVGBL)
# 2025-04-13 16:41:35,489 - INFO - Verified unique data for TIMETECHNO: Latest price = Rs.351.25
# 2025-04-13 16:41:35,490 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:35,518 - INFO - Processing Varroc Engineering Ltd. (VARROC)
# 2025-04-13 16:41:35,661 - INFO - Verified unique data for TRANSRAILL: Latest price = Rs.453.25
# 2025-04-13 16:41:35,662 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:35,680 - INFO - Processing Ventive Hospitality Ltd. (VENTIVE)
# 2025-04-13 16:41:35,802 - INFO - Verified unique data for UNIMECH: Latest price = Rs.904.60
# 2025-04-13 16:41:35,809 - INFO - Verified unique data for TIPSMUSIC: Latest price = Rs.641.15
# 2025-04-13 16:41:35,809 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:35,818 - INFO - Verified unique data for UJJIVANSFB: Latest price = Rs.39.77
# 2025-04-13 16:41:35,819 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:35,836 - INFO - Processing Venus Pipes & Tubes Ltd. (VENUSPIPES)
# 2025-04-13 16:41:35,837 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:35,868 - INFO - Processing Vesuvius India Ltd. (VESUVIUS)
# 2025-04-13 16:41:35,898 - INFO - Processing Voltamp Transformers Ltd (VOLTAMP)
# 2025-04-13 16:41:36,103 - INFO - Verified unique data for VMART: Latest price = Rs.3148.95
# 2025-04-13 16:41:36,104 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:36,131 - INFO - Processing Websol Energy System Ltd. (WEBELSOLAR)
# 2025-04-13 16:41:36,170 - INFO - Verified unique data for VIPIND: Latest price = Rs.267.20
# 2025-04-13 16:41:36,171 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:36,199 - INFO - Processing Welspun Enterprises Ltd. (WELENT)
# 2025-04-13 16:41:36,292 - INFO - Verified unique data for VSTIND: Latest price = Rs.273.70
# 2025-04-13 16:41:36,293 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:36,322 - INFO - Processing Wonderla Holidays Ltd. (WONDERLA)
# 2025-04-13 16:41:36,370 - INFO - Verified unique data for WABAG: Latest price = Rs.1401.60
# 2025-04-13 16:41:36,372 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:36,402 - INFO - Processing Yatharth Hospital & Trauma Care Services Ltd. (YATHARTH)
# 2025-04-13 16:41:36,537 - INFO - Verified unique data for VAIBHAVGBL: Latest price = Rs.211.18
# 2025-04-13 16:41:36,538 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:36,566 - INFO - Processing Zaggle Prepaid Ocean Services Ltd. (ZAGGLE)
# 2025-04-13 16:41:36,644 - INFO - Verified unique data for VARROC: Latest price = Rs.407.10
# 2025-04-13 16:41:36,645 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:36,673 - INFO - Processing Zinka Logistics Solutions Ltd. (BLACKBUCK)
# 2025-04-13 16:41:36,921 - INFO - Verified unique data for VENTIVE: Latest price = Rs.714.75
# 2025-04-13 16:41:36,921 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:36,938 - INFO - Processing Zydus Wellness Ltd. (ZYDUSWELL)
# 2025-04-13 16:41:37,109 - INFO - Verified unique data for VESUVIUS: Latest price = Rs.4408.35
# 2025-04-13 16:41:37,116 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:37,150 - INFO - Verified unique data for VENUSPIPES: Latest price = Rs.1197.35
# 2025-04-13 16:41:37,157 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:37,172 - INFO - Verified unique data for VOLTAMP: Latest price = Rs.6977.50
# 2025-04-13 16:41:37,174 - INFO - Processing eMudhra Ltd. (EMUDHRA)
# 2025-04-13 16:41:37,193 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:37,272 - INFO - Verified unique data for WEBELSOLAR: Latest price = Rs.1263.15
# 2025-04-13 16:41:37,273 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:37,423 - INFO - Verified unique data for WELENT: Latest price = Rs.488.40
# 2025-04-13 16:41:37,424 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:37,485 - INFO - Verified unique data for WONDERLA: Latest price = Rs.691.70
# 2025-04-13 16:41:37,486 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:37,538 - INFO - Verified unique data for YATHARTH: Latest price = Rs.453.25
# 2025-04-13 16:41:37,539 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:37,787 - INFO - Verified unique data for BLACKBUCK: Latest price = Rs.396.30
# 2025-04-13 16:41:37,788 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:37,907 - INFO - Verified unique data for ZAGGLE: Latest price = Rs.320.90
# 2025-04-13 16:41:37,907 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:38,076 - INFO - Verified unique data for ZYDUSWELL: Latest price = Rs.1748.10
# 2025-04-13 16:41:38,077 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)
# 2025-04-13 16:41:38,341 - INFO - Verified unique data for EMUDHRA: Latest price = Rs.840.90
# 2025-04-13 16:41:38,341 - INFO - Note: Last available date (2025-04-11) differs from requested date (2025-04-12)

# %%
# Green color ANSI escape code
GREEN = '\033[92m'
RESET = '\033[0m'  # Reset color code

print(f"{GREEN}Nifty Stocks Processed {len(stocks_nifty)} \nMidcap Stocks Processed {len(stocks_midcap)} \nSmallcap Stocks Processed {len(stocks_smallcap)} \nMicrocap Stocks Processed {len(stocks_microcap)}{RESET}")
print(f"{GREEN}Total Stocks Processed {len(stocks_nifty)+len(stocks_midcap)+len(stocks_smallcap)+len(stocks_microcap)}{RESET}")
# Out:
# Nifty Stocks Processed 50
# Midcap Stocks Processed 150
# Smallcap Stocks Processed 250
# Microcap Stocks Processed 250
# Total Stocks Processed 700
